# %%
DSolve[D[y[x],x] == y[x], y[x], x]
# Out:
#            x
# {{y[x] -> E  C[1]}}

# %%
eq = i * D[f[x,t],t] == (1/(2*m))D[D[f[x,t],x],x] + Cos[2*x*k + g[t]]*f[x,t]

DSolve[eq, f[x,t], x]
# Out:
#                                                (2,0)
#    (0,1)                                      f     [x, t]
# i f     [x, t] == Cos[2 k x + g[t]] f[x, t] + ------------
#                                                   2 m
#                                 m    2 k x + g[t]
# {{f[x, t] -> C[1] MathieuC[0, -(--), ------------] +
#                                  2        2
#                                 k
#
#                           m    2 k x + g[t]
# >      C[2] MathieuS[0, -(--), ------------] +
#                            2        2
#                           k
#
#                      m    2 k x + g[t]
# >      MathieuC[0, -(--), ------------]
#                       2        2
#                      k
#
#                                                  m    g[t] + 2 k K[1]
# >       Inactive[Integrate][(2 i m MathieuS[0, -(--), ---------------]
#                                                   2          2
#                                                  k
# ...

# %%
Plot3D[Sin[x^2 + y] + Cos[x + y^2], {x, -3,3}, {y,-3,3}]
# Out:
# -Graphics3D-
