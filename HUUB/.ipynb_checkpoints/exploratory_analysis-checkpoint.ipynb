# %%
import pandas as pd
import numpy as np
import seaborn as sns
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999

# %%
df = pd.read_excel("Case_Study_Dataset.xlsx", header=1)
df.head(5)
# Out:
#    hubspot_deal  deal_value brand_origin brand_tier brand_type  \
# 0            46      1920.0     Portugal          S      Other
# 1          5714         NaN       Sweden        NaN      Adult
# 2            54         NaN     Portugal        NaN      Other
# 3           356      2400.0    Singapore          S      Other
# 4            58         NaN        Spain        NaN  Men;Women
#
#   products_category production_origin                   sales_channels  \
# 0       Accessories          Portugal                        Ecommerce
# 1           Apparel  Portugal, Turkey  Ecommerce;Wholesale;Marketplace
# 2       Accessories          portugal              Ecommerce;Wholesale
# 3       Accessories          Portugal              Wholesale;Ecommerce
# 4          Footwear             spain             Ecommerce;Own Stores
#
#   instagram_followers    main_markets ecommerce_platform items_per_season  \
# 0               10455          Europe              Other             3200
# 1                 NaN  Germany;Europe            Shopify              NaN
# 2            5k - 20k             NaN            Shopify              NaN
# 3                N.D.     Middle East            Shopify              400
# 4              > 100k          Europe            Shopify              N.D
#
#    creation_date        estimated_close_date                  close_date  \
# 0     20180110.0  2017-12-15 00:00:00.000000                         NaN
# 1     20191115.0  2019-12-09 00:00:00.000000  2019-12-09 00:00:00.000000
# 2     20180116.0  2019-01-31 15:37:10.000000                         NaN
# 3     20180730.0  2018-08-29 17:40:15.000000                         NaN
# 4     20180122.0                         NaN                         NaN
#
#                 pipeline  hubspot_stage
# 0    Conversion Pipeline              8
# 1    Onboarding Pipeline             31
# 2  Inside Sales Pipeline             26
# 3    Conversion Pipeline             23
# 4         Fairs Pipeline             27

# %%
df.shape
# Out:
# (6164, 17)

# %%
df["brand_tier"].value_counts()
# Out:
# S      143
# M       48
# L       12
# XL       5
# XXL      3
# Name: brand_tier, dtype: int64

# %% [markdown]
# ### Even though we have 6164 observations, less than 200 are actually classified

# %% [markdown]
# # Data Cleaning of the Brand Origin

# %%
df.brand_origin = df.brand_origin.apply(lambda x: x.lower() if type(x)==str else x) # Capitalize all entries
sorted([x for x in df.brand_origin.unique() if type(x)==str])
# Out:
# ['amsterdam',
#  'andorra',
#  'argentina',
#  'australia',
#  'australia, new zealand',
#  'austria',
#  'bahrain',
#  'bangladesh',
#  'belarus',
#  'belgium',
#  'belgium-ukraine',
#  'berlin',
#  'brasil',
#  'brazil',
#  'bulgaria',
#  'california',
#  'canada',
#  'china',
#  'colombia',
#  'croatia',
#  'cyprus',
#  'czech republic',
#  'danimarca',
#  'denmark',
#  'deutschland',
#  'dubai',
#  'egypt',
#  'espanha',
#  'estonia',
#  'faroe islands',
#  'finland',
#  'france',
#  'france / morocco',
#  'france, australia',
#  'georgia',
#  'germany',
#  'germany, netherlands',
#  'ghana',
#  'grecia',
#  'greece',
#  'helsinki',
#  'holand',
#  'hong kong',
#  'hungary',
#  'iceland',
#  'india',
#  'indonesia',
#  'ireland',
#  'island',
#  'israel',
#  'italy',
#  'itália',
#  'japan',
#  'korea',
#  'latvia',
#  'letonia',
#  'lithuania',
#  'luxembourg',
#  'malaysia',
#  'mexico',
#  'moldova',
#  'monaco',
#  'nepal',
#  'netherlands',
#  'netherlands (the)',
#  'netherlands, turkey',
#  'new york',
#  'new zealand',
#  'norway',
#  'partner  referral',
#  'peru',
#  'poland',
#  'poland ',
#  'polland',
#  'portugal',
#  'portugal/ united kingdom',
#  'referral',
#  'romania',
#  'russia',
#  'saudi arabia',
#  'scotland',
#  'serbia',
#  'singapore',
#  'singapure',
#  'slovakia',
#  'slovenia',
#  'south africa',
#  'south korea',
#  'spain',
#  'spain / gran canaria',
#  'sri lanka',
#  'stockholm',
#  'suiça',
#  'svizzera',
#  'sweden',
#  'sweden ',
#  'swenden',
#  'switzerland',
#  'taiwan',
#  'thailand',
#  'the netherlands',
#  'the netherlands ',
#  'turkey',
#  'turquey',
#  'uk',
#  'uk portugal',
#  'uk/ portugal',
#  'ukraine',
#  'united arab emirates',
#  'united kingdom',
#  'united kingdom, greece',
#  'united kingdom/usa',
#  'united kingdown',
#  'united kingom',
#  'united states',
#  'united states of america',
#  'us',
#  'us - eu branch',
#  'usa',
#  'usa / pt',
#  'usa georgia',
#  'usa, brasil',
#  'usa, portugal',
#  'usa, spain',
#  'usa, uk',
#  'venezuela']

# %% [markdown]
# # **First design question:** What do we want to do with assets with multiple countries? We could duplicate the lines so that it takes that into account, use a single (more important) country or consider it as a separate entity. For now I will evolve with the latter.

# %%
# Correcting misspelings or other issues
# One of the entries is island. Could they mean Iceland?
country_manual_corrections = {
 'brasil':'brazil',
 'danimarca': 'denmark',
 'deutschland': 'germany',
 'dubai': 'united arab emirates', # I assume we don't want to separate dubai from other places
 'espanha': 'spain',
 'grecia': 'greece',
 'helsinki': 'finland',
 'holand': 'netherlands',
 'itália':'italy',
 'letonia': 'lithuania',
 'the netherlands': 'netherlands',
 'netherlands (the)': 'netherlands',
 'new york': "usa",
 'poland ':'poland',
 'polland':'poland',
 'partner  referral': 'referral',
 'singapure':'singapore',
 'korea': 'south korea', # I am assuming korea means south korea and never north korea, due to geopolitics and all
 'spain / gran canaria': 'spain',
 'stockholm': 'sweden',
 'suiça': 'switzerland',
 'sweden ': 'sweden',
 'swenden': 'sweden',
 'the netherlands': "netherlands",
 'the netherlands ': "netherlands",
 'turquey': "turkey",
 'uk/ portugal': 'uk portugal',
 'united kingdown':'united kingdom',
 'united kingom': 'united kingdom',
 'united states': 'usa',
 'united states of america': 'usa',
}

# %%
df.brand_origin = df.brand_origin.replace(country_manual_corrections)
sorted([x for x in df.brand_origin.unique() if type(x)==str])
# Out:
# ['amsterdam',
#  'andorra',
#  'argentina',
#  'australia',
#  'australia, new zealand',
#  'austria',
#  'bahrain',
#  'bangladesh',
#  'belarus',
#  'belgium',
#  'belgium-ukraine',
#  'berlin',
#  'brazil',
#  'bulgaria',
#  'california',
#  'canada',
#  'china',
#  'colombia',
#  'croatia',
#  'cyprus',
#  'czech republic',
#  'denmark',
#  'egypt',
#  'estonia',
#  'faroe islands',
#  'finland',
#  'france',
#  'france / morocco',
#  'france, australia',
#  'georgia',
#  'germany',
#  'germany, netherlands',
#  'ghana',
#  'greece',
#  'hong kong',
#  'hungary',
#  'iceland',
#  'india',
#  'indonesia',
#  'ireland',
#  'island',
#  'israel',
#  'italy',
#  'japan',
#  'latvia',
#  'lithuania',
#  'luxembourg',
#  'malaysia',
#  'mexico',
#  'moldova',
#  'monaco',
#  'nepal',
#  'netherlands',
#  'netherlands, turkey',
#  'new zealand',
#  'norway',
#  'peru',
#  'poland',
#  'portugal',
#  'portugal/ united kingdom',
#  'referral',
#  'romania',
#  'russia',
#  'saudi arabia',
#  'scotland',
#  'serbia',
#  'singapore',
#  'slovakia',
#  'slovenia',
#  'south africa',
#  'south korea',
#  'spain',
#  'sri lanka',
#  'svizzera',
#  'sweden',
#  'switzerland',
#  'taiwan',
#  'thailand',
#  'turkey',
#  'uk',
#  'uk portugal',
#  'ukraine',
#  'united arab emirates',
#  'united kingdom',
#  'united kingdom, greece',
#  'united kingdom/usa',
#  'us',
#  'us - eu branch',
#  'usa',
#  'usa / pt',
#  'usa georgia',
#  'usa, brasil',
#  'usa, portugal',
#  'usa, spain',
#  'usa, uk',
#  'venezuela']

# %%
country_order_counts = pd.DataFrame(data=df.brand_origin.value_counts(normalize=True))
country_order_counts.columns = ["frequency"]
country_order_counts["cumulative frequency"] = country_order_counts.cumsum()
country_order_counts.T
# Out:
#                          spain  united kingdom    france     italy   germany  \
# frequency             0.106114        0.104261  0.101735  0.094829  0.092976
# cumulative frequency  0.106114        0.210376  0.312110  0.406940  0.499916
#
#                       portugal   denmark        uk  netherlands       usa  \
# frequency             0.081691  0.056594  0.046488     0.045814  0.035371
# cumulative frequency  0.581607  0.638201  0.684689     0.730504  0.765875
#
#                         sweden   belgium    poland    greece   finland  \
# frequency             0.033182  0.025602  0.020044  0.017854  0.014317
# cumulative frequency  0.799057  0.824659  0.844703  0.862557  0.876874
#
#                         norway    turkey  switzerland     japan   austria  \
# frequency             0.010106  0.009938     0.009432  0.008927  0.007243
# cumulative frequency  0.886980  0.896918     0.906350  0.915277  0.922520
#
#                        ukraine  australia    canada  lithuania  south korea  \
# frequency             0.005558   0.005390  0.004885   0.004548     0.004042
# cumulative frequency  0.928078   0.933468  0.938353   0.942900     0.946943
#
#                        ireland    latvia    russia   romania   hungary  \
# frequency             0.003706  0.003706  0.003200  0.003032  0.002358
# cumulative frequency  0.950648  0.954354  0.957554  0.960586  0.962944
#
#                       new zealand    brazil   iceland   estonia  bulgaria  \
# frequency                0.002358  0.002190  0.002021  0.001853  0.001684
# cumulative frequency     0.965302  0.967492  0.969513  0.971366  0.973050
#
#                       scotland  czech republic   moldova    serbia    israel  \
# frequency             0.001516        0.001516  0.001516  0.001516  0.001516
# cumulative frequency  0.974566        0.976082  0.977598  0.979114  0.980630
#
#                           peru     china     india  slovakia  singapore  \
# frequency             0.001179  0.001179  0.001179  0.001179   0.001011
# cumulative frequency  0.981809  0.982988  0.984167  0.985346   0.986357
#
#                       hong kong  argentina  slovenia   croatia    taiwan  \
# frequency              0.000842   0.000674  0.000674  0.000674  0.000674
# cumulative frequency   0.987199   0.987873  0.988546  0.989220  0.989894
#
#                       luxembourg  uk portugal  united arab emirates    cyprus  \
# frequency               0.000505     0.000505              0.000505  0.000505
# cumulative frequency    0.990399     0.990904              0.991410  0.991915
#
#                        belarus   georgia    island    mexico  malaysia  \
# frequency             0.000337  0.000337  0.000337  0.000337  0.000337
# cumulative frequency  0.992252  0.992589  0.992926  0.993263  0.993599
#
#                       referral  california  belgium-ukraine  colombia  \
# frequency             0.000337    0.000168         0.000168  0.000168
# cumulative frequency  0.993936    0.994105         0.994273  0.994442
#
#                       usa, brasil  netherlands, turkey  \
# frequency                0.000168             0.000168
# cumulative frequency     0.994610             0.994779
#
#                       united kingdom, greece  germany, netherlands  indonesia  \
# frequency                           0.000168              0.000168   0.000168
# cumulative frequency                0.994947              0.995115   0.995284
#
#                       france, australia  sri lanka  bangladesh  svizzera  \
# frequency                      0.000168   0.000168    0.000168  0.000168
# cumulative frequency           0.995452   0.995621    0.995789  0.995958
#
#                       usa, spain  usa, portugal  south africa   andorra  \
# frequency               0.000168       0.000168      0.000168  0.000168
# cumulative frequency    0.996126       0.996294      0.996463  0.996631
#
#                       portugal/ united kingdom  venezuela  \
# frequency                             0.000168   0.000168
# cumulative frequency                  0.996800   0.996968
#
#                       australia, new zealand   bahrain  france / morocco  \
# frequency                           0.000168  0.000168          0.000168
# cumulative frequency                0.997137  0.997305          0.997473
#
#                       us - eu branch  amsterdam     egypt     nepal  usa / pt  \
# frequency                   0.000168   0.000168  0.000168  0.000168  0.000168
# cumulative frequency        0.997642   0.997810  0.997979  0.998147  0.998316
#
#                       thailand        us    berlin  usa georgia  \
# frequency             0.000168  0.000168  0.000168     0.000168
# cumulative frequency  0.998484  0.998653  0.998821     0.998989
#
#                       united kingdom/usa     ghana    monaco   usa, uk  \
# frequency                       0.000168  0.000168  0.000168  0.000168
# cumulative frequency            0.999158  0.999326  0.999495  0.999663
#
#                       faroe islands  saudi arabia
# frequency                  0.000168      0.000168
# cumulative frequency       0.999832      1.000000

# %% [markdown]
# # We can see that by taking the first few brand origins up until Cyprus we already cover over 99% of the deals while not having to deal with multiple countries and small countries either, hence allowing a fast analysis of most orders and then leaving the corner cases for later

# %%
df.head(5).T
# Out:
#                                                0  \
# hubspot_deal                                  46
# deal_value                                  1920
# brand_origin                            portugal
# brand_tier                                     S
# brand_type                                 Other
# products_category                    Accessories
# production_origin                       Portugal
# sales_channels                         Ecommerce
# instagram_followers                        10455
# main_markets                              Europe
# ecommerce_platform                         Other
# items_per_season                            3200
# creation_date                        2.01801e+07
# estimated_close_date  2017-12-15 00:00:00.000000
# close_date                                   NaN
# pipeline                     Conversion Pipeline
# hubspot_stage                                  8
#
#                                                     1  \
# hubspot_deal                                     5714
# deal_value                                        NaN
# brand_origin                                   sweden
# brand_tier                                        NaN
# brand_type                                      Adult
# products_category                             Apparel
# production_origin                    Portugal, Turkey
# sales_channels        Ecommerce;Wholesale;Marketplace
# instagram_followers                               NaN
# main_markets                           Germany;Europe
# ecommerce_platform                            Shopify
# items_per_season                                  NaN
# creation_date                             2.01911e+07
# estimated_close_date       2019-12-09 00:00:00.000000
# close_date                 2019-12-09 00:00:00.000000
# pipeline                          Onboarding Pipeline
# hubspot_stage                                      31
#
#                                                2                           3  \
# hubspot_deal                                  54                         356
# deal_value                                   NaN                        2400
# brand_origin                            portugal                   singapore
# brand_tier                                   NaN                           S
# brand_type                                 Other                       Other
# products_category                    Accessories                 Accessories
# production_origin                       portugal                    Portugal
# sales_channels               Ecommerce;Wholesale         Wholesale;Ecommerce
# instagram_followers                     5k - 20k                        N.D.
# main_markets                                 NaN                 Middle East
# ecommerce_platform                       Shopify                     Shopify
# items_per_season                             NaN                         400
# creation_date                        2.01801e+07                 2.01807e+07
# estimated_close_date  2019-01-31 15:37:10.000000  2018-08-29 17:40:15.000000
# close_date                                   NaN                         NaN
# pipeline                   Inside Sales Pipeline         Conversion Pipeline
# hubspot_stage                                 26                          23
#
#                                          4
# hubspot_deal                            58
# deal_value                             NaN
# brand_origin                         spain
# brand_tier                             NaN
# brand_type                       Men;Women
# products_category                 Footwear
# production_origin                    spain
# sales_channels        Ecommerce;Own Stores
# instagram_followers                 > 100k
# main_markets                        Europe
# ecommerce_platform                 Shopify
# items_per_season                       N.D
# creation_date                  2.01801e+07
# estimated_close_date                   NaN
# close_date                             NaN
# pipeline                    Fairs Pipeline
# hubspot_stage                           27

# %%
# Violin plot for instagram followers
histogram_followers = df[df.instagram_followers.astype(int, errors="ignore").apply(lambda x: type(x)==int)][["instagram_followers", "deal_value", "brand_tier"]]
histogram_followers["instagram_followers"] = histogram_followers["instagram_followers"].apply(lambda x:np.log(x)) # for getting the plot in log scale
histogram_followers.head(30).T
# Out:
#                          0        5        8        10      13       26   \
# instagram_followers  9.25484  8.51839  10.5976  9.35427  7.2717  7.48212
# deal_value              1920     3600      NaN     3840    4000     4000
# brand_tier                 S        S      NaN        S       S        S
#
#                          35      36       63       64       66       68   \
# instagram_followers  9.07372  7.7757  10.1572  7.31389  8.97954  7.46623
# deal_value              4000    4000      NaN     4000     4800     6000
# brand_tier                 S       S      NaN        S        S        S
#
#                         76       79       82       84       85       86   \
# instagram_followers  7.8018  11.1795  8.62909  10.1862  7.50549  9.80527
# deal_value             7200      NaN     9000    12000    12000    12000
# brand_tier                S      NaN        S        S        S        S
#
#                          102      103      106      229      237      267  \
# instagram_followers  7.80384  8.29455  9.49552  11.3383  9.31875  8.45361
# deal_value             12800    15000    24000    25000    27000    27000
# brand_tier                 S        S        S        S        S        S
#
#                          295      302     395      572      584      687
# instagram_followers  8.69951  11.0852  9.3676  9.21692  9.90349  10.2073
# deal_value             30000      NaN     NaN    30000    30000    30000
# brand_tier                 S      NaN     NaN        S        S        S

# %%
histogram_followers.groupby("brand_tier")["deal_value"].describe().style.background_gradient(cmap='viridis')
# Out:
# <style  type="text/css" >
#     #T_899b091a_fdb4_11ea_86ee_7b378d86636crow0_col0 {
#             background-color:  #48186a;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow0_col1 {
#             background-color:  #481b6d;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow0_col2 {
#             background-color:  #471164;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow0_col3 {
#             background-color:  #471365;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow0_col4 {
#             background-color:  #481c6e;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow0_col5 {
#             background-color:  #481d6f;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow0_col6 {
#             background-color:  #481b6d;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow0_col7 {
#             background-color:  #481c6e;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow1_col0 {
#             background-color:  #365c8d;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow1_col1 {
#             background-color:  #460b5e;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow1_col2 {
#             background-color:  #450457;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow1_col3 {
#             background-color:  #481769;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow1_col4 {
#             background-color:  #470d60;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow1_col5 {
#             background-color:  #460a5d;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow1_col6 {
#             background-color:  #470d60;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow1_col7 {
#             background-color:  #46085c;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow2_col0 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow2_col1 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow2_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow2_col3 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow2_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow2_col5 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow2_col6 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow2_col7 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow3_col0 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow3_col1 {
#             background-color:  #453781;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow3_col2 {
#             background-color:  #433e85;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow3_col3 {
#             background-color:  #463480;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow3_col4 {
#             background-color:  #453581;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow3_col5 {
#             background-color:  #453882;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow3_col6 {
#             background-color:  #443983;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow3_col7 {
#             background-color:  #453781;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow4_col0 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow4_col1 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow4_col2 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow4_col3 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow4_col4 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow4_col5 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow4_col6 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_899b091a_fdb4_11ea_86ee_7b378d86636crow4_col7 {
#             background-color:  #fde725;
#             color:  #000000;
#         }</style><table id="T_899b091a_fdb4_11ea_86ee_7b378d86636c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >mean</th>        <th class="col_heading level0 col2" >std</th>        <th class="col_heading level0 col3" >min</th>        <th class="col_heading level0 col4" >25%</th>        <th class="col_heading level0 col5" >50%</th>        <th class="col_heading level0 col6" >75%</th>        <th class="col_heading level0 col7" >max</th>    </tr>    <tr>        <th class="index_name level0" >brand_tier</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_899b091a_fdb4_11ea_86ee_7b378d86636clevel0_row0" class="row_heading level0 row0" >L</th>
#                         <td id="T_899b091a_fdb4_11ea_86ee_7b378d86636crow0_col0" class="data row0 col0" >7.000000</td>
#                         <td id="T_899b091a_fdb4_11ea_86ee_7b378d86636crow0_col1" class="data row0 col1" >229471.428571</td>
#                         <td id="T_899b091a_fdb4_11ea_86ee_7b378d86636crow0_col2" class="data row0 col2" >115597.962991</td>
#                         <td id="T_899b091a_fdb4_11ea_86ee_7b378d86636crow0_col3" class="data row0 col3" >62300.000000</td>
#                         <td id="T_899b091a_fdb4_11ea_86ee_7b378d86636crow0_col4" class="data row0 col4" >170000.000000</td>
#                         <td id="T_899b091a_fdb4_11ea_86ee_7b378d86636crow0_col5" class="data row0 col5" >240000.000000</td>
#                         <td id="T_899b091a_fdb4_11ea_86ee_7b378d86636crow0_col6" class="data row0 col6" >282000.000000</td>
#                         <td id="T_899b091a_fdb4_11ea_86ee_7b378d86636crow0_col7" class="data row0 col7" >400000.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_899b091a_fdb4_11ea_86ee_7b378d86636clevel0_row1" class="row_heading level0 row1" >M</th>
#                         <td id="T_899b091a_fdb4_11ea_86ee_7b378d86636crow1_col0" class="data row1 col0" >24.000000</td>
#                         <td id="T_899b091a_fdb4_11ea_86ee_7b378d86636crow1_col1" class="data row1 col1" >120396.666667</td>
#                         <td id="T_899b091a_fdb4_11ea_86ee_7b378d86636crow1_col2" class="data row1 col2" >40080.058521</td>
#                         <td id="T_899b091a_fdb4_11ea_86ee_7b378d86636crow1_col3" class="data row1 col3" >7

# %% [markdown]
# From the plots and description we can observe that the brand_tiers are divided by instagram_followers, however the division is not clear

# %%
histogram_followers.groupby("brand_tier").nunique()
# Out:
#             instagram_followers  deal_value  brand_tier
# brand_tier
# L                             7           6           1
# M                            24          15           1
# S                            79          34           1
# XL                            2           2           1
# XXL                           2           2           1

# %%
histogram_followers.groupby("brand_tier")["instagram_followers"].describe().style.background_gradient(cmap='viridis')
# Out:
# <style  type="text/css" >
#     #T_899b091b_fdb4_11ea_86ee_7b378d86636crow0_col0 {
#             background-color:  #48186a;
#             color:  #f1f1f1;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow0_col1 {
#             background-color:  #404688;
#             color:  #f1f1f1;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow0_col2 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow0_col3 {
#             background-color:  #26828e;
#             color:  #000000;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow0_col4 {
#             background-color:  #414487;
#             color:  #f1f1f1;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow0_col5 {
#             background-color:  #2a778e;
#             color:  #000000;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow0_col6 {
#             background-color:  #423f85;
#             color:  #f1f1f1;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow0_col7 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow1_col0 {
#             background-color:  #365c8d;
#             color:  #f1f1f1;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow1_col1 {
#             background-color:  #481769;
#             color:  #f1f1f1;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow1_col2 {
#             background-color:  #481b6d;
#             color:  #f1f1f1;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow1_col3 {
#             background-color:  #453581;
#             color:  #f1f1f1;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow1_col4 {
#             background-color:  #472e7c;
#             color:  #f1f1f1;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow1_col5 {
#             background-color:  #46307e;
#             color:  #f1f1f1;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow1_col6 {
#             background-color:  #460a5d;
#             color:  #f1f1f1;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow1_col7 {
#             background-color:  #3c4f8a;
#             color:  #f1f1f1;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow2_col0 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow2_col1 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow2_col2 {
#             background-color:  #470d60;
#             color:  #f1f1f1;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow2_col3 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow2_col4 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow2_col5 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow2_col6 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow2_col7 {
#             background-color:  #472e7c;
#             color:  #f1f1f1;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow3_col0 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow3_col1 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow3_col2 {
#             background-color:  #355e8d;
#             color:  #f1f1f1;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow3_col3 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow3_col4 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow3_col5 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow3_col6 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow3_col7 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow4_col0 {
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow4_col1 {
#             background-color:  #277f8e;
#             color:  #000000;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow4_col2 {
#             background-color:  #fde725;
#             color:  #000000;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow4_col3 {
#             background-color:  #1f958b;
#             color:  #000000;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow4_col4 {
#             background-color:  #2e6f8e;
#             color:  #f1f1f1;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow4_col5 {
#             background-color:  #277f8e;
#             color:  #000000;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow4_col6 {
#             background-color:  #21918c;
#             color:  #000000;
#         }    #T_899b091b_fdb4_11ea_86ee_7b378d86636crow4_col7 {
#             background-color:  #1e9c89;
#             color:  #000000;
#         }</style><table id="T_899b091b_fdb4_11ea_86ee_7b378d86636c" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >mean</th>        <th class="col_heading level0 col2" >std</th>        <th class="col_heading level0 col3" >min</th>        <th class="col_heading level0 col4" >25%</th>        <th class="col_heading level0 col5" >50%</th>        <th class="col_heading level0 col6" >75%</th>        <th class="col_heading level0 col7" >max</th>    </tr>    <tr>        <th class="index_name level0" >brand_tier</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_899b091b_fdb4_11ea_86ee_7b378d86636clevel0_row0" class="row_heading level0 row0" >L</th>
#                         <td id="T_899b091b_fdb4_11ea_86ee_7b378d86636crow0_col0" class="data row0 col0" >7.000000</td>
#                         <td id="T_899b091b_fdb4_11ea_86ee_7b378d86636crow0_col1" class="data row0 col1" >9.818630</td>
#                         <td id="T_899b091b_fdb4_11ea_86ee_7b378d86636crow0_col2" class="data row0 col2" >1.545167</td>
#                         <td id="T_899b091b_fdb4_11ea_86ee_7b378d86636crow0_col3" class="data row0 col3" >7.535830</td>
#                         <td id="T_899b091b_fdb4_11ea_86ee_7b378d86636crow0_col4" class="data row0 col4" >8.683173</td>
#                         <td id="T_899b091b_fdb4_11ea_86ee_7b378d86636crow0_col5" class="data row0 col5" >10.754557</td>
#                         <td id="T_899b091b_fdb4_11ea_86ee_7b378d86636crow0_col6" class="data row0 col6" >10.789448</td>
#                         <td id="T_899b091b_fdb4_11ea_86ee_7b378d86636crow0_col7" class="data row0 col7" >11.494782</td>
#             </tr>
#             <tr>
#                         <th id="T_899b091b_fdb4_11ea_86ee_7b378d86636clevel0_row1" class="row_heading level0 row1" >M</th>
#                         <td id="T_899b091b_fdb4_11ea_86ee_7b378d86636crow1_col0" class="data row1 col0" >24.000000</td>
#                         <td id="T_899b091b_fdb4_11ea_86ee_7b378d86636crow1_col1" class="data row1 col1" >9.056981</td>
#                         <td id="T_899b091b_fdb4_11ea_86ee_7b378d86636crow1_col2" class="data row1 col2" >1.707847</td>
#                         <td id="T_899b091b_fdb4_11ea_86ee_7b378d86636crow1_col3" class="data row1 col3" >5.075174</td>
#                         <td

# %% [markdown]
# From the 2 tables above it feels like deal_value plays a bigger role in the tier classification than instagram_followers

# %%
histogram_followers.groupby("brand_tier").plot.scatter(x="instagram_followers", y="deal_value", figsize=(40,3))
# Out:
# brand_tier
# L      AxesSubplot(0.125,0.125;0.775x0.755)
# M      AxesSubplot(0.125,0.125;0.775x0.755)
# S      AxesSubplot(0.125,0.125;0.775x0.755)
# XL     AxesSubplot(0.125,0.125;0.775x0.755)
# XXL    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
