# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
np.log(3)
# Out:
# 1.0986122886681096

# %%
np.geomspace
# Out:
# <function geomspace at 0x7cf26d7666f0>

# %%
x = range(1, 100)

# %%
plt.scatter(x=x, y=[np.log(t) * t for t in x])
