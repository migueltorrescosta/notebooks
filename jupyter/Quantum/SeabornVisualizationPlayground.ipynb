# %% [markdown]
# # Imports

# %%
import seaborn as sns

# %% [markdown]
# # Jointplot

# %%
penguins = sns.load_dataset("penguins")
sns.jointplot(
    data=penguins,
    x="bill_length_mm",
    y="bill_depth_mm",
    kind="reg",
)

# %%
sns.jointplot(
    data=penguins,
    x="bill_length_mm",
    y="bill_depth_mm",
    hue="species"
)

# %%
sns.jointplot(
    data=penguins,
    x="bill_length_mm",
    y="bill_depth_mm",
    hue="species",
    kind="reg"
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 sns.jointplot(
#       2     data=penguins,
#       3     x="bill_length_mm",
#       4     y="bill_depth_mm",
#       5     hue="species",
#       6     kind="reg"
#       7 )
#
# File ~/.cache/pypoetry/virtualenvs/notebooks-FzXm3nz_-py3.12/lib/python3.12/site-packages/seaborn/axisgrid.py:2228, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2226 if hue is not None and kind in ["hex", "reg", "resid"]:
#    2227     msg = f"Use of `hue` with `kind='{kind}'` is not currently supported."
# -> 2228     raise ValueError(msg)
#    2230 # Make a colormap based off the plot color
#    2231 # (Currently used only for kind="hex")
#    2232 if color is None:
#
# ...
