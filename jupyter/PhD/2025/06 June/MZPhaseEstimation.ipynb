# %% [markdown]
# # Steps
#
# 1. We work in `dim=2`, making the $J_z^2$ term negligible.
# 2. We select $J_S, \delta_S$ randomly.
# 3. We calculate $\frac{\partial}{\partial \delta_S} \mathrm{Tr}[\rho_t J_z]$ as a proxy for the variance of our estimator: for a large number of trials, $\mathrm{Var}[\hat{\delta}_S] \propto \left ( \frac{\partial}{\partial \delta_S} \mathrm{Tr}[\rho_t J_z] \right )^2$
# 4. We optimize the optimal ancilla coefficient for $\left | \frac{\partial}{\partial \delta_S} \mathrm{Tr}[\rho_t J_z] \right |$
# 5. We build the table with the original system, optimized couplings, and the sensitivity for both original and non-optimized systems

# %% [markdown]
# # Imports

# %%
from matplotlib.pyplot import figure
from matplotlib.colors import LogNorm
from tqdm import tqdm
from typing import Dict, List
import functools
import itertools
import numpy as np
import pandas as pd
import scipy
import seaborn as sns

figure(figsize=(16, 6))

# Create new `pandas` methods which use `tqdm` progress
# (can use tqdm_gui, optional kwargs, etc.)
tqdm.pandas()

# %%
eye_2 =  np.array([[.5, 0], [0, .5]])
j_x = np.array([[0, .5], [.5, 0]])
j_z = np.array([[.5, 0], [0, -.5]])
beam_splitter_system = np.divide(np.array([[1, 1j], [1j, 1]]), np.sqrt(2))
beam_splitter_full = np.kron(beam_splitter_system, eye_2)
initial_state = np.array([[1, 0], [0, 0]])
entangled_state = beam_splitter_system @ initial_state @ beam_splitter_system
full_initial_state = np.kron(entangled_state, initial_state)
precision = 1e-2
j_x, j_z, initial_state, entangled_state, full_initial_state
# Out:
# (array([[0. , 0.5],
#         [0.5, 0. ]]),
#  array([[ 0.5,  0. ],
#         [ 0. , -0.5]]),
#  array([[1, 0],
#         [0, 0]]),
#  array([[ 0.5+0.j ,  0. +0.5j],
#         [ 0. +0.5j, -0.5+0.j ]]),
#  array([[ 0.5+0.j ,  0. +0.j ,  0. +0.5j,  0. +0.j ],
#         [ 0. +0.j ,  0. +0.j ,  0. +0.j ,  0. +0.j ],
#         [ 0. +0.5j,  0. +0.j , -0.5+0.j , -0. +0.j ],
#         [ 0. +0.j ,  0. +0.j , -0. +0.j , -0. +0.j ]]))

# %%
full_initial_state
# Out:
# array([[ 0.5+0.j ,  0. +0.j ,  0. +0.5j,  0. +0.j ],
#        [ 0. +0.j ,  0. +0.j ,  0. +0.j ,  0. +0.j ],
#        [ 0. +0.5j,  0. +0.j , -0.5+0.j , -0. +0.j ],
#        [ 0. +0.j ,  0. +0.j , -0. +0.j , -0. +0.j ]])

# %% [markdown]
# # Single calculation

# %%
def system_optimization(j_s: float, delta_s: float) -> Dict[str, float]:
    hamiltonian_lower = (delta_s - precision) * j_z - j_s * j_x
    hamiltonian_upper = (delta_s + precision) * j_z - j_s * j_x
    def probability_difference(t: float):
        final_state_lower = scipy.linalg.expm(-1j * t * hamiltonian_lower) @ entangled_state @ scipy.linalg.expm(1j * t * hamiltonian_lower)
        prob_lower = np.abs((beam_splitter_system @ final_state_lower @ beam_splitter_system)[0][0]) ** 2
        final_state_upper = scipy.linalg.expm(-1j * t * hamiltonian_upper) @ entangled_state @ scipy.linalg.expm(1j * t * hamiltonian_upper)
        prob_upper = np.abs((beam_splitter_system @ final_state_upper @ beam_splitter_system)[0][0]) ** 2
        return - np.abs(prob_upper - prob_lower) # quantity to be minimized

    optimal_results = scipy.optimize.minimize(
        probability_difference,
        x0=1e-2 * np.random.rand(), # Start with a very small time. We want the optimal time to be bigger than the initial time, to ensure we minimize error compounding.
        method='Powell' # Experimentally Powell worked best
    )
    optimal_time = optimal_results.x[0]
    return {
        "time_system": optimal_time,
        "probability_difference_system": np.abs(probability_difference(optimal_time)),
        "optimization_message_system": optimal_results.message,
    }

# %%
system_optimization(2, 1)
# Out:
# {'time_system': 3.772545977753545,
#  'probability_difference_system': 0.021839307097579752,
#  'optimization_message_system': 'Optimization terminated successfully.'}

# %% [markdown]
# # Full calculation

# %%
def ancilla_optimization(j_s: float, delta_s: float, initial_time: float | None) -> Dict[str, float]:

    system_hamiltonian_lower = np.kron((delta_s - precision) * j_z - j_s * j_x, eye_2)
    system_hamiltonian_upper = np.kron((delta_s + precision) * j_z - j_s * j_x, eye_2)

    def probability_difference( x0: List[float]) -> float:
        j_a, delta_a, alpha_xx, alpha_xz, alpha_zx, alpha_zz, t = x0
        ancillary_hamiltonian = np.kron(eye_2, delta_a * j_z - j_a * j_x)
        interaction_hamiltonian = functools.reduce(
            lambda x, y: x + y,
            [
                alpha_xx * np.kron(j_x, j_x),
                alpha_xz * np.kron(j_x, j_z),
                alpha_zx * np.kron(j_z, j_x),
                alpha_zz * np.kron(j_z, j_z),
            ]
        )

        hamiltonian_lower = system_hamiltonian_lower + ancillary_hamiltonian + interaction_hamiltonian
        hamiltonian_upper = system_hamiltonian_upper + ancillary_hamiltonian + interaction_hamiltonian
        final_state_lower = scipy.linalg.expm(-1j * t * hamiltonian_lower) @ full_initial_state @ scipy.linalg.expm(1j * t * hamiltonian_lower)
        final_state_lower = beam_splitter_full @ final_state_lower @ beam_splitter_full
        reduced_state_lower = np.trace(np.array(final_state_lower).reshape(2,2,2,2), axis1=1, axis2=3)
        prob_lower = np.abs(reduced_state_lower[0][0])**2
        final_state_upper = scipy.linalg.expm(-1j * t * hamiltonian_upper) @ full_initial_state @ scipy.linalg.expm(1j * t * hamiltonian_upper)
        final_state_upper = beam_splitter_full @ final_state_upper @ beam_splitter_full
        reduced_state_upper = np.trace(np.array(final_state_upper).reshape(2,2,2,2), axis1=1, axis2=3)
        prob_upper = np.abs(reduced_state_upper[0][0])**2
        return - np.abs(prob_upper - prob_lower) # inverse of the gradient of the probability against delta_s

    initial_guess = 1e-5 * np.random.rand(7)
    if initial_time:
        initial_guess[-1] = initial_time

    optimal_results = scipy.optimize.minimize(
        probability_difference,
        x0=initial_guess, # Start with a very small time. We want the optimal time to be bigger than the initial time, to ensure we minimize error compounding.
        method='Powell'
    )

    ancilla_j_a, ancilla_delta_a, ancilla_alpha_xx, ancilla_alpha_xz, ancilla_alpha_zx, ancilla_alpha_zz, ancilla_t = optimal_results.x
    return {
        "j_a": ancilla_j_a,
        "delta_a": ancilla_delta_a,
        "alpha_xx": ancilla_alpha_xx,
        "alpha_xz": ancilla_alpha_xz,
        "alpha_zx": ancilla_alpha_zx,
        "alpha_zz": ancilla_alpha_zz,
        "time_ancilla": ancilla_t, # Time used when optimizing with all the coefficients available.
        "probability_difference_ancilla":np.abs(probability_difference(optimal_results.x)),
        "optimization_message_ancilla": optimal_results.message,
    }

# %%
ancilla_optimization(2,1, initial_time=5.099558682171591)
# Out:
# {'j_a': 6.588914383838129,
#  'delta_a': 20.17215525079058,
#  'alpha_xx': 0.7420778305986386,
#  'alpha_xz': 2.3466073330841275,
#  'alpha_zx': -1.3778169360484935,
#  'alpha_zz': -1.4288428904971666,
#  'time_ancilla': 51.093045509522234,
#  'probability_difference_ancilla': 0.019433275299676506,
#  'optimization_message_ancilla': 'Optimization terminated successfully.'}

# %% [markdown]
# # Batch calculation

# %%
def full_run(j_s: float, delta_s: float) -> Dict[str, float]:
    system_results = system_optimization(j_s, delta_s)
    ancilla_results = ancilla_optimization(j_s, delta_s, initial_time=system_results['time_system'])
    return {"j_s": j_s, "delta_s": delta_s} | system_results | ancilla_results # Merge dicts

# %%
k = 301 # TODO: Run overnight with k=201.
iterator = itertools.product(
    np.round(np.linspace(1., 3., k), 4), # j_s: float,
    np.round(np.linspace(1., 3., k), 4), # delta_s: float,
)
df = pd.DataFrame([
    full_run(a,b)
    for a,b
    in tqdm(iterator, total=k*k)],
)
df.sample(3).style.background_gradient(cmap='viridis', axis=0)
# Out:
#  17%|█▋        | 15656/90601 [2:02:49<9:47:58,  2.12it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 7
#       1 k = 301 # TODO: Run overnight with k=201.
#       2 iterator = itertools.product(
#       3     np.round(np.linspace(1., 3., k), 4), # j_s: float,
#       4     np.round(np.linspace(1., 3., k), 4), # delta_s: float,
#       5 )
#       6 df = pd.DataFrame([
# ----> 7     full_run(a,b)
#       8     for a,b
#       9     in tqdm(iterator, total=k*k)],
#      10 )
#      11 df.sample(3).style.background_gradient(cmap='viridis', axis=0)
#
# Cell In[22], line 3, in full_run(j_s, delta_s)
#       1 def full_run(j_s: float, delta_s: float) -> Dict[str, float]:
#       2     system_results = system_optimization(j_s, delta_s)
# ----> 3     ancilla_results = ancilla_optimization(j_s, delta_s, initial_time=system_results['time_system'])
#       4     return {"j_s": j_s, "delta_s": delta_s} | system_results | ancilla_results
#
# Cell In[20], line 35, in ancilla_optimization(j_s, delta_s, initial_time)
#      32 if initial_time:
#      33     initial_guess[-1] = initial_time
# ---> 35 optimal_results = scipy.optimize.minimize(
#      36     probability_difference,
#      37     x0=initial_guess, # Start with a very small time. We want the optimal time to be bigger than the initial time, to ensure we minimize error compounding.
#      38     method='Powell'
#      39 )
#      41 ancilla_j_a, ancilla_delta_a, ancilla_alpha_xx, ancilla_alpha_xz, ancilla_alpha_zx, ancilla_alpha_zz, ancilla_t = optimal_results.x
#      42 return {
#      43     "j_a": ancilla_j_a,
#      44     "delta_a": ancilla_delta_a,
#    (...)     51     "optimization_message_ancilla": optimal_results.message,
#      52 }
#
# File ~/.cache/pypoetry/virtualenvs/collapsedwave-FzXm3nz_-py3.12/lib/python3.12/site-packages/scipy/optimize/_minimize.py:729, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     726     res = _minimize_neldermead(fun, x0, args, callback, bounds=bounds,
#     727                                **options)
#     728 elif meth == 'powell':
# --> 729     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#     730 elif meth == 'cg':
#     731     res = _minimize_cg(fun, x0, args, jac, callback, **options)
#
# File ~/.cache/pypoetry/virtualenvs/collapsedwave-FzXm3nz_-py3.12/lib/python3.12/site-packages/scipy/optimize/_optimize.py:3529, in _minimize_powell(func, x0, args, callback, bounds, xtol, ftol, maxiter, maxfev, disp, direc, return_all, **unknown_options)
#    3527 direc1 = direc[i]
#    3528 fx2 = fval
# -> 3529 fval, x, direc1 = _linesearch_powell(func, x, direc1,
#    3530                                      tol=xtol * 100,
#    3531                                      lower_bound=lower_bound,
#    3532                                      upper_bound=upper_bound,
#    3533                                      fval=fval)
#    3534 if (fx2 - fval) > delta:
#    3535     delta = fx2 - fval
#
# File ~/.cache/pypoetry/virtualenvs/collapsedwave-FzXm3nz_-py3.12/lib/python3.12/site-packages/scipy/optimize/_optimize.py:3205, in _linesearch_powell(func, p, xi, tol, lower_bound, upper_bound, fval)
#    3202     return ((fval, p, xi) if fval is not None else (func(p), p, xi))
#    3203 elif lower_bound is None and upper_bound is None:
#    3204     # non-bounded minimization
# -> 3205     res = _recover_from_bracket_error(_minimize_scalar_brent,
#    3206                                       myfunc, None, tuple(), xtol=tol)
#    3207     alpha_min, fret = res.x, res.fun
#    3208     xi = alpha_min * xi
#
# File ~/.cache/pypoetry/virtualenvs/collapsedwave-FzXm3nz_-py3.12/lib/python3.12/site-packages/scipy/optimize/_optimize.py:3098, in _recover_from_bracket_error(solver, fun, bracket, args, **options)
#    3079 def _recover_from_bracket_error(solver, fun, bracket, args, **options):
#    3080     # `bracket` was originally written without checking whether the resulting
#    3081     # bracket is valid. `brent` and `golden` built on top of it without
#    (...)   3095     # storing the information needed by `minimize_scalar` in the error object,
#    3096     # and intercepting it here.
#    3097     try:
# -> 3098         res = solver(fun, bracket, args, **options)
#    3099     except BracketError as e:
#    3100         msg = str(e)
#
# File ~/.cache/pypoetry/virtualenvs/collapsedwave-FzXm3nz_-py3.12/lib/python3.12/site-packages/scipy/optimize/_optimize.py:2697, in _minimize_scalar_brent(func, brack, args, xtol, maxiter, disp, **unknown_options)
#    2694 brent = Brent(func=func, args=args, tol=tol,
#    2695               full_output=True, maxiter=maxiter, disp=disp)
#    2696 brent.set_bracket(brack)
# -> 2697 brent.optimize()
#    2698 x, fval, nit, nfev = brent.get_result(full_output=True)
#    2700 success = nit < maxiter and not (np.isnan(x) or np.isnan(fval))
#
# File ~/.cache/pypoetry/virtualenvs/collapsedwave-FzXm3nz_-py3.12/lib/python3.12/site-packages/scipy/optimize/_optimize.py:2534, in Brent.optimize(self)
#    2532 else:
#    2533     u = x + rat
# -> 2534 fu = func(*((u,) + self.args))      # calculate new output value
#    2535 funcalls += 1
#    2537 if (fu > fx):                 # if it's bigger than current
#
# File ~/.cache/pypoetry/virtualenvs/collapsedwave-FzXm3nz_-py3.12/lib/python3.12/site-packages/scipy/optimize/_optimize.py:3198, in _linesearch_powell.<locals>.myfunc(alpha)
#    3197 def myfunc(alpha):
# -> 3198     return func(p + alpha*xi)
#
# File ~/.cache/pypoetry/virtualenvs/collapsedwave-FzXm3nz_-py3.12/lib/python3.12/site-packages/scipy/optimize/_optimize.py:542, in _wrap_scalar_function_maxfun_validation.<locals>.function_wrapper(x, *wrapper_args)
#     540 ncalls[0] += 1
#     541 # A copy of x is sent to the user function (gh13740)
# --> 542 fx = function(np.copy(x), *(wrapper_args + args))
#     543 # Ideally, we'd like to a have a true scalar returned from f(x). For
#     544 # backwards-compatibility, also allow np.array([1.3]),
#     545 # np.array([[1.3]]) etc.
#     546 if not np.isscalar(fx):
#
# Cell In[20], line 13, in ancilla_optimization.<locals>.probability_difference(x0)
#       7 j_a, delta_a, alpha_xx, alpha_xz, alpha_zx, alpha_zz, t = x0
#       8 ancillary_hamiltonian = np.kron(eye_2, delta_a * j_z - j_a * j_x)
#       9 interaction_hamiltonian = functools.reduce(
#      10     lambda x, y: x + y,
#      11     [
#      12         alpha_xx * np.kron(j_x, j_x),
# ---> 13         alpha_xz * np.kron(j_x, j_z),
#      14         alpha_zx * np.kron(j_z, j_x),
#      15         alpha_zz * np.kron(j_z, j_z),
#      16     ]
#      17 )
#      19 hamiltonian_lower = system_hamiltonian_lower + ancillary_hamiltonian + interaction_hamiltonian
#      20 hamiltonian_upper = system_hamiltonian_upper + ancillary_hamiltonian + interaction_hamiltonian
#
# File ~/.cache/pypoetry/virtualenvs/collapsedwave-FzXm3nz_-py3.12/lib/python3.12/site-packages/numpy/lib/shape_base.py:1149, in kron(a, b)
#    1147 is_any_mat = isinstance(a, matrix) or isinstance(b, matrix)
#    1148 ndb, nda = b.ndim, a.ndim
# -> 1149 nd = max(ndb, nda)
#    1151 if (nda == 0 or ndb == 0):
#    1152     return _nx.multiply(a, b)
#
# KeyboardInterrupt:

# %%
df.sample(20).style.background_gradient(cmap='viridis', axis=0)
# Out:
# <style type="text/css">
# #T_aaaeb_row0_col0, #T_aaaeb_row19_col8 {
#   background-color: #481467;
#   color: #f1f1f1;
# }
# #T_aaaeb_row0_col1, #T_aaaeb_row7_col3, #T_aaaeb_row16_col11 {
#   background-color: #470d60;
#   color: #f1f1f1;
# }
# #T_aaaeb_row0_col2, #T_aaaeb_row0_col5, #T_aaaeb_row0_col6, #T_aaaeb_row1_col2, #T_aaaeb_row1_col7, #T_aaaeb_row5_col2, #T_aaaeb_row5_col3, #T_aaaeb_row5_col11, #T_aaaeb_row5_col12, #T_aaaeb_row7_col2, #T_aaaeb_row7_col9, #T_aaaeb_row7_col10, #T_aaaeb_row9_col2, #T_aaaeb_row10_col8, #T_aaaeb_row12_col2, #T_aaaeb_row14_col2, #T_aaaeb_row14_col11, #T_aaaeb_row15_col2, #T_aaaeb_row16_col1, #T_aaaeb_row16_col2, #T_aaaeb_row17_col0, #T_aaaeb_row17_col2, #T_aaaeb_row17_col11, #T_aaaeb_row17_col12, #T_aaaeb_row18_col2, #T_aaaeb_row18_col11 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_aaaeb_row0_col3, #T_aaaeb_row12_col11, #T_aaaeb_row18_col8 {
#   background-color: #481a6c;
#   color: #f1f1f1;
# }
# #T_aaaeb_row0_col7 {
#   background-color: #9bd93c;
#   color: #000000;
# }
# #T_aaaeb_row0_col8, #T_aaaeb_row0_col9, #T_aaaeb_row0_col10, #T_aaaeb_row1_col12, #T_aaaeb_row4_col3, #T_aaaeb_row6_col0, #T_aaaeb_row6_col2, #T_aaaeb_row6_col3, #T_aaaeb_row6_col11, #T_aaaeb_row6_col12, #T_aaaeb_row7_col6, #T_aaaeb_row7_col7, #T_aaaeb_row10_col3, #T_aaaeb_row11_col3, #T_aaaeb_row12_col5, #T_aaaeb_row18_col1, #T_aaaeb_row19_col3 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_aaaeb_row0_col11 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_aaaeb_row0_col12 {
#   background-color: #efe51c;
#   color: #000000;
# }
# #T_aaaeb_row1_col0 {
#   background-color: #bddf26;
#   color: #000000;
# }
# #T_aaaeb_row1_col1, #T_aaaeb_row9_col11, #T_aaaeb_row12_col3, #T_aaaeb_row15_col11 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_aaaeb_row1_col3, #T_aaaeb_row2_col2, #T_aaaeb_row2_col11, #T_aaaeb_row14_col12, #T_aaaeb_row16_col3 {
#   background-color: #471063;
#   color: #f1f1f1;
# }
# #T_aaaeb_row1_col5 {
#   background-color: #e5e419;
#   color: #000000;
# }
# #T_aaaeb_row1_col6, #T_aaaeb_row5_col5, #T_aaaeb_row9_col5, #T_aaaeb_row13_col5, #T_aaaeb_row14_col5, #T_aaaeb_row17_col5, #T_aaaeb_row19_col5 {
#   background-color: #bade28;
#   color: #000000;
# }
# #T_aaaeb_row1_col8, #T_aaaeb_row6_col8, #T_aaaeb_row16_col8 {
#   background-color: #470e61;
#   color: #f1f1f1;
# }
# #T_aaaeb_row1_col9 {
#   background-color: #30698e;
#   color: #f1f1f1;
# }
# #T_aaaeb_row1_col10 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# #T_aaaeb_row1_col11 {
#   background-color: #46307e;
#   color: #f1f1f1;
# }
# #T_aaaeb_row2_col0 {
#   background-color: #3e4989;
#   color: #f1f1f1;
# }
# #T_aaaeb_row2_col1 {
#   background-color: #37b878;
#   color: #f1f1f1;
# }
# #T_aaaeb_row2_col3 {
#   background-color: #93d741;
#   color: #000000;
# }
# #T_aaaeb_row2_col5, #T_aaaeb_row3_col5, #T_aaaeb_row4_col5, #T_aaaeb_row6_col5, #T_aaaeb_row8_col5, #T_aaaeb_row10_col5, #T_aaaeb_row11_col5, #T_aaaeb_row15_col5, #T_aaaeb_row18_col5 {
#   background-color: #b8de29;
#   color: #000000;
# }
# #T_aaaeb_row2_col6, #T_aaaeb_row3_col6, #T_aaaeb_row4_col6, #T_aaaeb_row5_col6, #T_aaaeb_row6_col6, #T_aaaeb_row10_col6, #T_aaaeb_row11_col6, #T_aaaeb_row12_col12, #T_aaaeb_row13_col6, #T_aaaeb_row14_col6, #T_aaaeb_row15_col6, #T_aaaeb_row17_col6, #T_aaaeb_row18_col6, #T_aaaeb_row19_col6 {
#   background-color: #6ccd5a;
#   color: #000000;
# }
# #T_aaaeb_row2_col7, #T_aaaeb_row9_col8, #T_aaaeb_row11_col7, #T_aaaeb_row13_col7, #T_aaaeb_row14_col7 {
#   background-color: #453581;
#   color: #f1f1f1;
# }
# #T_aaaeb_row2_col8, #T_aaaeb_row4_col2, #T_aaaeb_row4_col11 {
#   background-color: #482475;
#   color: #f1f1f1;
# }
# #T_aaaeb_row2_col9, #T_aaaeb_row3_col9, #T_aaaeb_row4_col9, #T_aaaeb_row6_col9, #T_aaaeb_row10_col9, #T_aaaeb_row11_col9, #T_aaaeb_row13_col9, #T_aaaeb_row16_col9, #T_aaaeb_row18_col9, #T_aaaeb_row19_col9 {
#   background-color: #42be71;
#   color: #f1f1f1;
# }
# #T_aaaeb_row2_col10, #T_aaaeb_row3_col10, #T_aaaeb_row10_col10, #T_aaaeb_row11_col10, #T_aaaeb_row18_col10, #T_aaaeb_row19_col10 {
#   background-color: #20a386;
#   color: #f1f1f1;
# }
# #T_aaaeb_row2_col12 {
#   background-color: #1f9a8a;
#   color: #f1f1f1;
# }
# #T_aaaeb_row3_col0 {
#   background-color: #b5de2b;
#   color: #000000;
# }
# #T_aaaeb_row3_col1 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_aaaeb_row3_col2, #T_aaaeb_row18_col3 {
#   background-color: #481d6f;
#   color: #f1f1f1;
# }
# #T_aaaeb_row3_col3 {
#   background-color: #ece51b;
#   color: #000000;
# }
# #T_aaaeb_row3_col7, #T_aaaeb_row4_col7, #T_aaaeb_row5_col7, #T_aaaeb_row6_col7, #T_aaaeb_row10_col7, #T_aaaeb_row19_col7 {
#   background-color: #453781;
#   color: #f1f1f1;
# }
# #T_aaaeb_row3_col8 {
#   background-color: #481668;
#   color: #f1f1f1;
# }
# #T_aaaeb_row3_col11 {
#   background-color: #481c6e;
#   color: #f1f1f1;
# }
# #T_aaaeb_row3_col12 {
#   background-color: #2eb37c;
#   color: #f1f1f1;
# }
# #T_aaaeb_row4_col0, #T_aaaeb_row12_col10 {
#   background-color: #2b758e;
#   color: #f1f1f1;
# }
# #T_aaaeb_row4_col1, #T_aaaeb_row5_col0, #T_aaaeb_row12_col6 {
#   background-color: #65cb5e;
#   color: #000000;
# }
# #T_aaaeb_row4_col8, #T_aaaeb_row7_col11 {
#   background-color: #481769;
#   color: #f1f1f1;
# }
# #T_aaaeb_row4_col10 {
#   background-color: #22a884;
#   color: #f1f1f1;
# }
# #T_aaaeb_row4_col12 {
#   background-color: #cde11d;
#   color: #000000;
# }
# #T_aaaeb_row5_col1 {
#   background-color: #482576;
#   color: #f1f1f1;
# }
# #T_aaaeb_row5_col8 {
#   background-color: #482173;
#   color: #f1f1f1;
# }
# #T_aaaeb_row5_col9 {
#   background-color: #40bd72;
#   color: #f1f1f1;
# }
# #T_aaaeb_row5_col10 {
#   background-color: #22a785;
#   color: #f1f1f1;
# }
# #T_aaaeb_row6_col1, #T_aaaeb_row15_col7, #T_aaaeb_row17_col7 {
#   background-color: #424186;
#   color: #f1f1f1;
# }
# #T_aaaeb_row6_col10, #T_aaaeb_row13_col10, #T_aaaeb_row15_col10, #T_aaaeb_row17_col10 {
#   background-color: #20a486;
#   color: #f1f1f1;
# }
# #T_aaaeb_row7_col0 {
#   background-color: #287c8e;
#   color: #f1f1f1;
# }
# #T_aaaeb_row7_col1 {
#   background-color: #e2e418;
#   color: #000000;
# }
# #T_aaaeb_row7_col5 {
#   background-color: #e7e419;
#   color: #000000;
# }
# #T_aaaeb_row7_col8 {
#   background-color: #25848e;
#   color: #f1f1f1;
# }
# #T_aaaeb_row7_col12 {
#   background-color: #60ca60;
#   color: #000000;
# }
# #T_aaaeb_row8_col0 {
#   background-color: #26828e;
#   color: #f1f1f1;
# }
# #T_aaaeb_row8_col1 {
#   background-color: #a0da39;
#   color: #000000;
# }
# #T_aaaeb_row8_col2, #T_aaaeb_row8_col11, #T_aaaeb_row14_col0, #T_aaaeb_row14_col3, #T_aaaeb_row17_col3, #T_aaaeb_row18_col12 {
#   background-color: #46075a;
#   color: #f1f1f1;
# }
# #T_aaaeb_row8_col3 {
#   background-color: #27808e;
#   color: #f1f1f1;
# }
# #T_aaaeb_row8_col6, #T_aaaeb_row9_col6 {
#   background-color: #6ece58;
#   color: #000000;
# }
# #T_aaaeb_row8_col7 {
#   background-color: #46327e;
#   color: #f1f1f1;
# }
# #T_aaaeb_row8_col8, #T_aaaeb_row9_col12, #T_aaaeb_row11_col2, #T_aaaeb_row11_col11, #T_aaaeb_row12_col1, #T_aaaeb_row19_col2, #T_aaaeb_row19_col11 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_aaaeb_row8_col9, #T_aaaeb_row9_col9 {
#   background-color: #3fbc73;
#   color: #f1f1f1;
# }
# #T_aaaeb_row8_col10 {
#   background-color: #1fa287;
#   color: #f1f1f1;
# }
# #T_aaaeb_row8_col12, #T_aaaeb_row13_col0 {
#   background-color: #3a538b;
#   color: #f1f1f1;
# }
# #T_aaaeb_row9_col0 {
#   background-color: #9dd93b;
#   color: #000000;
# }
# #T_aaaeb_row9_col1 {
#   background-color: #c2df23;
#   color: #000000;
# }
# #T_aaaeb_row9_col3 {
#   background-color: #46085c;
#   color: #f1f1f1;
# }
# #T_aaaeb_row9_col7 {
#   background-color: #423f85;
#   color: #f1f1f1;
# }
# #T_aaaeb_row9_col10, #T_aaaeb_row10_col1 {
#   background-color: #20938c;
#   color: #f1f1f1;
# }
# #T_aaaeb_row10_col0 {
#   background-color: #67cc5c;
#   color: #000000;
# }
# #T_aaaeb_row10_col2, #T_aaaeb_row10_col11 {
#   background-color: #34618d;
#   color: #f1f1f1;
# }
# #T_aaaeb_row10_col12 {
#   background-color: #d8e219;
#   color: #000000;
# }
# #T_aaaeb_row11_col0 {
#   background-color: #365d8d;
#   color: #f1f1f1;
# }
# #T_aaaeb_row11_col1 {
#   background-color: #90d743;
#   color: #000000;
# }
# #T_aaaeb_row11_col8, #T_aaaeb_row14_col8 {
#   background-color: #481b6d;
#   color: #f1f1f1;
# }
# #T_aaaeb_row11_col12 {
#   background-color: #cae11f;
#   color: #000000;
# }
# #T_aaaeb_row12_col0 {
#   background-color: #218

# %% [markdown]
# # Plots

# %%
df["information_gain"] = np.divide(df["probability_difference_ancilla"], df["probability_difference_system"])
df["log2_information_gain"] = np.log2(df["information_gain"])

# %%
figure(figsize=(20, 20))
sns.heatmap(
    df.pivot(columns="j_s", index="delta_s", values="information_gain"),
    # annot=True,
    cmap='viridis',
    fmt=".2f",
    norm=LogNorm(),
    square=True,
)
# Out:
# <Axes: xlabel='j_s', ylabel='delta_s'>

# %%
figure(figsize=(20, 2))
sns.histplot(
    df["information_gain"],
    bins=50,
    log_scale=True,
)
# Out:
# <Axes: xlabel='information_gain', ylabel='Count'>

# %%
df[[
    "j_s",
    "delta_s",
    "time_system",
    "time_ancilla",
    "probability_difference_system",
    "probability_difference_ancilla",
    "information_gain",
]].sample(10).style.background_gradient(cmap='viridis', axis=1)
# Out:
# <style type="text/css">
# #T_b3132_row0_col0, #T_b3132_row1_col4, #T_b3132_row2_col4, #T_b3132_row4_col1, #T_b3132_row4_col4, #T_b3132_row5_col1, #T_b3132_row6_col0, #T_b3132_row6_col4, #T_b3132_row7_col0, #T_b3132_row9_col4 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_b3132_row0_col1, #T_b3132_row0_col4, #T_b3132_row0_col5, #T_b3132_row0_col6, #T_b3132_row1_col5, #T_b3132_row1_col6, #T_b3132_row2_col5, #T_b3132_row2_col6, #T_b3132_row3_col5, #T_b3132_row3_col6, #T_b3132_row4_col5, #T_b3132_row4_col6, #T_b3132_row5_col4, #T_b3132_row5_col5, #T_b3132_row5_col6, #T_b3132_row6_col5, #T_b3132_row6_col6, #T_b3132_row7_col1, #T_b3132_row7_col4, #T_b3132_row7_col5, #T_b3132_row7_col6, #T_b3132_row8_col4, #T_b3132_row8_col5, #T_b3132_row9_col5, #T_b3132_row9_col6 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_b3132_row0_col2, #T_b3132_row0_col3, #T_b3132_row1_col3, #T_b3132_row2_col3, #T_b3132_row3_col3, #T_b3132_row4_col2, #T_b3132_row4_col3, #T_b3132_row5_col2, #T_b3132_row5_col3, #T_b3132_row6_col2, #T_b3132_row6_col3, #T_b3132_row7_col2, #T_b3132_row7_col3, #T_b3132_row8_col3, #T_b3132_row9_col3 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_b3132_row1_col0, #T_b3132_row3_col0 {
#   background-color: #460b5e;
#   color: #f1f1f1;
# }
# #T_b3132_row1_col1, #T_b3132_row4_col0, #T_b3132_row8_col6, #T_b3132_row9_col0, #T_b3132_row9_col1 {
#   background-color: #450559;
#   color: #f1f1f1;
# }
# #T_b3132_row1_col2 {
#   background-color: #81d34d;
#   color: #000000;
# }
# #T_b3132_row2_col0 {
#   background-color: #481a6c;
#   color: #f1f1f1;
# }
# #T_b3132_row2_col1 {
#   background-color: #482677;
#   color: #f1f1f1;
# }
# #T_b3132_row2_col2 {
#   background-color: #23898e;
#   color: #f1f1f1;
# }
# #T_b3132_row3_col1 {
#   background-color: #481668;
#   color: #f1f1f1;
# }
# #T_b3132_row3_col2 {
#   background-color: #f1e51d;
#   color: #000000;
# }
# #T_b3132_row3_col4, #T_b3132_row5_col0, #T_b3132_row6_col1 {
#   background-color: #450457;
#   color: #f1f1f1;
# }
# #T_b3132_row8_col0 {
#   background-color: #472f7d;
#   color: #f1f1f1;
# }
# #T_b3132_row8_col1 {
#   background-color: #481d6f;
#   color: #f1f1f1;
# }
# #T_b3132_row8_col2 {
#   background-color: #3b528b;
#   color: #f1f1f1;
# }
# #T_b3132_row9_col2 {
#   background-color: #efe51c;
#   color: #000000;
# }
# </style>
# <table id="T_b3132">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3132_level0_col0" class="col_heading level0 col0" >j_s</th>
#       <th id="T_b3132_level0_col1" class="col_heading level0 col1" >delta_s</th>
#       <th id="T_b3132_level0_col2" class="col_heading level0 col2" >time_system</th>
#       <th id="T_b3132_level0_col3" class="col_heading level0 col3" >time_ancilla</th>
#       <th id="T_b3132_level0_col4" class="col_heading level0 col4" >probability_difference_system</th>
#       <th id="T_b3132_level0_col5" class="col_heading level0 col5" >probability_difference_ancilla</th>
#       <th id="T_b3132_level0_col6" class="col_heading level0 col6" >information_gain</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b3132_level0_row0" class="row_heading level0 row0" >84371</th>
#       <td id="T_b3132_row0_col0" class="data row0 col0" >2.866700</td>
#       <td id="T_b3132_row0_col1" class="data row0 col1" >1.606700</td>
#       <td id="T_b3132_row0_col2" class="data row0 col2" >399.981900</td>
#       <td id="T_b3132_row0_col3" class="data row0 col3" >399.812476</td>
#       <td id="T_b3132_row0_col4" class="data row0 col4" >0.983775</td>
#       <td id="T_b3132_row0_col5" class="data row0 col5" >0.057505</td>
#       <td id="T_b3132_row0_col6" class="data row0 col6" >0.058454</td>
#     </tr>
#     <tr>
#       <th id="T_b3132_level0_row1" class="row_heading level0 row1" >70469</th>
#       <td id="T_b3132_row1_col0" class="data row1 col0" >2.560000</td>
#       <td id="T_b3132_row1_col1" class="data row1 col1" >1.233300</td>
#       <td id="T_b3132_row1_col2" class="data row1 col2" >69.280129</td>
#       <td id="T_b3132_row1_col3" class="data row1 col3" >85.661199</td>
#       <td id="T_b3132_row1_col4" class="data row1 col4" >0.379017</td>
#       <td id="T_b3132_row1_col5" class="data row1 col5" >0.030319</td>
#       <td id="T_b3132_row1_col6" class="data row1 col6" >0.079993</td>
#     </tr>
#     <tr>
#       <th id="T_b3132_level0_row2" class="row_heading level0 row2" >7041</th>
#       <td id="T_b3132_row2_col0" class="data row2 col0" >1.153300</td>
#       <td id="T_b3132_row2_col1" class="data row2 col1" >1.786700</td>
#       <td id="T_b3132_row2_col2" class="data row2 col2" >7.893145</td>
#       <td id="T_b3132_row2_col3" class="data row2 col3" >16.752793</td>
#       <td id="T_b3132_row2_col4" class="data row2 col4" >0.085944</td>
#       <td id="T_b3132_row2_col5" class="data row2 col5" >0.006024</td>
#       <td id="T_b3132_row2_col6" class="data row2 col6" >0.070091</td>
#     </tr>
#     <tr>
#       <th id="T_b3132_level0_row3" class="row_heading level0 row3" >12879</th>
#       <td id="T_b3132_row3_col0" class="data row3 col0" >1.280000</td>
#       <td id="T_b3132_row3_col1" class="data row3 col1" >2.580000</td>
#       <td id="T_b3132_row3_col2" class="data row3 col2" >45.093480</td>
#       <td id="T_b3132_row3_col3" class="data row3 col3" >46.144522</td>
#       <td id="T_b3132_row3_col4" class="data row3 col4" >0.497019</td>
#       <td id="T_b3132_row3_col5" class="data row3 col5" >0.018374</td>
#       <td id="T_b3132_row3_col6" class="data row3 col6" >0.036968</td>
#     </tr>
#     <tr>
#       <th id="T_b3132_level0_row4" class="row_heading level0 row4" >67493</th>
#       <td id="T_b3132_row4_col0" class="data row4 col0" >2.493300</td>
#       <td id="T_b3132_row4_col1" class="data row4 col1" >1.460000</td>
#       <td id="T_b3132_row4_col2" class="data row4 col2" >199.386473</td>
#       <td id="T_b3132_row4_col3" class="data row4 col3" >199.154146</td>
#       <td id="T_b3132_row4_col4" class="data row4 col4" >0.940772</td>
#       <td id="T_b3132_row4_col5" class="data row4 col5" >0.056120</td>
#       <td id="T_b3132_row4_col6" class="data row4 col6" >0.059653</td>
#     </tr>
#     <tr>
#       <th id="T_b3132_level0_row5" class="row_heading level0 row5" >60302</th>
#       <td id="T_b3132_row5_col0" class="data row5 col0" >2.333300</td>
#       <td id="T_b3132_row5_col1" class="data row5 col1" >1.680000</td>
#       <td id="T_b3132_row5_col2" class="data row5 col2" >254.071433</td>
#       <td id="T_b3132_row5_col3" class="data row5 col3" >254.001713</td>
#       <td id="T_b3132_row5_col4" class="data row5 col4" >0.999946</td>
#       <td id="T_b3132_row5_col5" class="data row5 col5" >0.050299</td>
#       <td id="T_b3132_row5_col6" class="data row5 col6" >0.050302</td>
#     </tr>
#     <tr>
#       <th id="T_b3132_level0_row6" class="row_heading level0 row6" >13172</th>
#       <td id="T_b3132_row6_col0" class="data row6 col0" >1.286700</td>
#       <td id="T_b3132_row6_col1" class="data row6 col1" >2.526700</td>
#       <td id="T_b3132_row6_col2" class="data row6 col2" >228.671032</td>
#       <td id="T_b3132_row6_col3" class="data row6 col3" >228.670771</td>
#       <td id="T_b3132_row6_col4" class="data row6 col4" >0.968297</td>
#       <td id="T_b3132_row6_col5" class="data row6 col5" >0.060927</td>
#       <td id="T_b3132_row6_col6" class="data row6 col6" >0.062921</td>
#     </tr>
#     <tr>
#       <th id="T_b3132_level0_row7" class="row_heading level0 row7" >70196</th>
#       <td id="T_b3132_row7_col0" class="data row7 col0" >2.553300</td>
#       <td id="T_b3132_row7_col1" class="data row7 col1" >1.420000</td>
#       <td id="T_b3132_row7_col2" class="data row7 col2" >370.367234</td>
#       <td id="T_b3132_row7_col3" class="data row7 col3" >370.492331</td>
#       <td id="T_b3132_row7_col4" class="data row7 col4" >0.997560</td>
#       <td id="T_b3132_row7_col5" class="data row7 col5" >0.057230</td>
#       <td id="T_b3132_row7_col6" class="data row7 col6" >0.057370</td>
#     </tr>
#     <tr>
#       <th id="T_b3132_level0_row8" class="row_heading level0 row8" >43970</th>
#       <td id="T_b3132_row8_col0" class="data row8 col0" >1.973300</td>
#       <td id="T_b3132_row8_col1" class="data row8 col1" >1.160000</td>
#       <td id
