# %% [markdown]
# # Steps
#
# 1. Build a `RunOptions` generator with the parameters of interest, namely $dim_S, J_S, \delta_S, U_S, dim_A, J_A, \delta_A, U_A, \alpha_{xx}, \alpha_{xz}, \alpha_{zx}, \alpha_{zz}, t$. We need a decent range for $\delta_S$ for the Bayesian update side of things. We assume a uniform prior on the cartesian product.
# 2. Calculate the probabilities for the $J_z$ measurement for each value. This is a `dict`, as $J_z$ can have multiple outcomes.
# 3. Use the probabilities to build the expected likelihood function over all inputs, for a given range of $N_{trials}$. This also requires a "True" set of values for each parameter.
# 4. Use the likelihood to build the marginal distribution for all variables.
# 5. Save the std variation for each estimated variable!
# 6. Plot $\Delta$ agains the $N_{trials}$, keeping the parameters of the plot saved

# %%
from dataclasses import dataclass, field
from src.angular_momentum import generate_spin_matrices
from tqdm import tqdm
import functools
import itertools
import numpy as np
import pandas as pd
import scipy

# Create new `pandas` methods which use `tqdm` progress
# (can use tqdm_gui, optional kwargs, etc.)
tqdm.pandas()

# %%
@dataclass
class Settings:
    dim_s: int
    dim_a: int
    probability_error_tolerance: float
    system_jx: np.array = field(init=False)
    system_jz: np.array = field(init=False)
    ancilla_jx: np.array = field(init=False)
    ancilla_jz: np.array = field(init=False)
    initial_state: np.array = field(init=False)

    def __post_init__(self):
        self.system_jx, self.system_jz = generate_spin_matrices(dim=self.dim_s)
        self.ancilla_jx, self.ancilla_jz = generate_spin_matrices(dim=self.dim_a)
        self.initial_state = np.zeros(self.dim_s * self.dim_a)
        self.initial_state[0] = 1
        self.initial_state = np.outer(self.initial_state, self.initial_state)

    def generate_hamiltonian(
        self,
        j_s: float,
        u_s: float,
        delta_s: float,
        j_a: float,
        u_a: float,
        delta_a: float,
        alpha_xx: float,
        alpha_xz: float,
        alpha_zx: float,
        alpha_zz: float,
    ) -> np.array:
        system_hamiltonian = np.kron(
            -1 * j_s * self.system_jx + u_s * self.system_jz @ self.system_jz + delta_s * self.system_jz,
            np.divide(np.eye(self.dim_a), self.dim_a)
        )
        ancillary_hamiltonian = np.kron(
            np.divide(np.eye(self.dim_s), self.dim_s),
            -1 * j_a * self.ancilla_jx + u_a * self.ancilla_jz @ self.ancilla_jz + delta_a * self.ancilla_jz
        )
        interaction_hamiltonian = functools.reduce(
            lambda x, y: x + y,
            [
                alpha_xx * np.kron(self.system_jx, self.ancilla_jx),
                alpha_xz * np.kron(self.system_jx, self.ancilla_jz),
                alpha_zx * np.kron(self.system_jz, self.ancilla_jx),
                alpha_zz * np.kron(self.system_jz, self.ancilla_jz),
            ]
        )
        return system_hamiltonian + ancillary_hamiltonian + interaction_hamiltonian

    def trace_out_ancillary(self, state: np.array):
        return np.trace(
            np.array(state).reshape(self.dim_s, self.dim_a, self.dim_s, self.dim_a),
            axis1=1,
            axis2=3
        )

    @staticmethod
    def calculate_final_state(
        hamiltonian: np.array,
        initial_state: np.ndarray,
        t: float = 0,
    ) -> np.array:
        return scipy.linalg.expm(-1j * t * hamiltonian) @ initial_state @ scipy.linalg.expm(1j * t * hamiltonian)

    def calculate_probabilities(self, final_state: np.array) -> np.array:
        system_state = self.trace_out_ancillary(state=final_state)
        probabilities = [np.abs(x)**2 for x in np.diag(system_state)] # TODO: Ensure these actually up to 1!!!
        # assert np.abs(np.sum(probabilities) - 1) < settings.probability_error_tolerance, f"⚠ The observed probabilities {probabilities} are unphysical by {np.abs(np.sum(probabilities) - 1):.5f}%"
        return probabilities

# %% [markdown]
# # Initial state $\ket{0} \otimes \ket{0}$

# %%
settings = Settings(
    dim_s= 2,
    dim_a= 1,
    probability_error_tolerance= .001,
)

# %%
pd.DataFrame(settings.initial_state).style.background_gradient(cmap='viridis')
# Out:
# <style type="text/css">
# #T_f9439_row0_col0 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_f9439_row0_col1, #T_f9439_row1_col0, #T_f9439_row1_col1 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f9439">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9439_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_f9439_level0_col1" class="col_heading level0 col1" >1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9439_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f9439_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_f9439_row0_col1" class="data row0 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f9439_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f9439_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_f9439_row1_col1" class="data row1 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Create generator object

# %%
true_values = {
    "j_s": .2,
    "u_s": .1,
    "delta_s": 1.2,
    "j_a": .3,
    "u_a": .1,
    "delta_a": 1,
    "alpha_xx": 0,
    "alpha_xz": 0,
    "alpha_zx": 0,
    "alpha_zz": 0,
    "time": 5,
}
df = pd.DataFrame([
    {
        "j_s": j_s,
        "u_s": u_s,
        "delta_s": delta_s,
        "j_a": j_a,
        "u_a": u_a,
        "delta_a": delta_a,
        "alpha_xx": alpha_xx,
        "alpha_xz": alpha_xz,
        "alpha_zx": alpha_zx,
        "alpha_zz": alpha_zz,
        "time": time
    }
    for j_s, u_s, delta_s, j_a, u_a, delta_a, alpha_xx, alpha_xz, alpha_zx, alpha_zz, time
    in itertools.product(
        np.linspace(.099, .101, 3), # j_s: float,
        np.linspace(.099, .101, 3), # u_s: float,
        np.linspace(1,2,101), # delta_s: float,
        [0], # j_a: float,
        [0], # u_a: float,
        [1], # delta_a: float,
        [0], # alpha_xx: float,
        [0], # alpha_xz: float,
        [0], # alpha_zx: float,
        [0], # alpha_zz: float,
        [3,5,10], # time: float
    )],
)
df.sample(10).style.background_gradient(cmap='viridis', axis=0)
# Out:
# <style type="text/css">
# #T_ddb0b_row0_col0, #T_ddb0b_row1_col0, #T_ddb0b_row2_col1, #T_ddb0b_row3_col0, #T_ddb0b_row8_col1, #T_ddb0b_row9_col0 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_ddb0b_row0_col1, #T_ddb0b_row0_col3, #T_ddb0b_row0_col4, #T_ddb0b_row0_col5, #T_ddb0b_row0_col6, #T_ddb0b_row0_col7, #T_ddb0b_row0_col8, #T_ddb0b_row0_col9, #T_ddb0b_row0_col10, #T_ddb0b_row1_col3, #T_ddb0b_row1_col4, #T_ddb0b_row1_col5, #T_ddb0b_row1_col6, #T_ddb0b_row1_col7, #T_ddb0b_row1_col8, #T_ddb0b_row1_col9, #T_ddb0b_row2_col0, #T_ddb0b_row2_col3, #T_ddb0b_row2_col4, #T_ddb0b_row2_col5, #T_ddb0b_row2_col6, #T_ddb0b_row2_col7, #T_ddb0b_row2_col8, #T_ddb0b_row2_col9, #T_ddb0b_row3_col3, #T_ddb0b_row3_col4, #T_ddb0b_row3_col5, #T_ddb0b_row3_col6, #T_ddb0b_row3_col7, #T_ddb0b_row3_col8, #T_ddb0b_row3_col9, #T_ddb0b_row3_col10, #T_ddb0b_row4_col1, #T_ddb0b_row4_col3, #T_ddb0b_row4_col4, #T_ddb0b_row4_col5, #T_ddb0b_row4_col6, #T_ddb0b_row4_col7, #T_ddb0b_row4_col8, #T_ddb0b_row4_col9, #T_ddb0b_row5_col1, #T_ddb0b_row5_col3, #T_ddb0b_row5_col4, #T_ddb0b_row5_col5, #T_ddb0b_row5_col6, #T_ddb0b_row5_col7, #T_ddb0b_row5_col8, #T_ddb0b_row5_col9, #T_ddb0b_row6_col3, #T_ddb0b_row6_col4, #T_ddb0b_row6_col5, #T_ddb0b_row6_col6, #T_ddb0b_row6_col7, #T_ddb0b_row6_col8, #T_ddb0b_row6_col9, #T_ddb0b_row7_col0, #T_ddb0b_row7_col3, #T_ddb0b_row7_col4, #T_ddb0b_row7_col5, #T_ddb0b_row7_col6, #T_ddb0b_row7_col7, #T_ddb0b_row7_col8, #T_ddb0b_row7_col9, #T_ddb0b_row8_col3, #T_ddb0b_row8_col4, #T_ddb0b_row8_col5, #T_ddb0b_row8_col6, #T_ddb0b_row8_col7, #T_ddb0b_row8_col8, #T_ddb0b_row8_col9, #T_ddb0b_row9_col1, #T_ddb0b_row9_col2, #T_ddb0b_row9_col3, #T_ddb0b_row9_col4, #T_ddb0b_row9_col5, #T_ddb0b_row9_col6, #T_ddb0b_row9_col7, #T_ddb0b_row9_col8, #T_ddb0b_row9_col9, #T_ddb0b_row9_col10 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_ddb0b_row0_col2 {
#   background-color: #355f8d;
#   color: #f1f1f1;
# }
# #T_ddb0b_row1_col1, #T_ddb0b_row1_col2, #T_ddb0b_row1_col10, #T_ddb0b_row3_col1, #T_ddb0b_row4_col0, #T_ddb0b_row5_col0, #T_ddb0b_row5_col10, #T_ddb0b_row6_col0, #T_ddb0b_row6_col1, #T_ddb0b_row6_col10, #T_ddb0b_row7_col1, #T_ddb0b_row8_col0, #T_ddb0b_row8_col10 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_ddb0b_row2_col2 {
#   background-color: #3c4f8a;
#   color: #f1f1f1;
# }
# #T_ddb0b_row2_col10, #T_ddb0b_row4_col10, #T_ddb0b_row7_col10 {
#   background-color: #365c8d;
#   color: #f1f1f1;
# }
# #T_ddb0b_row3_col2 {
#   background-color: #277e8e;
#   color: #f1f1f1;
# }
# #T_ddb0b_row4_col2 {
#   background-color: #32658e;
#   color: #f1f1f1;
# }
# #T_ddb0b_row5_col2 {
#   background-color: #470d60;
#   color: #f1f1f1;
# }
# #T_ddb0b_row6_col2 {
#   background-color: #bade28;
#   color: #000000;
# }
# #T_ddb0b_row7_col2 {
#   background-color: #84d44b;
#   color: #000000;
# }
# #T_ddb0b_row8_col2 {
#   background-color: #26818e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ddb0b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ddb0b_level0_col0" class="col_heading level0 col0" >j_s</th>
#       <th id="T_ddb0b_level0_col1" class="col_heading level0 col1" >u_s</th>
#       <th id="T_ddb0b_level0_col2" class="col_heading level0 col2" >delta_s</th>
#       <th id="T_ddb0b_level0_col3" class="col_heading level0 col3" >j_a</th>
#       <th id="T_ddb0b_level0_col4" class="col_heading level0 col4" >u_a</th>
#       <th id="T_ddb0b_level0_col5" class="col_heading level0 col5" >delta_a</th>
#       <th id="T_ddb0b_level0_col6" class="col_heading level0 col6" >alpha_xx</th>
#       <th id="T_ddb0b_level0_col7" class="col_heading level0 col7" >alpha_xz</th>
#       <th id="T_ddb0b_level0_col8" class="col_heading level0 col8" >alpha_zx</th>
#       <th id="T_ddb0b_level0_col9" class="col_heading level0 col9" >alpha_zz</th>
#       <th id="T_ddb0b_level0_col10" class="col_heading level0 col10" >time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ddb0b_level0_row0" class="row_heading level0 row0" >1011</th>
#       <td id="T_ddb0b_row0_col0" class="data row0 col0" >0.100000</td>
#       <td id="T_ddb0b_row0_col1" class="data row0 col1" >0.099000</td>
#       <td id="T_ddb0b_row0_col2" class="data row0 col2" >1.340000</td>
#       <td id="T_ddb0b_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_ddb0b_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_ddb0b_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_ddb0b_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_ddb0b_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_ddb0b_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_ddb0b_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_ddb0b_row0_col10" class="data row0 col10" >3</td>
#     </tr>
#     <tr>
#       <th id="T_ddb0b_level0_row1" class="row_heading level0 row1" >1802</th>
#       <td id="T_ddb0b_row1_col0" class="data row1 col0" >0.100000</td>
#       <td id="T_ddb0b_row1_col1" class="data row1 col1" >0.101000</td>
#       <td id="T_ddb0b_row1_col2" class="data row1 col2" >1.950000</td>
#       <td id="T_ddb0b_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_ddb0b_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_ddb0b_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_ddb0b_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_ddb0b_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_ddb0b_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_ddb0b_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_ddb0b_row1_col10" class="data row1 col10" >10</td>
#     </tr>
#     <tr>
#       <th id="T_ddb0b_level0_row2" class="row_heading level0 row2" >391</th>
#       <td id="T_ddb0b_row2_col0" class="data row2 col0" >0.099000</td>
#       <td id="T_ddb0b_row2_col1" class="data row2 col1" >0.100000</td>
#       <td id="T_ddb0b_row2_col2" class="data row2 col2" >1.290000</td>
#       <td id="T_ddb0b_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_ddb0b_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_ddb0b_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_ddb0b_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_ddb0b_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_ddb0b_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_ddb0b_row2_col9" class="data row2 col9" >0</td>
#       <td id="T_ddb0b_row2_col10" class="data row2 col10" >5</td>
#     </tr>
#     <tr>
#       <th id="T_ddb0b_level0_row3" class="row_heading level0 row3" >1650</th>
#       <td id="T_ddb0b_row3_col0" class="data row3 col0" >0.100000</td>
#       <td id="T_ddb0b_row3_col1" class="data row3 col1" >0.101000</td>
#       <td id="T_ddb0b_row3_col2" class="data row3 col2" >1.450000</td>
#       <td id="T_ddb0b_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_ddb0b_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_ddb0b_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_ddb0b_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_ddb0b_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_ddb0b_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_ddb0b_row3_col9" class="data row3 col9" >0</td>
#       <td id="T_ddb0b_row3_col10" class="data row3 col10" >3</td>
#     </tr>
#     <tr>
#       <th id="T_ddb0b_level0_row4" class="row_heading level0 row4" >1927</th>
#       <td id="T_ddb0b_row4_col0" class="data row4 col0" >0.101000</td>
#       <td id="T_ddb0b_row4_col1" class="data row4 col1" >0.099000</td>
#       <td id="T_ddb0b_row4_col2" class="data row4 col2" >1.360000</td>
#       <td id="T_ddb0b_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_ddb0b_row4_col4" class="data row4 col4" >0</td>
#       <td id="T_ddb0b_row4_col5" class="data row4 col5" >1</td>
#       <td id="T_ddb0b_row4_col6" class="data row4 col6" >0</td>
#       <td id="T_ddb0b_row4_col7" class="data row4 col7" >0</td>
#       <td id="T_ddb0b_row4_col8" class="data row4 col8" >0</td>
#       <td id="T_ddb0b_row4_col9" class="data row4 col9" >0</td>
#       <td id="T_ddb0b_row4_col10" class="data row4 col10" >5</td>
#     </tr>
#     <tr>
#       <th id="T_ddb0b_level0_row5"

# %% [markdown]
# # Calculate measurement probabilities

# %%
def calculate_final_probabilities(row: pd.Series) -> np.array:
    hamiltonian = settings.generate_hamiltonian(
        j_s = row["j_s"],
        u_s = row["u_s"],
        delta_s = row["delta_s"],
        j_a = row["j_a"],
        u_a = row["u_a"],
        delta_a = row["delta_a"],
        alpha_xx = row["alpha_xx"],
        alpha_xz = row["alpha_xz"],
        alpha_zx = row["alpha_zx"],
        alpha_zz = row["alpha_zz"]
    )
    final_state = settings.calculate_final_state(
        hamiltonian = hamiltonian,
        initial_state = settings.initial_state,
        t = row["time"],
    )
    # return final_state
    final_probabilities = settings.calculate_probabilities(final_state)
    return final_probabilities
    # return np.divide(final_probabilities, np.sum(final_probabilities))

df["probabilities"] = df.progress_apply(calculate_final_probabilities, axis=1) # These are the measurement probabilities, i.e. Prob[J_z=k] for k in range(0, dim_s)
df["final_state_error"] = df.progress_apply(lambda row: np.abs(np.sum(row["probabilities"]) - 1), axis=1)

df.sample(30).style.background_gradient(cmap='viridis', axis=0)
# Out:
# 100%|██████████| 2727/2727 [00:01<00:00, 1452.30it/s]
# 100%|██████████| 2727/2727 [00:00<00:00, 64828.02it/s]
# <style type="text/css">
# #T_018cf_row0_col0, #T_018cf_row3_col0, #T_018cf_row4_col0, #T_018cf_row4_col1, #T_018cf_row6_col0, #T_018cf_row6_col1, #T_018cf_row8_col0, #T_018cf_row9_col0, #T_018cf_row10_col1, #T_018cf_row13_col1, #T_018cf_row14_col0, #T_018cf_row16_col0, #T_018cf_row17_col1, #T_018cf_row18_col1, #T_018cf_row19_col0, #T_018cf_row19_col1, #T_018cf_row20_col0, #T_018cf_row21_col0, #T_018cf_row25_col0, #T_018cf_row26_col0, #T_018cf_row28_col1 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_018cf_row0_col1, #T_018cf_row0_col3, #T_018cf_row0_col4, #T_018cf_row0_col5, #T_018cf_row0_col6, #T_018cf_row0_col7, #T_018cf_row0_col8, #T_018cf_row0_col9, #T_018cf_row1_col0, #T_018cf_row1_col3, #T_018cf_row1_col4, #T_018cf_row1_col5, #T_018cf_row1_col6, #T_018cf_row1_col7, #T_018cf_row1_col8, #T_018cf_row1_col9, #T_018cf_row1_col10, #T_018cf_row2_col1, #T_018cf_row2_col3, #T_018cf_row2_col4, #T_018cf_row2_col5, #T_018cf_row2_col6, #T_018cf_row2_col7, #T_018cf_row2_col8, #T_018cf_row2_col9, #T_018cf_row2_col10, #T_018cf_row3_col3, #T_018cf_row3_col4, #T_018cf_row3_col5, #T_018cf_row3_col6, #T_018cf_row3_col7, #T_018cf_row3_col8, #T_018cf_row3_col9, #T_018cf_row4_col3, #T_018cf_row4_col4, #T_018cf_row4_col5, #T_018cf_row4_col6, #T_018cf_row4_col7, #T_018cf_row4_col8, #T_018cf_row4_col9, #T_018cf_row4_col10, #T_018cf_row5_col0, #T_018cf_row5_col1, #T_018cf_row5_col3, #T_018cf_row5_col4, #T_018cf_row5_col5, #T_018cf_row5_col6, #T_018cf_row5_col7, #T_018cf_row5_col8, #T_018cf_row5_col9, #T_018cf_row6_col3, #T_018cf_row6_col4, #T_018cf_row6_col5, #T_018cf_row6_col6, #T_018cf_row6_col7, #T_018cf_row6_col8, #T_018cf_row6_col9, #T_018cf_row7_col0, #T_018cf_row7_col3, #T_018cf_row7_col4, #T_018cf_row7_col5, #T_018cf_row7_col6, #T_018cf_row7_col7, #T_018cf_row7_col8, #T_018cf_row7_col9, #T_018cf_row8_col3, #T_018cf_row8_col4, #T_018cf_row8_col5, #T_018cf_row8_col6, #T_018cf_row8_col7, #T_018cf_row8_col8, #T_018cf_row8_col9, #T_018cf_row9_col1, #T_018cf_row9_col3, #T_018cf_row9_col4, #T_018cf_row9_col5, #T_018cf_row9_col6, #T_018cf_row9_col7, #T_018cf_row9_col8, #T_018cf_row9_col9, #T_018cf_row10_col0, #T_018cf_row10_col3, #T_018cf_row10_col4, #T_018cf_row10_col5, #T_018cf_row10_col6, #T_018cf_row10_col7, #T_018cf_row10_col8, #T_018cf_row10_col9, #T_018cf_row11_col0, #T_018cf_row11_col3, #T_018cf_row11_col4, #T_018cf_row11_col5, #T_018cf_row11_col6, #T_018cf_row11_col7, #T_018cf_row11_col8, #T_018cf_row11_col9, #T_018cf_row12_col3, #T_018cf_row12_col4, #T_018cf_row12_col5, #T_018cf_row12_col6, #T_018cf_row12_col7, #T_018cf_row12_col8, #T_018cf_row12_col9, #T_018cf_row13_col3, #T_018cf_row13_col4, #T_018cf_row13_col5, #T_018cf_row13_col6, #T_018cf_row13_col7, #T_018cf_row13_col8, #T_018cf_row13_col9, #T_018cf_row14_col1, #T_018cf_row14_col3, #T_018cf_row14_col4, #T_018cf_row14_col5, #T_018cf_row14_col6, #T_018cf_row14_col7, #T_018cf_row14_col8, #T_018cf_row14_col9, #T_018cf_row15_col0, #T_018cf_row15_col1, #T_018cf_row15_col3, #T_018cf_row15_col4, #T_018cf_row15_col5, #T_018cf_row15_col6, #T_018cf_row15_col7, #T_018cf_row15_col8, #T_018cf_row15_col9, #T_018cf_row16_col1, #T_018cf_row16_col3, #T_018cf_row16_col4, #T_018cf_row16_col5, #T_018cf_row16_col6, #T_018cf_row16_col7, #T_018cf_row16_col8, #T_018cf_row16_col9, #T_018cf_row16_col10, #T_018cf_row17_col0, #T_018cf_row17_col3, #T_018cf_row17_col4, #T_018cf_row17_col5, #T_018cf_row17_col6, #T_018cf_row17_col7, #T_018cf_row17_col8, #T_018cf_row17_col9, #T_018cf_row17_col10, #T_018cf_row18_col0, #T_018cf_row18_col3, #T_018cf_row18_col4, #T_018cf_row18_col5, #T_018cf_row18_col6, #T_018cf_row18_col7, #T_018cf_row18_col8, #T_018cf_row18_col9, #T_018cf_row18_col10, #T_018cf_row19_col3, #T_018cf_row19_col4, #T_018cf_row19_col5, #T_018cf_row19_col6, #T_018cf_row19_col7, #T_018cf_row19_col8, #T_018cf_row19_col9, #T_018cf_row19_col10, #T_018cf_row20_col3, #T_018cf_row20_col4, #T_018cf_row20_col5, #T_018cf_row20_col6, #T_018cf_row20_col7, #T_018cf_row20_col8, #T_018cf_row20_col9, #T_018cf_row21_col1, #T_018cf_row21_col3, #T_018cf_row21_col4, #T_018cf_row21_col5, #T_018cf_row21_col6, #T_018cf_row21_col7, #T_018cf_row21_col8, #T_018cf_row21_col9, #T_018cf_row21_col10, #T_018cf_row22_col3, #T_018cf_row22_col4, #T_018cf_row22_col5, #T_018cf_row22_col6, #T_018cf_row22_col7, #T_018cf_row22_col8, #T_018cf_row22_col9, #T_018cf_row23_col0, #T_018cf_row23_col1, #T_018cf_row23_col2, #T_018cf_row23_col3, #T_018cf_row23_col4, #T_018cf_row23_col5, #T_018cf_row23_col6, #T_018cf_row23_col7, #T_018cf_row23_col8 ...
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_018cf_row0_col2 {
#   background-color: #2e6f8e;
#   color: #f1f1f1;
# }
# #T_018cf_row0_col10, #T_018cf_row3_col10, #T_018cf_row5_col10, #T_018cf_row6_col10, #T_018cf_row9_col10, #T_018cf_row10_col10, #T_018cf_row10_col12, #T_018cf_row11_col10, #T_018cf_row12_col10, #T_018cf_row13_col10, #T_018cf_row20_col10, #T_018cf_row22_col10, #T_018cf_row25_col10, #T_018cf_row27_col10, #T_018cf_row29_col10 {
#   background-color: #365c8d;
#   color: #f1f1f1;
# }
# #T_018cf_row0_col12 {
#   background-color: #471063;
#   color: #f1f1f1;
# }
# #T_018cf_row1_col1, #T_018cf_row2_col0, #T_018cf_row3_col1, #T_018cf_row7_col1, #T_018cf_row7_col10, #T_018cf_row8_col1, #T_018cf_row8_col10, #T_018cf_row11_col1, #T_018cf_row12_col0, #T_018cf_row12_col1, #T_018cf_row13_col0, #T_018cf_row14_col10, #T_018cf_row15_col10, #T_018cf_row16_col12, #T_018cf_row20_col1, #T_018cf_row22_col0, #T_018cf_row22_col1, #T_018cf_row23_col10, #T_018cf_row24_col0, #T_018cf_row24_col1, #T_018cf_row24_col10, #T_018cf_row25_col1, #T_018cf_row27_col1, #T_018cf_row28_col0, #T_018cf_row28_col2, #T_018cf_row28_col10, #T_018cf_row29_col0, #T_018cf_row29_col1 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_018cf_row1_col2 {
#   background-color: #481769;
#   color: #f1f1f1;
# }
# #T_018cf_row1_col12 {
#   background-color: #e7e419;
#   color: #000000;
# }
# #T_018cf_row2_col2 {
#   background-color: #482878;
#   color: #f1f1f1;
# }
# #T_018cf_row2_col12 {
#   background-color: #c0df25;
#   color: #000000;
# }
# #T_018cf_row3_col2 {
#   background-color: #3fbc73;
#   color: #f1f1f1;
# }
# #T_018cf_row3_col12, #T_018cf_row25_col12 {
#   background-color: #34618d;
#   color: #f1f1f1;
# }
# #T_018cf_row4_col2 {
#   background-color: #297a8e;
#   color: #f1f1f1;
# }
# #T_018cf_row4_col12 {
#   background-color: #29798e;
#   color: #f1f1f1;
# }
# #T_018cf_row5_col2, #T_018cf_row25_col2 {
#   background-color: #bddf26;
#   color: #000000;
# }
# #T_018cf_row5_col12, #T_018cf_row22_col12 {
#   background-color: #355f8d;
#   color: #f1f1f1;
# }
# #T_018cf_row6_col2, #T_018cf_row16_col2, #T_018cf_row24_col12 {
#   background-color: #471365;
#   color: #f1f1f1;
# }
# #T_018cf_row6_col12 {
#   background-color: #3d4d8a;
#   color: #f1f1f1;
# }
# #T_018cf_row7_col2 {
#   background-color: #dfe318;
#   color: #000000;
# }
# #T_018cf_row7_col12 {
#   background-color: #460b5e;
#   color: #f1f1f1;
# }
# #T_018cf_row8_col2 {
#   background-color: #63cb5f;
#   color: #000000;
# }
# #T_018cf_row8_col12 {
#   background-color: #482979;
#   color: #f1f1f1;
# }
# #T_018cf_row9_col2 {
#   background-color: #46085c;
#   color: #f

# %% [markdown]
# # Calculate likelihoods

# %%
true_likelihoods = calculate_final_probabilities(true_values)
true_likelihoods /= np.prod(true_likelihoods)
true_likelihoods
# Out:
# array([1.36660704e+07, 1.00054123e+00])

# %%
df = df.merge(
    pd.DataFrame([{"n_trials": 2**x} for x in range(16)]),
    how='cross'
)
df.astype({'n_trials': 'int32'}, copy=False)
df.shape
# Out:
# (43632, 14)

# %%
np.power(np.subtract(np.linspace(1,3,11),1), np.linspace(0,2,11))
# Out:
# array([1.        , 0.72477966, 0.69314484, 0.73602192, 0.83651164,
#        1.        , 1.24456475, 1.6016929 , 2.12125057, 2.8806501 ,
#        4.        ])

# %%
np.array([1,2]) * np.array([3,4])
# Out:
# array([3, 8])

# %%
def calculate_log_likelihood(true_probabilities: np.array, expected_probabilities: np.array, n_trials: float) -> float:
    true_probabilities = np.array(true_probabilities)
    expected_probabilities = np.array(expected_probabilities)
    return np.sum([
        scipy.special.loggamma(n_trials * np.sum(expected_probabilities)),
        np.sum((n_trials * expected_probabilities - 1)*np.log(true_probabilities)),
        np.sum(scipy.special.loggamma(n_trials * expected_probabilities)),
    ])

df["log_likelihood"] = df.progress_apply(lambda row: calculate_log_likelihood(
    true_probabilities=true_likelihoods,
    expected_probabilities=row["probabilities"],
    n_trials=row["n_trials"]
), axis=1)
df["log_likelihood"] -= np.max(df["log_likelihood"])
# Out:
# 100%|██████████| 43632/43632 [00:01<00:00, 25793.61it/s]

# %%
# df.sample(30).style.background_gradient(cmap='viridis', axis=0)
df.sort_values("log_likelihood", ascending=False).head(30).style.background_gradient(cmap='viridis', axis=0)
# Out:
# <style type="text/css">
# #T_0f4e9_row0_col0, #T_0f4e9_row0_col14, #T_0f4e9_row1_col0, #T_0f4e9_row1_col14, #T_0f4e9_row2_col0, #T_0f4e9_row2_col1, #T_0f4e9_row2_col14, #T_0f4e9_row5_col1, #T_0f4e9_row8_col1, #T_0f4e9_row9_col0, #T_0f4e9_row9_col2, #T_0f4e9_row9_col10, #T_0f4e9_row10_col0, #T_0f4e9_row10_col1, #T_0f4e9_row10_col2, #T_0f4e9_row10_col10, #T_0f4e9_row11_col0, #T_0f4e9_row11_col2, #T_0f4e9_row11_col10, #T_0f4e9_row12_col2, #T_0f4e9_row12_col10, #T_0f4e9_row13_col2, #T_0f4e9_row13_col10, #T_0f4e9_row14_col1, #T_0f4e9_row14_col2, #T_0f4e9_row14_col10, #T_0f4e9_row15_col2, #T_0f4e9_row15_col10, #T_0f4e9_row16_col1, #T_0f4e9_row16_col2, #T_0f4e9_row16_col10, #T_0f4e9_row17_col2, #T_0f4e9_row17_col10, #T_0f4e9_row18_col0, #T_0f4e9_row18_col10, #T_0f4e9_row19_col0, #T_0f4e9_row19_col10, #T_0f4e9_row20_col0, #T_0f4e9_row20_col1, #T_0f4e9_row20_col10, #T_0f4e9_row21_col10, #T_0f4e9_row22_col10, #T_0f4e9_row23_col1, #T_0f4e9_row23_col10, #T_0f4e9_row24_col10, #T_0f4e9_row25_col10, #T_0f4e9_row26_col1, #T_0f4e9_row26_col10, #T_0f4e9_row27_col12, #T_0f4e9_row28_col1, #T_0f4e9_row28_col12, #T_0f4e9_row29_col12 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_0f4e9_row0_col1, #T_0f4e9_row0_col2, #T_0f4e9_row0_col3, #T_0f4e9_row0_col4, #T_0f4e9_row0_col5, #T_0f4e9_row0_col6, #T_0f4e9_row0_col7, #T_0f4e9_row0_col8, #T_0f4e9_row0_col9, #T_0f4e9_row0_col10, #T_0f4e9_row0_col12, #T_0f4e9_row0_col13, #T_0f4e9_row1_col2, #T_0f4e9_row1_col3, #T_0f4e9_row1_col4, #T_0f4e9_row1_col5, #T_0f4e9_row1_col6, #T_0f4e9_row1_col7, #T_0f4e9_row1_col8, #T_0f4e9_row1_col9, #T_0f4e9_row1_col10, #T_0f4e9_row1_col12, #T_0f4e9_row1_col13, #T_0f4e9_row2_col2, #T_0f4e9_row2_col3, #T_0f4e9_row2_col4, #T_0f4e9_row2_col5, #T_0f4e9_row2_col6, #T_0f4e9_row2_col7, #T_0f4e9_row2_col8, #T_0f4e9_row2_col9, #T_0f4e9_row2_col10, #T_0f4e9_row2_col12, #T_0f4e9_row2_col13, #T_0f4e9_row3_col2, #T_0f4e9_row3_col3, #T_0f4e9_row3_col4, #T_0f4e9_row3_col5, #T_0f4e9_row3_col6, #T_0f4e9_row3_col7, #T_0f4e9_row3_col8, #T_0f4e9_row3_col9, #T_0f4e9_row3_col10, #T_0f4e9_row3_col13, #T_0f4e9_row4_col1, #T_0f4e9_row4_col2, #T_0f4e9_row4_col3, #T_0f4e9_row4_col4, #T_0f4e9_row4_col5, #T_0f4e9_row4_col6, #T_0f4e9_row4_col7, #T_0f4e9_row4_col8, #T_0f4e9_row4_col9, #T_0f4e9_row4_col10, #T_0f4e9_row4_col13, #T_0f4e9_row5_col2, #T_0f4e9_row5_col3, #T_0f4e9_row5_col4, #T_0f4e9_row5_col5, #T_0f4e9_row5_col6, #T_0f4e9_row5_col7, #T_0f4e9_row5_col8, #T_0f4e9_row5_col9, #T_0f4e9_row5_col10, #T_0f4e9_row5_col13, #T_0f4e9_row6_col0, #T_0f4e9_row6_col2, #T_0f4e9_row6_col3, #T_0f4e9_row6_col4, #T_0f4e9_row6_col5, #T_0f4e9_row6_col6, #T_0f4e9_row6_col7, #T_0f4e9_row6_col8, #T_0f4e9_row6_col9, #T_0f4e9_row6_col10, #T_0f4e9_row6_col13, #T_0f4e9_row7_col0, #T_0f4e9_row7_col1, #T_0f4e9_row7_col2, #T_0f4e9_row7_col3, #T_0f4e9_row7_col4, #T_0f4e9_row7_col5, #T_0f4e9_row7_col6, #T_0f4e9_row7_col7, #T_0f4e9_row7_col8, #T_0f4e9_row7_col9, #T_0f4e9_row7_col10, #T_0f4e9_row7_col13, #T_0f4e9_row8_col0, #T_0f4e9_row8_col2, #T_0f4e9_row8_col3, #T_0f4e9_row8_col4, #T_0f4e9_row8_col5, #T_0f4e9_row8_col6, #T_0f4e9_row8_col7, #T_0f4e9_row8_col8, #T_0f4e9_row8_col9, #T_0f4e9_row8_col10, #T_0f4e9_row8_col13, #T_0f4e9_row9_col3, #T_0f4e9_row9_col4, #T_0f4e9_row9_col5, #T_0f4e9_row9_col6, #T_0f4e9_row9_col7, #T_0f4e9_row9_col8, #T_0f4e9_row9_col9, #T_0f4e9_row9_col13, #T_0f4e9_row10_col3, #T_0f4e9_row10_col4, #T_0f4e9_row10_col5, #T_0f4e9_row10_col6, #T_0f4e9_row10_col7, #T_0f4e9_row10_col8, #T_0f4e9_row10_col9, #T_0f4e9_row10_col13, #T_0f4e9_row11_col1, #T_0f4e9_row11_col3, #T_0f4e9_row11_col4, #T_0f4e9_row11_col5, #T_0f4e9_row11_col6, #T_0f4e9_row11_col7, #T_0f4e9_row11_col8, #T_0f4e9_row11_col9, #T_0f4e9_row11_col13, #T_0f4e9_row12_col3, #T_0f4e9_row12_col4, #T_0f4e9_row12_col5, #T_0f4e9_row12_col6, #T_0f4e9_row12_col7, #T_0f4e9_row12_col8, #T_0f4e9_row12_col9, #T_0f4e9_row12_col13, #T_0f4e9_row13_col1, #T_0f4e9_row13_col3, #T_0f4e9_row13_col4, #T_0f4e9_row13_col5, #T_0f4e9_row13_col6, #T_0f4e9_row13_col7, #T_0f4e9_row13_col8, #T_0f4e9_row13_col9, #T_0f4e9_row13_col13, #T_0f4e9_row14_col3, #T_0f4e9_row14_col4, #T_0f4e9_row14_col5, #T_0f4e9_row14_col6, #T_0f4e9_row14_col7, #T_0f4e9_row14_col8, #T_0f4e9_row14_col9, #T_0f4e9_row14_col13, #T_0f4e9_row15_col0, #T_0f4e9_row15_col1, #T_0f4e9_row15_col3, #T_0f4e9_row15_col4, #T_0f4e9_row15_col5, #T_0f4e9_row15_col6, #T_0f4e9_row15_col7, #T_0f4e9_row15_col8, #T_0f4e9_row15_col9, #T_0f4e9_row15_col13, #T_0f4e9_row16_col0, #T_0f4e9_row16_col3, #T_0f4e9_row16_col4, #T_0f4e9_row16_col5, #T_0f4e9_row16_col6, #T_0f4e9_row16_col7, #T_0f4e9_row16_col8, #T_0f4e9_row16_col9, #T_0f4e9_row16_col13, #T_0f4e9_row17_col0, #T_0f4e9_row17_col3, #T_0f4e9_row17_col4, #T_0f4e9_row17_col5, #T_0f4e9_row17_col6, #T_0f4e9_row17_col7, #T_0f4e9_row17_col8, #T_0f4e9_row17_col9, #T_0f4e9_row17_col13, #T_0f4e9_row18_col1, #T_0f4e9_row18_col2, #T_0f4e9_row18_col3, #T_0f4e9_row18_col4, #T_0f4e9_row18_col5, #T_0f4e9_row18_col6, #T_0f4e9_row18_col7, #T_0f4e9_row18_col8, #T_0f4e9_row18_col9, #T_0f4e9_row18_col13, #T_0f4e9_row19_col2, #T_0f4e9_row19_col3, #T_0f4e9_row19_col4, #T_0f4e9_row19_col5, #T_0f4e9_row19_col6, #T_0f4e9_row19_col7, #T_0f4e9_row19_col8, #T ...
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_0f4e9_row1_col1, #T_0f4e9_row3_col0, #T_0f4e9_row3_col1, #T_0f4e9_row4_col0, #T_0f4e9_row5_col0, #T_0f4e9_row6_col1, #T_0f4e9_row9_col1, #T_0f4e9_row12_col0, #T_0f4e9_row12_col1, #T_0f4e9_row13_col0, #T_0f4e9_row14_col0, #T_0f4e9_row17_col1, #T_0f4e9_row19_col1, #T_0f4e9_row21_col0, #T_0f4e9_row21_col1, #T_0f4e9_row22_col0, #T_0f4e9_row23_col0, #T_0f4e9_row24_col1, #T_0f4e9_row29_col1 {
#   background-color: #21918c;
#   color: #f1f1f1;
# }
# #T_0f4e9_row3_col12, #T_0f4e9_row4_col12, #T_0f4e9_row5_col12 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# #T_0f4e9_row3_col1

# %% [markdown]
# # Take likelihood marginals

# %%
true_likelihoods
# Out:
# array([1.36660704e+07, 1.00054123e+00])

# %%
np.exp([1,2,3])
# Out:
# array([ 2.71828183,  7.3890561 , 20.08553692])

# %%
# for parameter in true_values.keys():
#     temp_df = df[[parameter, "n_trials", "likelihood"]]

parameter = "delta_s"
temp_df = df[[parameter, "n_trials", "log_likelihood"]]
temp_df.groupby(["n_trials", "delta_s"])["log_likelihood"].agg(lambda row: np.sum(np.exp(row)))
# Out:
# n_trials  delta_s
# 1         1.00        0.000000e+00
#           1.01        0.000000e+00
#           1.02        0.000000e+00
#           1.03        0.000000e+00
#           1.04        0.000000e+00
#                          ...
# 32768     1.96       2.955513e-109
#           1.97        3.352855e-93
#           1.98        1.493572e-78
#           1.99        2.813945e-65
#           2.00        2.423271e-53
# Name: log_likelihood, Length: 1616, dtype: float64

# %%
temp_df = df[[parameter, "n_trials", "likelihood"]]
temp_df.sample(10).style.background_gradient(cmap='viridis', axis=0)

# %%
temp_df.groupby("n_trials")["likelihood"].sum()
