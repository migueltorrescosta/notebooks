# %%
from dataclasses import dataclass, field, asdict
from scipy.optimize import minimize
from tqdm import tqdm
import functools
import itertools
import numpy as np
import pandas as pd
import scipy
from src.angular_momentum import generate_spin_matrices

# %% [markdown]
# # Setup
#
# - $\ket{ \psi_0 } = \ket{0}_S \bigotimes \ket{0}_A$

# %%
@dataclass
class Settings:
    dim_s: int
    dim_a: int
    # n_trials: int
    true_delta_s: float
    probability_error_tolerance: float
    system_jx: np.array = field(init=False)
    system_jz: np.array = field(init=False)
    ancilla_jx: np.array = field(init=False)
    ancilla_jz: np.array = field(init=False)
    initial_state: np.array = field(init=False)

    def __post_init__(self):
        self.system_jx, self.system_jz = generate_spin_matrices(dim=self.dim_s)
        self.ancilla_jx, self.ancilla_jz = generate_spin_matrices(dim=self.dim_a)
        self.initial_state = np.zeros(self.dim_s * self.dim_a)
        self.initial_state[0] = 1
        self.initial_state = np.outer(self.initial_state, self.initial_state)

    def generate_hamiltonian(
        self,
        j_s: float,
        u_s: float,
        delta_s: float,
        j_a: float,
        u_a: float,
        delta_a: float,
        alpha_xx: float,
        alpha_xz: float,
        alpha_zx: float,
        alpha_zz: float,
    ) -> np.array:
        system_hamiltonian = np.kron(
            -1 * j_s * self.system_jx + u_s * self.system_jz @ self.system_jz + delta_s * self.system_jz,
            np.divide(np.eye(self.dim_a), self.dim_a)
        )
        ancillary_hamiltonian = np.kron(
            np.divide(np.eye(self.dim_s), self.dim_s),
            -1 * j_a * self.ancilla_jx + u_a * self.ancilla_jz @ self.ancilla_jz + delta_a * self.ancilla_jz
        )
        interaction_hamiltonian = functools.reduce(
            lambda x, y: x + y,
            [
                alpha_xx * np.kron(self.system_jx, self.ancilla_jx),
                alpha_xz * np.kron(self.system_jx, self.ancilla_jz),
                alpha_zx * np.kron(self.system_jz, self.ancilla_jx),
                alpha_zz * np.kron(self.system_jz, self.ancilla_jz),
            ]
        )
        return system_hamiltonian + ancillary_hamiltonian + interaction_hamiltonian

    def trace_out_ancillary(self, state: np.array):
        return np.trace(
            np.array(state).reshape(self.dim_a, self.dim_s, self.dim_a, self.dim_s),
            axis1=1,
            axis2=3
        )
    
    @staticmethod
    def calculate_final_state(
        hamiltonian: np.array,
        initial_state: np.ndarray,
        t: float = 0,
    ) -> np.array:
        return scipy.linalg.expm(-1j * t * hamiltonian) @ initial_state
    
    def calculate_probabilities(self, final_state: np.array) -> np.array:
        system_state = self.trace_out_ancillary(state=final_state)
        probabilities = [np.abs(x)**2 for x in np.diag(system_state)]
        # assert np.abs(np.sum(probabilities) - 1) < settings.probability_error_tolerance, f"The observed probabilities {probabilities} are unphysical"
        return probabilities
    
    def loss_function(self, x) -> float:
        j_s = x[0]
        u_s = x[1]
        j_a = x[2]
        u_a = x[3]
        delta_a = x[4]
        alpha_xx = x[5]
        alpha_xz = x[6]
        alpha_zx = x[7]
        alpha_zz = x[8]
        time = x[9]
        epsilon = x[10] # Used to approximate the numerical derivative
        hamiltonian = self.generate_hamiltonian(
            j_s=j_s,
            u_s=u_s,
            delta_s=self.true_delta_s + epsilon,
            j_a=j_a,
            u_a=u_a,
            delta_a=delta_a,
            alpha_xx=alpha_xx,
            alpha_xz=alpha_xz,
            alpha_zx=alpha_zx,
            alpha_zz=alpha_zz,
        )
        final_state = self.calculate_final_state(hamiltonian, initial_state=self.initial_state, t=time)
        probabilities_upper = self.calculate_probabilities(final_state)
        hamiltonian = self.generate_hamiltonian(
            j_s=j_s,
            u_s=u_s,
            delta_s=self.true_delta_s - epsilon,
            j_a=j_a,
            u_a=u_a,
            delta_a=delta_a,
            alpha_xx=alpha_xx,
            alpha_xz=alpha_xz,
            alpha_zx=alpha_zx,
            alpha_zz=alpha_zz,
        )
        final_state = self.calculate_final_state(hamiltonian, initial_state=self.initial_state, t=time)
        probabilities_lower = self.calculate_probabilities(final_state)
        probability_derivative_cost = -1 * np.divide(
            np.sum(np.abs(np.subtract(probabilities_upper, probabilities_lower))),
            epsilon
        ) # Maximize delta info obtained
        epsilon_cost = (1-epsilon)**2  # Avoid low epsilons to avoid numerical instability. High epsilons are naturally avoided by the derivative cost
        time_cost = time**2 # Avoids unnecessarily large times
        coefficients_l1_cost = np.sum([np.abs(x) for x in [j_s, u_s, j_a, u_a, delta_a, alpha_xx, alpha_xz, alpha_zx, alpha_zz]]) # Minimizes the number of non-zero coeffs
        return np.sum([
            100 * probability_derivative_cost,
            1e-2 * epsilon_cost,
            1e-10 * time_cost,
            1e-5 * coefficients_l1_cost
        ])

# %% [markdown]
# # Run optimization

# %%
@dataclass
class Results:
    j_s: float
    u_s: float
    j_a: float
    u_a: float
    delta_a: float
    alpha_xx: float
    alpha_xz: float
    alpha_zx: float
    alpha_zz: float
    time: float
    epsilon: float
    nits: int
    nfev: int
    loss: float
    success: bool
    message: str
    method: str

# %%
def get_optimal_solution(settings: Settings, method:str = "Nelder-Mead") -> Results:    
    initial_x = (
        1e-1, # j_s
        1e-1, # u_s
        1e-1, # j_a
        1e-1, # u_a
        1e-1, # delta_a
        1e-1, # alpha_xx
        1e-1, # alpha_xz
        1e-1, # alpha_zx
        1e-1, # alpha_zz
        1e-1, # time
        1e-1, # epsilon    
    )
    results = minimize(
        settings.loss_function,
        initial_x,
        method=method,
        # jac=None,
        # hess=None,
        # hessp=None,
        # bounds=None,
        # constraints=(),
        # tol=None,
        # callback=None,
        # options=None
    )
    return Results(
        j_s=results.x[0],
        u_s=results.x[1],
        j_a=results.x[2],
        u_a=results.x[3],
        delta_a=results.x[4],
        alpha_xx=results.x[5],
        alpha_xz=results.x[6],
        alpha_zx=results.x[7],
        alpha_zz=results.x[8],
        time=results.x[9],
        epsilon=results.x[10],
        nits=results.nit,
        nfev=results.nfev,
        loss=results.fun,
        success=results.success,
        message=results.message,
        method=method,
    )

# %% [markdown]
# # Generate results df

# %%
test = get_optimal_solution(Settings(
    dim_s = 2,
    dim_a = 4,
    # n_trials = 5,
    true_delta_s = 3,
    probability_error_tolerance = 1e-10,
))

# %%
options = range(2,10)
tqdm_generator = itertools.product(options, repeat=2)
tqdm_total = len(options)**2
settings_generator = (
    Settings(dim_s, dim_a, 3, 1e-10)
    for dim_s, dim_a
    in tqdm_generator
)

df = pd.DataFrame([
    {
        "dim_s": settings.dim_s,
        "dim_a": settings.dim_a,
        # "n_trials": settings.n_trials,
        "true_delta_s": settings.true_delta_s,
        "probability_error_tolerance": settings.probability_error_tolerance,
        **asdict(get_optimal_solution(settings))
    }
    for settings in tqdm(settings_generator, total=tqdm_total)]
)
# Out:
# 100%|██████████| 64/64 [28:23<00:00, 26.62s/it]

# %%
df.T
# Out:
#                                                                             0   \
# dim_s                                                                        2
# dim_a                                                                        2
# true_delta_s                                                                 3
# probability_error_tolerance                                                0.0
# j_s                                                                  -0.614164
# u_s                                                                  13.035962
# j_a                                                                  -1.893744
# u_a                                                                   2.791028
# delta_a                                                              -5.732849
# alpha_xx                                                              1.353268
# alpha_xz                                                             -0.837998
# alpha_zx                                                             -0.909006
# alpha_zz                                                             -2.939662
# time                                                                  8.783537
# epsilon                                                                    0.0
# nits                                                                      1566
# nfev                                                                      2200
# loss                                                               -265.555741
# success                                                                  False
# message                      Maximum number of function evaluations has bee...
# method                                                             Nelder-Mead
#
#                                                                             1   \
# dim_s                                                                        2
# dim_a                                                                        3
# true_delta_s                                                                 3
# probability_error_tolerance                                                0.0
# j_s                                                                   0.400113
# u_s                                                                  -9.063561
# j_a                                                                  -5.403509
# u_a                                                                   4.545929
# delta_a                                                              13.767416
# alpha_xx                                                             -5.893731
# alpha_xz                                                              1.658588
# alpha_zx                                                             -7.243728
# alpha_zz                                                              1.326521
# time                                                                 20.602379
# epsilon                                                               0.016892
# nits                                                                      1590
# nfev                                                                      2200
# loss                                                               -380.192621
# success                                                                  False
# message                      Maximum number of function evaluations has bee...
# method                                                             Nelder-Mead
#
#                                                                             2   \
# dim_s                                                                        2
# dim_a                                                                        4
# true_delta_s                                                                 3
# probability_error_tolerance                                                0.0
# j_s                                                                  -4.808845
# u_s                                                                   4.516185
# j_a                                                                  -0.706968
# u_a                                                                    1.54556
# delta_a                                                               0.707584
# alpha_xx                                                              -0.26987
# alpha_xz                                                             -1.476643
# alpha_zx                                                             -1.765912
# alpha_zz                                                              0.218168
# time                                                                  3.471314
# epsilon                                                               0.000068
# nits                                                                      1582
# nfev                                                                      2200
# loss                                                                 -47.09289
# success                                                                  False
# message                      Maximum number of function evaluations has bee...
# method                                                             Nelder-Mead
#
#                                                                             3   \
# dim_s                                                                        2
# dim_a                                                                        5
# true_delta_s                                                                 3
# probability_error_tolerance                                                0.0
# j_s                                                                  -5.251521
# u_s                                                                  -8.827469
# j_a                                                                   0.276883
# u_a                                                                   3.966685
# delta_a                                                              -3.851547
# alpha_xx                                                              0.501047
# alpha_xz                                                             -0.843229
# alpha_zx                                                              -1.66365
# alpha_zz                                                             -3.096562
# time                                                                  9.580045
# epsilon                                                               0.000233
# nits                                                                      1595
# nfev                                                                      2200
# loss                                                               -104.066046
# success                                                                  False
# message                      Maximum number of function evaluations has bee...
# method                                                             Nelder-Mead
#
#                                                                             4   \
# dim_s                                                                        2
# dim_a                                                                        6
# true_delta_s                                                                 3
# probability_error_tolerance                                                0.0
# j_s                                                                    5.97029
# u_s                                                                  -0.410294
# j_a                                                                   1.305826
# u_a                                                                   6.847315
# delta_a                                                             -20.719336
# alpha_xx                                                              0.586046
# alpha_xz                                                               0.13409
# alpha_zx                                                              0.349416
# alpha_zz                                                             -2.114662
# time                                                                  6.988315
# epsilon                                                                0.57518
# nits                                                                      1564
# nfev                                                                      2200
# loss                                                                  -66.3354
# success                                                                  False
# message                      Maximum number of function evaluations has bee...
# method                                                             Nelder-Mead
#
#                                                                             5   \
# dim_s                                                                        2
# dim_a                                                                        7
# true_delta_s                                                                 3
# probability_error_tolerance                                                0.0
# j_s                                                                  -3.504574
# u_s                                                                  -1.168505
# j_a                                                                  -0.885973
# u_a                                                                   1.889797
# delta_a                                                               -0.06183
# alpha_xx                                                              0.771212
# alpha_xz                                                             -0.044455
# alpha_zx                                                             -0.899345
# alpha_zz                                                             -1.666293
# time                                                                   4.44954
# epsilon                                                               0.017264
# nits                                                                      1600
# nfev                                                                      2200
# loss                                                                -36.582235
# success                                                                  False
# message                      Maximum number of function evaluations has bee...
# method                                                             Nelder-Mead
#
#                                                                             6   \
# dim_s                                                                        2
# dim_a                                                                        8
# true_delta_s                                                                 3
# probability_error_tolerance                                                0.0
# j_s                                                                  -7.080327
# u_s                                                                   0.483279
# j_a                                                                   0.730601
# u_a                                                                   1.670508
# delta_a                                                              -1.789909
# alpha_xx                                                              1.057593
# alpha_xz                                                             -0.132508
# alpha_zx                                                               2.24884
# alpha_zz                                                             -0.919506
# time                                                                  4.134659
# epsilon                                                               2.556546
# nits                                                                      1592
# nfev                                                                      2200
# loss                                                                -25.670361
# success                                                                  False
# message                      Maximum number of function evaluations has bee...
# method                                                             Nelder-Mead
#
#                                                                             7   \
# dim_s                                                                        2
# dim_a                                                                        9
# true_delta_s                                                                 3
# probability_error_tolerance                                                0.0
# j_s                                                                   1.309152
# u_s                                                                  -4.283175
# j_a                                                                  -3.728412
# u_a                                                                   1.406339
# delta_a                                                               -0.11524
# alpha_xx                                                             -1.548468
# alpha_xz                                                             -0.109384
# alpha_zx                                                             -2.306295
# alpha_zz                                                             -2.089827
# time                                                                  3.523102
# epsilon                                                               4.946203
# nits                                                                      1575
# nfev                                                                      2200
# loss                                                                -12.676858
# success                                                                  False
# message                      Maximum number of function evaluations has bee...
# method                                                             Nelder-Mead
#
#                                                                             8   \
# dim_s                                                                        3
# dim_a                                                                        2
# true_delta_s                                                                 3
# probability_error_tolerance                                                0.0
# j_s                                                                   0.354777
# u_s                                                                   1.751447
# j_a                                                                  -1.017799
# u_a                                                                  -3.699153
# delta_a                                                              -0.591386
# alpha_xx                                                              0.124327
# alpha_xz                                                              2.970946
# alpha_zx                                                             -2.027606
# alpha_zz                                                             -0.650848
# time                                                                  3.598874
# epsilon                                                                0.15379
# nits                                                                      1575
# nfev                                                                      2200
# loss                                                               -155.869156
# success                                                                  False
# message                      Maximum number of function evaluations has bee...
# method                                                             Nelder-Mead
#
#                                                                             9   \
# dim_s                                                                        3
# dim_a                                                                        3
# true_delta_s                                                                 3
# probability_error_tolerance                                                0.0
# j_s                                                                  -6.065865
# u_s                                                                  -1.281647
# j_a                                                                   5.467036
# u_a                                                                  -3.932155
# delta_a                                                              -1.346478
# alpha_xx                                                              1.580692
# alpha_xz                                                             -1.726883
# alpha_zx                                                              2.570842
# alpha_zz                                                             -0.952801
# time                                                                  6.787841
# epsilon                                                               0.001514
# nits                                                                      1577
# nfev                                                                      2200
# loss                                                               -155.220035
# success                                                                  False
# message                      Maximum number of function evaluations has bee...
# method                                                             Nelder-Mead
#
#                              ...  \
# dim_s                        ...
# dim_a                        ...
# true_delta_s                 ...
# probability_error_tolerance  ...
# j_s                          ...
# u_s                          ...
# j_a                          ...
# u_a                          ...
# delta_a                      ...
# alpha_xx                     ...
# alpha_xz                     ...
# alpha_zx                     ...
# alpha_zz                     ...
# time                         ...
# epsilon                      ...
# nits                         ...
# nfev                         ...
# loss                         ...
# success                      ...
# message                      ...
# method                       ...
#
#                                                                             54  \
# dim_s                                                                        8
# dim_a                                                                        8
# true_delta_s                                                                 3
# probability_error_tolerance                                                0.0
# j_s                                                                    0.89038
# u_s                                                                   0.630342
# j_a                                                                  -0.744437
# u_a                                                                   1.940635
# delta_a                                                               0.716617
# alpha_xx                                                             -0.064887
# alpha_xz                                                             -0.590328
# alpha_zx                                                             -0.472568
# alpha_zz                                                              0.570097
# time                                                                 -1.438924
# epsilon                                                               0.000019
# nits                                                                      1537
# nfev                                                                      2200
# loss                                                                -21.061562
# success                                                                  False
# message                      Maximum number of function evaluations has bee...
# method                                                             Nelder-Mead
#
#                                                                             55  \
# dim_s                                                                        8
# dim_a                                                                        9
# true_delta_s                                                                 3
# probability_error_tolerance                                                0.0
# j_s                                                                   2.837332
# u_s                                                                   1.495663
# j_a                                                                  -3.410284
# u_a                                                                   1.078107
# delta_a                                                              -1.789703
# alpha_xx                                                             -0.030466
# alpha_xz                                                             -0.188507
# alpha_zx                                                               -0.0306
# alpha_zz                                                              0.009178
# time                                                                 -6.110043
# epsilon                                                               0.071628
# nits                                                                      1591
# nfev                                                                      2200
# loss                                                                -89.668353
# success                                                                  False
# message                      Maximum number of function evaluations has bee...
# method                                                             Nelder-Mead
#
#                                                                             56  \
# dim_s                                                                        9
# dim_a                                                                        2
# true_delta_s                                                                 3
# probability_error_tolerance                                                0.0
# j_s                                                                  -1.317831
# u_s                                                                    0.73743
# j_a                                                                   6.380873
# u_a                                                                  -2.271747
# delta_a                                                               2.727562
# alpha_xx                                                             -0.715325
# alpha_xz                                                             -4.136419
# alpha_zx                                                             -0.219697
# alpha_zz                                                             -3.113477
# time                                                                  4.211104
# epsilon                                                               0.046201
# nits                                                                      1577
# nfev                                                                      2200
# loss                                                               -435.153973
# success                                                                  False
# message                      Maximum number of function evaluations has bee...
# method                                                             Nelder-Mead
#
#                                                                             57  \
# dim_s                                                                        9
# dim_a                                                                        3
# true_delta_s                                                                 3
# probability_error_tolerance                                                0.0
# j_s                                                                  -4.586215
# u_s                                                                   1.459927
# j_a                                                                  -3.892244
# u_a                                                                   0.343363
# delta_a                                                               4.108234
# alpha_xx                                                              1.512545
# alpha_xz                                                              0.540876
# alpha_zx                                                              0.404506
# alpha_zz                                                              0.528807
# time                                                                  1.354004
# epsilon                                                                0.00001
# nits                                                                      1537
# nfev                                                                      2200
# loss                                                                -52.318797
# success                                                                  False
# message                      Maximum number of function evaluations has bee...
# method                                                             Nelder-Mead
#
#                                                                             58  \
# dim_s                                                                        9
# dim_a                                                                        4
# true_delta_s                                                                 3
# probability_error_tolerance                                                0.0
# j_s                                                                   2.602346
# u_s                                                                  -1.136438
# j_a                                                                  -6.876324
# u_a                                                                 -11.714435
# delta_a                                                               10.69357
# alpha_xx                                                              0.269581
# alpha_xz                                                              0.621304
# alpha_zx                                                             -0.159504
# alpha_zz                                                              0.102318
# time                                                                  4.159925
# epsilon                                                               1.569482
# nits                                                                      1554
# nfev                                                                      2200
# loss                                                                -37.334502
# success                                                                  False
# message                      Maximum number of function evaluations has bee...
# method                                                             Nelder-Mead
#
#                                                                 59  \
# dim_s                                                            9
# dim_a                                                            5
# true_delta_s                                                     3
# probability_error_tolerance                                    0.0
# j_s                                                       3.466666
# u_s                                                      -0.742083
# j_a                                                      -2.276501
# u_a                                                      -1.735873
# delta_a                                                  -0.937116
# alpha_xx                                                 -0.666404
# alpha_xz                                                 -0.208755
# alpha_zx                                                  0.089554
# alpha_zz                                                 -0.164232
# time                                                      3.682808
# epsilon                                                        0.0
# nits                                                          1512
# nfev                                                          2153
# loss                                                    -68.317327
# success                                                       True
# message                      Optimization terminated successfully.
# method                                                 Nelder-Mead
#
#                                                                 60  \
# dim_s                                                            9
# dim_a                                                            6
# true_delta_s                                                     3
# probability_error_tolerance                                    0.0
# j_s                                                       -1.10107
# u_s                                                       1.018646
# j_a                                                       0.187026
# u_a                                                       0.726863
# delta_a                                                   0.185769
# alpha_xx                                                 -0.019961
# alpha_xz                                                  1.092435
# alpha_zx                                                   0.00045
# alpha_zz                                                  0.495204
# time                                                     -1.683763
# epsilon                                                        0.0
# nits                                                          1087
# nfev                                                          1592
# loss                                                     -50.20821
# success                                                       True
# message                      Optimization terminated successfully.
# method                                                 Nelder-Mead
#
#                                                                             61  \
# dim_s                                                                        9
# dim_a                                                                        7
# true_delta_s                                                                 3
# probability_error_tolerance                                                0.0
# j_s                                                                   0.537358
# u_s                                                                   1.552601
# j_a                                                                  -1.467712
# u_a                                                                   3.519649
# delta_a                                                               1.454115
# alpha_xx                                                             -0.676247
# alpha_xz                                                             -0.754005
# alpha_zx                                                             -0.393379
# alpha_zz                                                              0.479294
# time                                                                 -2.152515
# epsilon                                                               0.001082
# nits                                                                      1573
# nfev                                                                      2200
# loss                                                                -42.958829
# success                                                                  False
# message                      Maximum number of function evaluations has bee...
# method                                                             Nelder-Mead
#
#                                                                             62  \
# dim_s                                                                        9
# dim_a                                                                        8
# true_delta_s                                                                 3
# probability_error_tolerance                                                0.0
# j_s                                                                    0.01408
# u_s                                                                   1.109244
# j_a                                                                    -8.0859
# u_a                                                                   6.468964
# delta_a                                                              -9.986251
# alpha_xx                                                             -0.109386
# alpha_xz                                                             -0.669878
# alpha_zx                                                              0.019576
# alpha_zz                                                              0.256925
# time                                                                  -2.14406
# epsilon                                                               0.110465
# nits                                                                      1564
# nfev                                                                      2200
# loss                                                                -41.534831
# success                                                                  False
# message                      Maximum number of function evaluations has bee...
# method                                                             Nelder-Mead
#
#                                                                             63
# dim_s                                                                        9
# dim_a                                                                        9
# true_delta_s                                                                 3
# probability_error_tolerance                                                0.0
# j_s                                                                  -3.517571
# u_s                                                                   1.908023
# j_a                                                                   -4.52134
# u_a                                                                   1.093718
# delta_a                                                               1.867129
# alpha_xx                                                              0.186442
# alpha_xz                                                             -0.473242
# alpha_zx                                                             -0.002068
# alpha_zz                                                              0.012054
# time                                                                 -4.477451
# epsilon                                                               0.782107
# nits                                                                      1589
# nfev                                                                      2200
# loss                                                                -88.448411
# success                                                                  False
# message                      Maximum number of function evaluations has bee...
# method                                                             Nelder-Mead
#
# [21 rows x 64 columns]

# %%
df[["dim_s", "dim_a", "j_s", "u_s", "j_a", "u_a", "delta_a", "alpha_xx", "alpha_xz", "alpha_zx", "alpha_zz", "time", "loss", "success"]]
# Out:
#     dim_s  dim_a       j_s        u_s       j_a       u_a    delta_a  \
# 0       2      2 -0.614164  13.035962 -1.893744  2.791028  -5.732849
# 1       2      3  0.400113  -9.063561 -5.403509  4.545929  13.767416
# 2       2      4 -4.808845   4.516185 -0.706968  1.545560   0.707584
# 3       2      5 -5.251521  -8.827469  0.276883  3.966685  -3.851547
# 4       2      6  5.970290  -0.410294  1.305826  6.847315 -20.719336
# ..    ...    ...       ...        ...       ...       ...        ...
# 59      9      5  3.466666  -0.742083 -2.276501 -1.735873  -0.937116
# 60      9      6 -1.101070   1.018646  0.187026  0.726863   0.185769
# 61      9      7  0.537358   1.552601 -1.467712  3.519649   1.454115
# 62      9      8  0.014080   1.109244 -8.085900  6.468964  -9.986251
# 63      9      9 -3.517571   1.908023 -4.521340  1.093718   1.867129
#
#     alpha_xx  alpha_xz  alpha_zx  alpha_zz       time        loss  success
# 0   1.353268 -0.837998 -0.909006 -2.939662   8.783537 -265.555741    False
# 1  -5.893731  1.658588 -7.243728  1.326521  20.602379 -380.192621    False
# 2  -0.269870 -1.476643 -1.765912  0.218168   3.471314  -47.092890    False
# 3   0.501047 -0.843229 -1.663650 -3.096562   9.580045 -104.066046    False
# 4   0.586046  0.134090  0.349416 -2.114662   6.988315  -66.335400    False
# ..       ...       ...       ...       ...        ...         ...      ...
# 59 -0.666404 -0.208755  0.089554 -0.164232   3.682808  -68.317327     True
# 60 -0.019961  1.092435  0.000450  0.495204  -1.683763  -50.208210     True
# 61 -0.676247 -0.754005 -0.393379  0.479294  -2.152515  -42.958829    False
# 62 -0.109386 -0.669878  0.019576  0.256925  -2.144060  -41.534831    False
# 63  0.186442 -0.473242 -0.002068  0.012054  -4.477451  -88.448411    False
#
# [64 rows x 14 columns]
