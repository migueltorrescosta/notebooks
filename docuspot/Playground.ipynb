# %% [markdown]
# # PDF to Text

# %%
# !pip install pdfplumber
# Out:
# Requirement already satisfied: pdfplumber in /opt/conda/lib/python3.9/site-packages (0.6.1)
# Requirement already satisfied: Pillow>=9.1 in /opt/conda/lib/python3.9/site-packages (from pdfplumber) (9.1.0)
# Requirement already satisfied: Wand>=0.6.7 in /opt/conda/lib/python3.9/site-packages (from pdfplumber) (0.6.7)
# Requirement already satisfied: pdfminer.six==20220319 in /opt/conda/lib/python3.9/site-packages (from pdfplumber) (20220319)
# Requirement already satisfied: cryptography in /opt/conda/lib/python3.9/site-packages (from pdfminer.six==20220319->pdfplumber) (36.0.2)
# Requirement already satisfied: chardet in /opt/conda/lib/python3.9/site-packages (from pdfminer.six==20220319->pdfplumber) (4.0.0)
# Requirement already satisfied: cffi>=1.12 in /opt/conda/lib/python3.9/site-packages (from cryptography->pdfminer.six==20220319->pdfplumber) (1.15.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.9/site-packages (from cffi>=1.12->cryptography->pdfminer.six==20220319->pdfplumber) (2.21)

# %%
import pdfplumber

# %%
file = "sample_pdfs/MutualInformation.pdf"
pdf = pdfplumber.open(file)
parsed_text = "\n\n".join([page.extract_text() for page in pdf.pages])
print(parsed_text)
# Out:
# 1
# PatternRecognitionLetters
# journalhomepage: www.elsevier.com
# Fast computation of mutual information in the frequency domain with applications to
# global multimodal image alignment
# JohanO¨fverstedta,∗∗,JoakimLindblada,NatasˇaSladojea
# 1 aDepartmentofInformationTechnology,UppsalaUniversity,La¨gerhyddsva¨gen2,75237Uppsala,Sweden
# 2
# 0
# 2 ABSTRACT
#
# n
# Multimodalimagealignmentistheprocessofﬁndingspatialcorrespondencesbetweenimagesformed
# u
# J bydiﬀerentimagingtechniquesorunderdiﬀerentconditions, tofacilitateheterogeneousdatafusion
# 8  andcorrelativeanalysis.Theinformation-theoreticconceptofmutualinformation(MI)iswidelyused
# 2 as a similarity measure to guide multimodal alignment processes, where most works have focused
#   on local maximization of MI that typically works well only for small displacements; this points to
#
# ]
# a need for global maximization of MI, which has previously been computationally infeasible due to
# V
# the high run-time complexity of existing algorithms. We propose an eﬃcient algorithm for comput-
# C
# ingMIforalldiscretedisplacements(formalizedasthecross-mutualinformationfunction(CMIF)),
# .
# s whichisbasedoncross-correlationcomputedinthefrequencydomain. Weshowthatthealgorithm
# c
# isequivalenttoadirectmethodwhileasymptoticallysuperiorintermsofrun-time. Furthermore,we
# [
#   propose a method for multimodal image alignment for transformation models with few degrees of
#
# 1 freedom (e.g. rigid) based on the proposed CMIF-algorithm. We evaluate the eﬃcacy of the pro-
# v
# posed method on three distinct benchmark datasets, of aerial images, cytological images, and histo-
# 9
# logical images, and we observe excellent success-rates (in recovering known rigid transformations),
# 9
# 6 overall outperforming alternative methods, including local optimization of MI as well as several re-
# 4 cent deep learning-based approaches. We also evaluate the run-times of a GPU implementation of
# 1 the proposed algorithm and observe speed-ups from 100 to more than 10,000 times for realistic im-
# .
# 6 age sizes compared to a GPU implementation of a direct method. Code is shared as open-source at
# 0 github.com/MIDA-group/globalign.
# 1 ©2021ElsevierLtd.Allrightsreserved.
# 2
# :
# v
# i
# X
# 1. Introduction containsmall/thinstructuresthatarediﬃculttomatchwithout
# r
# a relying on ﬁducial markers or time-consuming manual inter-
# Multimodal image alignment (also known as registration)
# vention[2].
# [1], involves ﬁnding correspondences between images formed
# by diﬀerent imaging techniques or under diﬀerent conditions. Monomodal(orunimodal)alignmentcanbeaddressedbya
# number of existing techniques, often grouped into (i) feature-
# The goal is often to enable data fusion of the heterogeneous
# based methods, such as SIFT [3], where the focus is on ﬁnd-
# information of the sources involved. Processes closely related
# ing correspondences between distinct feature points detected
# toregistrationarepatchretrievalandtemplatematching. Mul-
# in the images, and (ii) intensity-based methods, such as [4],
# timodal image alignment can be a very challenging problem,
# wherethealignmentisguidedbysimilaritybetweenthewhole
# duetogreatdissimilaritiesoftheinvolvedmodalities. Onearea
# image functions. Multimodal alignment is more complex and
# wherefullyautomatedapproacheshavebeenlackingisinalign-
# challenging,sincesimilarityinappearancecannotbeexpected
# mentofmicrographs,andinparticularcorrelativemicroscopy,
# for corresponding structures. This reduces the applicability
# where image modalities are often highly distinct and images
# of feature-based methods. Instead, intensity-based methods
# guidedbylocaloptimizationofsimilaritymeasureswhichrely
# ∗∗Correspondingauthor: on some statistics, such as mutual information (MI) [5, 6] or
# e-mail:johan.ofverstedt@it.uu.se(JohanO¨fverstedt) modalityindependentneighbourhooddescriptors[7],arewell-
#
# 2
# A A (Quantized)
# CMIFs Aligned
# Quantize Compute Max CMIF A and T(B)
# (k-means) CMIFs gives T
# B B (Quantized)
# Fig.1: Illustrationofthemainstepsoftheproposedimagealignmentmethod. TheinputconsistsoftwounalignedhistologicalimagesfromSHG(modalityA)
# andBFimaging(B).Theyarebothquantizedinto16categoricallabelsusingk-meansclustering(illustratedbypseudo-coloring)followedbycomputationofdense
# CMIFmaps(MIoveralldiscretedisplacements)foreachconsideredrotationangle. ThetransformationwiththemaxCMIFisidentiﬁed;itprovidesthedesired
# alignment.Attheendofthepipelineweobservethetransformedoverlappingimageswhicharesuccessfullyaligned.
# establishedtoolsforthistask. Anotherclassofmethodsrelyon run-time of the fast CMIF-algorithm in comparison to the di-
# reducingamultimodalalignmenttasktoamonomodalone,by recthistogram-basedalgorithm. Weobservespeed-upsranging
# (typicallylearning-based)transformationoftheimagemodali- from hundreds of times to more than 10,000 times for practi-
# tiestoacommonmodality[8,9],forwhichhigh-performance callyrelevantimagesizes.
# monomodalmethodsareapplicable. Ourﬁfthcontributionisanevaluationoftheproposedglobal
# IthasbeenobservedthatMIexhibitshighperformancewhen rigidalignmentmethodcomparedwithstate-of-the-artmethods
# usedasasimilaritymeasureinlocaloptimizationframeworks onthreedistinctandpubliclyavailablemultimodalrigidalign-
# if the displacements to recover are small, but struggles for mentbenchmarkdatasets,followingtheprotocolof[9].
# largerdisplacements[4,6,9]. Thishighlightstheneedforfast The two proposed algorithms are implemented in PyTorch
# globaloptimizationofMI.However,existingmethods[10,11] [13] for accelerated computation on general-purpose graphics
# exhibit run-time complexities which make them unsuited for processing units (GPGPUs), and the code is shared as open-
# manypracticallyrelevantimagesizes. sourceatgithub.com/MIDA-group/globalign.
# We here present two algorithms. The ﬁrst algorithm, and
# main contribution of this work, eﬃciently computes MI be- 2. MIinimageprocessing
# tween two images for all possible discrete displacements on a
# rectangular domain. The output corresponds to a generaliza- MI, introduced in [14], is an information-theoretic measure
# tion of the, in the ﬁeld of 1D (EEG) signal analysis, existing quantifying the mutual dependence between two random vari-
# notion of cross-mutual information function (CMIF) [12] and ables. Itiscommonlyusedinimageprocessingasasimilarity
# we therefore use the same name in this work. We propose measurebetweenimages[15,16].
# a novel approach for eﬃcient computation of CMIF by using Given two discrete images A and B with domains XA ⊂ Zn
# cross-correlation (CC) in the frequency domain, providing an andXB ⊂Zn,intersectingonXAB,whereXAB ≠∅,withranges
# outputwhichisequivalenttoexhaustivelycomputingMIover AandB,MIisdeﬁnedas
# allpossiblediscretedisplacements.
# pAB(a,b)
# Our second contribution is a method that combines the fast I(A,B)=∑∑ pAB(a,b)log XAB , (1)
# XAB 2 pA (a)pB (b)
# CMIFcomputationwithagridsearchoveradditionaltransfor- a∈Ab∈B XAB XAB
# mationparameters(e.g.rotation)tofacilitateglobalmultimodal
# where pAB(a,b)denotestherelativefrequencyofvaluesaand
# image alignment for transformations with reasonably few de- b occurrXinABg jointly in X , and pA (a) denotes the marginal
# grees of freedom (rigid, aﬃne, etc.). Figure 1 illustrates the AB XAB
# relativefrequencyofvalueaoccurringinimageA,withinX .
# main steps of global rigid alignment by this method applied AB
# Thefrequencies pAB(a,b), pA (a), pB (b)canbecomputed
# onhistologicalimagesacquiredbysecondharmonicgeneration XAB XAB XAB
# usingmarginalandjointhistograms.
# (SHG)microscopy,andbright-ﬁeld(BF)microscopy.
# Alternatively,MIcanbeformulatedintermsofthemarginal
# Our third contribution is a theoretical analysis of the pro-
# andthejointentropies,
# posed CMIF-algorithm. We show that it is equivalent to a di-
# recthistogram-basedalgorithmforcomputationofMI.Further- I(A,B)=H +H −H , (2)
# A B AB
# more, we derive the asymptotic computational complexity of
# theproposedCMIF-algorithm,andshowthatitissubstantially wherethemarginalentropyofimageA,onXABisgivenby
# morecomputationallyeﬃcientthantheexistingmethods.
# H =−∑pA (a)log pA (a), (3)
# Our fourth contribution is an empirical evaluation of the A XAB 2 XAB
# a∈A
#
# 3
# analogousdeﬁnitionholdsforimageB,andthejointentropyis 3. Method
# givenby
# We propose a fast and exact algorithm for computing MI
# HAB=−∑∑ pXAABB(a,b)log2(pXAABB(a,b)). (4) forallpossiblediscretedisplacementsonarectangulardomain
# a∈Ab∈B (Eq. (5)), enabling fast global translation-based alignment us-
# CMIF describes the MI between two images subject to dis- ing MI maximization. We show the equivalence to a direct
# placementχ∈Zn(generalizationtonDofdeﬁnitionin[12]), histogram-based method and we analyze the asymptotic com-
# CMIF(χ;A,B)=I(A,T [B]), (5) putationalcomplexity. Furthermore,weproposeaglobalmul-
# χ
# timodalimagealignmentmethodbasedontheproposedCMIF-
# where Tχ[B] denotes the image B translated as Tχ[B](x) = algorithm.
# B(x+χ). CMIFcanalsobeformulatedintermsofentropies,
# similartoEq.(2),forentropiesdeﬁnedasfunctionsofdisplace- 3.1. Notationandbasicdeﬁnitions
# ments,HA(χ)=HA,HB(χ)=HTχ[B],andHAB(χ)=HATχ[B]. Consider pairs of images, A∶XA→A and B∶XB→B, where
# X ⊆X ⊂Zn, togetherwithcorrespondinggivenregionofin-
# 2.1. ImagealignmentbyMImaximization B A
# terest masks, M ∶X →{0,1} and M ∶X →{0,1} indicating
# A A B B
# AnimagealignmentprocessbasedonMImaximizationcan
# the user-deﬁned part to be included in the computation of MI.
# ̂
# beexpressedasﬁndingatransformationT suchthat
# Withoutlossofgenerality,weassumethatX andX arerect-
# A B
# T̂=argmaxI(A,T(B)), (6) angular subsets of Zn, since any other subset can be obtained
# T∈Ω through appropriately deﬁned masks MA and MB. Let XS de-
# where A is the reference image, and T(B) denotes the geo- notethesetofdisplacementsχforwhichtheentiredomainof
# metricallytransformedﬂoatingimage,wheretransformationT theshiftedimageBintersectswiththedomainofimageA.
# is applied to image B to warp it into the space of A, and Ω TheCC,forreal-valuedfunctions f andgdeﬁnedonZn, is
# is a chosen set of transformations. Solutions to (6) are com- givenby
# monlysoughtlocally,usinggradient-basedmethods[5,15–17], (f ⋆g)(χ)= ∑ f(x)g(x+χ). (7)
# orrecentlythroughaGibbs-samplingprocess[18],orglobally x∈Zn
# throughcomputationofMIforeachdiscretedisplacement[10]. Let La[A]denote an indicator function (level set) on XA, of
# Use of local methods requires a good initial guess since MI imageAbeingequaltoa∈AandwithinthemaskimageMA,
# typicallyexhibitsalargenumberoflocalmaxima[6]. MIcan
# 1, for M (x)=1 and A(x)=a
# be combined with gradient information to improve the perfor- L [A](x)={ A }. (8)
# a 0, otherwise
# mancewhenthemodalitiesexhibitsimilarityofvariation[19].
# To reduce the dependence on the size of the images and their
# 3.2. AlgorithmforcomputingCMIFinthefrequencydomain
# overlap,anormalizedMI(NMI)[20]wasdeveloped.
# Fast computation of MI is critical in many applications, in Contrarytothedirectmethod,where,givenaparticulardis-
# particular when MI is used as a similarity measure for align- placement χ, histograms are computed for all image values a
# menttasks,duetothelargedataandnumberofsimilaritycom- andb, weinsteadreordertherequiredoperations; givenasin-
# putations involved. Stochastic sub-sampling is commonly uti- gleimagevaluea,(or)b,orapairofvalues(a,b),thenumber
# lized together with gradient-based local optimization methods ofoccurrencesofthevalue/pair,andthecorrespondingentropy
# [5,6]. Otherworksincludespeedinguplocaloptimizationap- contribution,iscomputedforallχ∈XS.
# proachesbyusingGPU-basedhistogrammethods[11,21]. ComputationofthejointhistogramentriesCAB(χ;A,B)can
# a,b
# beexpressedas
# 2.2. Globaloptimizationoverdiscretedisplacements
# Eﬃcient methods for global optimization over discrete dis- CaA,bB(χ;A,B)=(La[A]⋆Lb[B])(χ), (9)
# placements (based on fast convolutions performed in the fre-
# and the marginal histogram entries CA(χ;A,B) and
# quencydomainoronuseofintegralimages)existforabsolute a
# CB(χ;A,B)respectively,canbeexpressedas
# mean diﬀerences, mean square diﬀerences [22], CC and nor- b
# malizedcross-correlation[23],while(tothebestofourknowl- CA(χ;A,B)=(L [A]⋆M )(χ),
# a a B
# edge)sofarnotforMI[6,10,11,24]. (10)
# CB(χ;A,B)=(M ⋆L [B])(χ).
# Adirect,histogram-based,approachforcomputingCMIFfor b A b
# all displacements χ requires, for each χ (considered in isola-
# Complete histograms are computed by evaluating Eq. (9) and
# tion), toiterate over XATχ[B] and incrementthe joint histogram Eq.(10)forallimagevaluesa∈Aandb∈B. Anotherquantity
# bincorrespondingtothevaluesaandb(andanalogouslyforthe ofinterestfortheCMIFcomputationisamapN∶X →R rep-
# marginalhistograms).Finallytheentropies(Eq.(3)and(4))are S ≥0
# resentingthenumberofvalidpoints(pointswherebothmasks
# computed using relative histograms, which then directly give arenon-zero)forallχ∈X ,whichenablescomputationofrel-
# S
# theMIthroughEq.(2). Thismethodisdiscussedin[10]. Fur-
# ativehistograms. N isgivenby
# thermore, [11, 21] discuss maximization of MI by exhaustive
# search in the context of their fast approaches for GPU-based N(χ;A,B)=(M ⋆M )(χ)=
# A B
# histogramcomputation,andconcludethatsuchanapproachis ∑CA(χ,A,B)= ∑CB(χ,A,B). (11)
# toocostlytobeusefulinpractice. a b
# a∈A b∈B
#
# 4
# The relative histograms obtained after normalizing Ca, Cb, 3.5. Complexityanalysis
# A B
# Ca,bby(pointwisedivisionby)Ncanbeinsertedasprobability
# AB Theworst-caserun-timecomplexityofthedirectapproachis
# functionsintotheshiftedversionsofEq.(3)andEq.(4),
# T (A,B)=O(∣X ∣∣X ∣+(∣A∣+∣B∣+∣A∣∣B∣)∣X ∣), (14)
# D B S S
# CA(χ;A,B) CA(χ;A,B)
# HA(χ)=−∑ Na(χ;A,B) log2 Na(χ;A,B) , given by its requirement of O(1) work for every element in
# a∈A image B for every χ ∈ X and O(1) work per histogram bin.
# CB(χ;A,B) CB(χ;A,B) S
# HB(χ)=−b∑∈B Nb(χ;A,B) log2 Nb(χ;A,B) , (12) Orenquthireeso,thinesrtheaadn,d,cocommppuutattaitoionnooffaCtCmoinstth1e+fr∣eAq∣u+en∣Bcy∣+do∣Am∣a∣Bin∣
# CAB(χ;A,B) CAB(χ;A,B) (forward and inverse) DFTs using the Fast Fourier Transform
# H (χ)=−∑∑ a,b log a,b ,
# AB N(χ;A,B) 2 N(χ;A,B) (FFT) algorithm [26] and element-wise (complex) multiplica-
# a∈Ab∈B tions,yieldinganasymptoticrun-timecomplexityof
# whichcanbeuseddirectlytocomputeCMIF(Eq.(5)). Round-
# T (A,B)=O((1+∣A∣+∣B∣+∣A∣∣B∣)∣X ∣log∣X ∣). (15)
# ingCA,CB,CABandNforallχtointegerswecircumventpos- F A A
# a b a,b
# sibleﬂoating-pointerrorsinthecomputationandreachanexact If ∣A∣ and ∣B∣ are treated as (small) constants, the proposed
# result. InEq.(12),wedeﬁnethat 00 =0and0log20=0. methodisasymptoticallyeﬃcientcf. thedirectapproach(w.r.t.
# thesizeoftheimages),exceptforcaseswithverysmall∣X ∣. It
# B
# hasbeenobserved[19]that32intensitybinsprovidedthebest
# 3.3. GeneralizationtospatiallyweightedMI
# trade-oﬀbetween(i)ﬂexibilityanddetail,and(ii)insensitivity
# tonoise,forgradient-basedimagealignment.
# Spatially weighted MI (SWMI) [25] is a version of MI that
# associates each x ∈ X with a weight, modelling the relative ForverysmallimagesBorsetsofdisplacements∣XS∣,orfor
# A large value sets A and B, the direct method may be the bet-
# importanceofthecorrespondingimageelement(anditscontri-
# ter choice. In practice, small or medium sized value sets are
# bution to the relative frequencies). Our here proposed CMIF-
# usually acceptable and the image sizes are often such that the
# algorithm can be generalized to compute SWMI by replacing
# the binary mask M with a weight mask W ∶X → R , and proposedalgorithmisseveralordersofmagnitudesfaster.
# A A A ≥0
# modifyingthelevel-setformulationtoaweightedversion,
# 3.6. Methodforglobalmultimodalalignment
# W (x), for A(x)=a We propose a method for image alignment by global MI
# LW[A](x)={ A }. (13)
# a 0, otherwise maximizationfortransformationswithfewdegreesoffreedom
# (e.g.rigidoraﬃne)bycombiningtheeﬃcientCMIF-algorithm
# proposedinSec.3.2,withgridsearchoverothertransformation
# Wemayfurthergeneralizethisapproachbyconsideringweight
# masks for both images A and B where the weight for a parameterssuchasrotationangle.Relyingonglobalsearch,the
# given x ∈ X and χ ∈ X is taken to be the product, methodcanﬁndtheglobalmaximumwithoutsmoothingofthe
# A S
# w(x)=W (x)⋅T [W ](x). images, which otherwise is commonly performed to increase
# A χ B
# thesizeoftheregionofattractionoftheglobalmaximum,but
# mayleadtoﬁndingasub-optimalsolution[6].
# 3.4. Equivalenceofthecorrelation-basedalgorithmandthedi- Themethod,describedinAlg.1,performsglobalalignment
# rectmethod by taking a set of transformations Ω={T ,...,T } (e.g. se-
# 1 k
# lected from a grid in the parameter space, or through random
# The proposed algorithm uses CC to compute CMIF ex- selection), warping the ﬂoating image (B) for each transfor-
# actly, and identically to the direct method; both involve com- mationusingnearest-neighbor(NN)interpolation,computinga
# puting contributions to the same discrete histogram counts CMIFmapusingtheproposedalgorithm,andlocatingthedis-
# N(χ,A,B), CA(χ,A,B), CB(χ,A,B) andCAB(χ,A,B) for all placement with highest MI. We use NN interpolation to com-
# a b a,b
# a,b and χ ∈ X . The CC (Eq. (7)) computes a sliding inner- pute T(B) since B is assumed to be categorical. A parameter
# S
# product between the two functions. For binary functions (im- γ∈[0,1]controlstherequiredfractionofoverlapcomparedto
# ages) f and g, Eq. (7) yields the number of elements x where the maximal observed overlap; γ is both used to select trans-
# f(x)=g(x+χ)=1, foragivenχ. Hence, theCCoflevel-set formations with suﬃcient overlap, and to control how large
# and level-set, level-set and mask, as well as mask and mask, padding is required. Finally, the resulting transformation is
# givethehistogramentries,foreachχ,asgivenbyEq.(9),(10) takenasthecompositionofthetransformationfromΩandthe
# and (11). These inner-products provide all the quantities re- T ,χ∈X whichleadstothehighestMIwithrequiredoverlap.
# χ S
# quiredforexactcomputationoftheshiftedentropies(Eq.(12)), TheﬁrststepofAlg.1istoquantizetheimagesintosuitably
# andthusforCMIF.Themaindistinctionbetweentheproposed smallnumberoflevelsusingsomeappropriatequantizationap-
# algorithm and the direct method is the order in which the his- proach(unlesstherangesarealreadysuitablediscreterepresen-
# togram counts are computed; the direct method computes the tations). Weusek-meansclustering,whichhasbeenshownto
# histogram entries (N(χ;A,B),CA(χ,A,B), CB(χ,A,B) for all yieldmoreeﬃcientutilizationofthediscretebinsforMI-based
# a b
# a,b,foraﬁxedχ,andtheproposedapproachcomputesthehis- imagealignment[17]thanequisizedbinning. Furthermore, k-
# togramentriesforallχ,forﬁxeda,b,beforeproceeding. means clustering enables the direct application of the method
#
# 5
# Algorithm1ImagealignmentbyglobalMImaximization cytological image dataset consist of 864 and 5040 images re-
# Input: A∶XA→RmA,MA∶XA→{0,1}, spectively, and are both divided into three distinct folds; the
# B∶XB→RmB,MB∶XB→{0,1}, Ω∈{T1,...,Tk}, γ∈[0,1]. histological image dataset consists of a single set of 536 im-
# Output: I∈R≥0,T̂∶Rn→Rn. ages. Theaerialandcytologicalimagesareofsize300×300,
# 1: A←QUANTIZE(A),B←QUANTIZE(B) andthehistologicalimagesareofsize834×834.
# 2: A,MA←ZERO-PAD(A,MA;XB,1−γ)
# 3: I←0,T̂←IDENTITY 5.1. Run-timeanalysis
# 4: forT ∈Ωdo
# 5: N ←γmaxN(χ;A,T(B)) We investigate the run-times of the proposed CMIF-
# χ∈XS algorithm,comparedtoadirecthistogram-basedalgorithm,im-
# 6: χ← argmax CMIF(χ,A,T(B)) plemented in Python/PyTorch, using the built-in PyTorch im-
# χ∈XSs.t.N(χ;A,T(B))≥N
# 7: IT ←CMIF(χ,A,T(B)) plementationforcomputingimagehistogramsontheGPU.The
# 8: ifIT >Ithen algorithms implemented in PyTorch are very similar to meth-
# 9: I←IT,T̂←T○Tχ ods 1 and 2 in [11], where the method is chosen dynamically
# 10: endif basedonthenumberofrequestedbins,andthusenablingafair
# 11: endfor comparisonoftheproposedmethodandthedirectmethod.The
# sort-and-countalgorithmforcomputingthehistograms[11]has
# beenshowntoberelevantmostlyforlargernumberofbins,and
# to multi-channel images, including image pairs with diﬀerent
# thereforewedonotconsiderithere,giventhatweobservethat
# numbersofchannels(denotedm andm ). Forthiswork, we
# A B smallnumberofbinsisshowntoworkwellinthisglobalopti-
# use the mini-batch k-means algorithm [27] which is fast and
# mizationcontext,asseeninSec.5.2.2.
# scalable. Wedenotekthenumberofclustersusedforquantiza-
# tionofbothimages,suchthatk=∣A∣=∣B∣.
# 5.1.1. Experimentalsetup
# In Alg. 1, the reference image A and its mask M are zero-
# A
# paddedwith⌈∣X ∣(1−γ)⌉units(beforeandafter)along(each) We select one of the histological image pairs at ran-
# axisi,where∣XB∣idenotesthesize(diameter)ofthe(rectangu- dom, and crop/pad it to various sizes such that the
# Bi
# side-lengths of the reference image are a power of two
# lar)domainofimageBalongaxisi.
# {128,256,512,1024,2048,4096} and the other (ﬂoating) im-
# For the task of global rigid alignment we run the method
# age is of half the size along each dimension, which is the
# twice: (i)ﬁrstusinggridsearchtoreachacoarsealignmentat
# scenarioencounteredwhenaligningequallysizedimageswith
# anangleθ,(ii)followedbyan(optional)reﬁnementstep,where
# Alg.1andγ=0.5. WecomputetheCMIF-mapforallχ∈X .
# randomsearchisemployedinanintervalaroundthebestangle S
# foundbytheﬁrstgridsearch,samplinguniformlyfromthein- ExperimentsarerunonaNvidiaGeForceGTX2080GPU,
# terval[θ− 2π,θ+ 2π],where∣Ω∣denotesthenumberofangles with11GBofmemory.
# ∣Ω∣ ∣Ω∣ Wealsoapplytheimagealignmentmethod(Alg.1)oncyto-
# intheﬁrstgridsearchstage.
# logicalandhistologicalimages,andmeasuretherun-timefora
# Bothimagealignmenttasks,wherethereferenceandﬂoating
# numberofconﬁgurations,including50,100,and200gridsteps
# images are similar in size, as well as patch retrieval (template
# (with 32 additional reﬁnement angles), with k ∈ {8,16,32},
# matching) tasks, where the reference image is larger than the
# withk-meansbatchsizeof1000andmaxiterations25.
# ﬂoatingimage,canbeeﬃcientlysolveddirectlybyAlg.1.
# 5.1.2. Results
# 4. Implementation
# The results of the run-time performance experiment regard-
# ing computation of a complete CMIF-map are summarized in
# We implement both the proposed CMIF-algorithm, as
# Fig.2. Weobservethattheproposedalgorithmissubstantially
# well as the global image alignment procedure (Alg. 1) in
# Python/PyTorch as a way to utilize parallel processing on a (between 100 times to more than 10000 times) faster than the
# directmethod,andthediﬀerenceisparticularlynoteworthyfor
# GPU.Using Python3.8.8and PyTorch1.8.1, the methodruns
# lownumbersofbins,k∈{2,4,8}.
# almostentirelyontheGPU,includingimagewarping,padding,
# Table 1 shows the run-time for the global rigid alignment
# level-sets,andCC(FFTsandcomplexmultiplication).
# methodforanumberofrealisticconﬁgurations.Forthesmaller
# Mini-batchk-meansclusteringreliesontheprovidedimple-
# cytologicalimages,with8binsinparticular,weobserveperfor-
# mentationinthesklearnpackage[28],version0.24.1.
# mancecompatiblewithreal-timeapplications. Onerigidimage
# alignment for the histological dataset using the direct method
# 5. Performanceanalysis withk=16and200angles+32reﬁnementangles,runsinap-
# proximately 19 hours (compared to 32.9s with the fast CMIF-
# Weconsiderthreedatasets([29]): (i)aerialimages[30]with
# algorithm).
# infrared(IR)asonemodalityandcolorimagesastheother,(ii)
# cytological images [31] with quantitative phase images as one
# 5.2. Rigidimagealignment
# modality and ﬂuorescence images as the other, (iii) histologi-
# cal images [32] with SHG images as one modality and BF as To evaluate the eﬃcacy of the proposed image alignment
# the other, (illustrated in Fig. 1). The aerial image dataset and method, compared to several existing methods, we follow the
#
# 6
# 10000.0 Direct (k=64) 1.0 Aerial
# Direct (k=32) 0.9 Cytological
# Run-time (s) 1101001000....0000 DDPPPrrriiooorreepppccooottsss  ((eeekkddd==   (((18kkk6)===)631426))) uccess-rate00000.....45678 Histological
# 0.1 Proposed (k=8) S0.3
# 0.01 Proposed (k=4) 0.2
# 0.001 Proposed (k=2) 0.1
# 1282 2562 5122 10242 20482 40962 0.0
# Reference image size (px) 2 4 8 16 32 64
# k
# Fig.2:Run-timeoftheproposedCMIF-algorithmforvariousreferenceimage
# Fig.3:Therelationshipbetweensuccess-rateandchoiceofkonthethreeeval-
# sizesandchoicesofk, incomparisontothedirecthistogram-basedmethod,
# uationdatasets.
# implementedinPyTorchandexecutedonaGPU.Weobservethattheproposed
# CMIF-algorithmisseveralordersofmagnitudefasterthanthedirectmethod.
# The empirical run-times of the proposed algorithm exhibits a strong depen-
# 1.0 Aerial
# dencyonk,asexpectedfromEq.(15). Theempiricalrun-timesforthedirect 0.9 Aerial (w. refinement)
# mTbeaetbtwlheeoe1dn:aRsrueucnrhe-tlciamhtioveiecilenysssfetocarobknled∈sw{f.8or.,rt.1g6klo,;3bw2a,le6roi4gb}isd.erivmeadgaetamligonstmaendtiﬀfoerreancneumofbe3r0o%f Success-rate000000......345678 CCHHyyiissttttoooollllooooggggiiiiccccaaaallll  ((ww..  rreeffiinneemmeenntt))
# 0.2
# conﬁgurationsusingimagestakenfromthecytologicalandhistologicaldataset. 0.1
# 0.0
# 25 50 100 150 200 250 300
# Cytological k Histological k Angles
# 8 16 32 8 16 32
# Fig.4: Therelationshipbetweensuccess-rateandthenumberofanglesinthe
# s 50 0.8 2.2 7.3 s 50 4.0 11.8 42.2 gridsearch,usingk=32,bothwith,orwithout,thesubsequentreﬁnementstep.
# e e
# gl 100 1.2 3.4 11.4 gl 100 6.1 18.9 67.9 Inbothcases,theperformanceincreasessubstantiallyupto150anglesforthe
# n n
# A 200 2.2 6.1 22.1 A 200 10.3 32.9 119 threedatasets.
# evaluation protocol of [9], comprising a benchmark for evalu- erations. Weevaluatethemethodonthethreedatasetsusinga
# atingtheeﬀectivenessof2Drigidimagealignmentmethodson set of angle counts {25,50,100,150,200,250,300}, with and
# three distinct datasets. The study includes comparison of four withoutreﬁnementwith32randomlyselectedangles,andmea-
# image-to-image (I2I) translation methods, as well as a state- surethesuccess-rateforeachconﬁguration.
# of-the-art contrastive learning method for modality transfer, We use circular masks, to avoid bias from presence or ab-
# whichareallusedtoattempttotransformthemultimodalalign- senceofthesignalcontentsinthecornersoftheimages.
# ment task into an easier monomodal alignment task, and are
# then combined with either a high-performance intensity-based
# 5.2.2. Results
# method[4]orawell-knownfeature-basedmethod[3]. Finally,
# First we present the performance on the three evaluation
# localoptimization(gradient-based)MIisalsoincluded;itisap-
# datasets(asmeasuredbysuccess-rates)fordiﬀerentchoicesof:
# pliedtomultimodaldatadirectly. Eventhough2Drigidtrans-
# kinFig.3,andanglecountinFig.4;Thesuccess-rateincreases
# formation is among the simplest models, solving these align-
# substantiallyuptok=16,and150angles.
# ment tasks still poses a challenge in the presence of multiple
# Furthermore, we present the performance of the considered
# distinctmodalities. Itisalsoarealistictaskinmicroscopyand
# methods in comparison to a number of alternative methods in
# aerialsettingswhererelativescalebetweentheimagesmaybe
# Tab. 2. The four I2I translation-based methods are combined
# known a priori, or readily estimated, while arbitrary rotations
# intoasinglerow,wherethemaximumsuccess-ratealongeach
# canbeencountered.
# column is shown. The proposed method is the best choice on
# twoofthedatasets(thecytologicalandthehistological)where
# 5.2.1. Experimentalsetup
# it exhibits a substantial improvement over existing methods.
# Following [9], we apply the proposed alignment method on
# CoMIRcombinedwithSIFTreaches100%success-rateonthe
# allthreedatasets. Theperformancemeasureisbasedontheav-
# Zurich dataset, while the proposed method delivers a success-
# erageEuclideandistancebetweenimagecornersconsideredas
# rateof99.8%,whichisbetterthanallincludedintensity-based
# landmarksinthereferenceimagespace,andthecorresponding
# methods.
# recovered landmarks of the aligned ﬂoating image. An align-
# mentisconsideredsuccessfuliftheerrorislessthan2%ofthe
# widthoftheimages[9]. Table2:Successrates(presentedaspercentages)oftheevaluatedmethodson
# rigidalignmenttasksonthreedatasets. Resultsontheaerialandcytological
# Animportantparameteroftheproposedmethodisk,which
# datasetsarepresentedasempiricalmean±std-devoverthethreefolds. Bold
# hasalargeimpactontherun-time(Eq.15)whilealsodirectly
# marksthebestresultoneachdataset.Usedparametersfortheproposedmethod
# inﬂuencing how detailed structures can be represented in the arek=32,γ=0.5,200equispacedanglesin[−π,π]plus32randomreﬁnement
# quantizedrepresentations. Werunthealignmenttaskforallthe angles.Fordetailsaboutthereferencemethods,andtheirconﬁguration,see[9].
# images in the included datasets (aerial, cytological, and histo- Dataset AerialData CytologicalData HistologicalData
# logical), with k ∈ {2,4,8,16,32,64}, with k-means batch size Method α-AMD SIFT α-AMD SIFT α-AMD SIFT
# I2I 80.2±3.9 98.3±0.5 71.1±5.8 24.4±6.2 28.4 0
# of100andmaxiterations100,andmeasurethesuccess-rates. CoMIR 91.8±7.7 100.0±0.0 68.0±14.0 72.5±7.1 81.3 59.3
# The number of angles for the grid search, as well as if in- LocalMI 68.9±3.8 89.9±3.0 47.8
# cluding the reﬁnement step or not, are also important consid- Proposed 99.8±0.4 99.4±0.4 91.2
#
# 7
# 6. DiscussionandConclusion [6] J.P.Pluim, J.A.Maintz, M.A.Viergever, Mutual-information-based
# registrationofmedicalimages: asurvey, IEEETrans.Med.Imag.22
# WepresentanovelfastCMIF-algorithmwhichcomputesMI (2003)986–1004.
# [7] M.P.Heinrich,M.Jenkinson,M.Bhushan,T.Matin,F.V.Gleeson,S.M.
# foralldiscretedisplacementsoftwoimages(similarlyascross-
# Brady,J.A.Schnabel, MIND:Modalityindependentneighbourhoodde-
# correlation). The algorithm works in nD. The proposed algo- scriptorformulti-modaldeformableregistration, Med.ImageAnal.16
# rithmenablesfastglobalalignment(fortransformationmodels (2012)1423–1435.
# withfewdegreesoffreedom),hasveryfewparameters,andis [8] N. Pielawski, E. Wetzer, J. O¨fverstedt, J. Lu, C. Wa¨hlby, J. Lindblad,
# N. Sladoje, CoMIR: Contrastive multimodal image representation for
# straightforwardtoconﬁgurefornewapplications. Quantization
# registration,in:Neur.Inf.Proc.Sys.,volume33,2020,pp.18433–18444.
# ofimagerangeswithk-meansclusteringprovideseﬃcientuse [9] J.Lu,J.O¨fverstedt,J.Lindblad,N.Sladoje, Isimage-to-imagetransla-
# ofalimitednumberofquantizationlevels,andenablesaligning tionthepanaceaformultimodalimageregistration?Acomparativestudy,
# imageswithdiﬀerentnumbersofchannels. arXivpreprintarXiv:2103.16262(2021).
# [10] F.Barrera,F.Lumbreras,A.D.Sappa, Multimodaltemplatematching
# We compare the run-time of the proposed CMIF-algorithm
# basedongradientandmutualinformationusingscale-space, in: IEEE
# with a direct histogram-method (using a fast GPU-based his- Int.Conf.ImageProcess.,IEEE,2010,pp.2749–2752.
# togram algorithm), and observe speed-ups ranging from hun- [11] R.Shams,P.Sadeghi,R.Kennedy,R.Hartley, Parallelcomputationof
# mutualinformationontheGPUwithapplicationtoreal-timeregistration
# dreds of times to more than 10,000 times for practically rele-
# of3dmedicalimages,Comp.Meth.Prog.Biomed.99(2010)133–146.
# vant image sizes, indicating the potential for real-time global
# [12] B.Pompe,P.Blidh,D.Hoyer,M.Eiselt, Usingmutualinformationto
# multimodalalignment. Thepresentedmethodsarehighlypar- measurecouplinginthecardiorespiratorysystem, IEEEEng.Med.Biol.
# allelizable; the work can readily be distributed over multiple Mag.17(1998)32–39.
# [13] A. Paszke, S. Gross, et al., Pytorch: An imperative style, high-
# GPUsorcomputers.
# performancedeeplearninglibrary, AdvancesinNeuralInformationPro-
# Furthermore, we evaluate the performance of the proposed cessingSystems32(2019)8026–8037.
# alignment method on three datasets, and compare it with both [14] C.E.Shannon,Amathematicaltheoryofcommunication,BellSys.Tech.
# gradient-based MI method, and recent methods which rely on Jour.27(1948)379–423.
# [15] W.M.WellsIII,P.Viola,H.Atsumi,S.Nakajima,R.Kikinis, Multi-
# deep learning. We observe excellent performance of the pro-
# modalvolumeregistrationbymaximizationofmutualinformation,Med.
# posed method on all three datasets, and we conclude that it is ImageAnal.1(1996)35–51.
# the overall top performing method, even outperforming state [16] F.Maes,A.Collignon,D.Vandermeulen,G.Marchal,P.Suetens, Mul-
# of the art deep learning-based methods. Finally, the proposed timodality image registration by maximization of mutual information,
# IEEETrans.Med.Imag.16(1997)187–198.
# methoddoesnotrequirealignedimagepairs(oranytraining),
# [17] Z.F.Knops,J.A.Maintz,M.A.Viergever,J.P.Pluim, Normalizedmu-
# andhavefewparameterstotune,whichareadvantagesincom- tualinformationbasedregistrationusingk-meansclusteringandshading
# parisontothedeeplearning-basedmethods. correction,Med.ImageAnal.10(2006)432–439.
# [18] M.Agn,K.VanLeemput,Fastnonparametricmutual-information-based
# Onelimitationoftheproposedmethodisthatitdoesnotsup-
# registrationanduncertaintyestimation, in:Unc.SafeUtil.Mach.Learn.
# port cost-eﬀective sub-pixel alignment. Future work could in-
# Med.Imag.Clin.Image-BasedProc.,Springer,2019,pp.42–51.
# volve application of a suitable reﬁnement step based on local [19] J.Pluim,J.Maintz,M.Viergever, Imageregistrationbymaximization
# optimizationtowardsthisend. ofcombinedmutualinformationandgradientinformation, IEEETrans.
# Med.Imag.19(2000)809–814.
# [20] C.Studholme, D.L.Hill, D.J.Hawkes, Anoverlapinvariantentropy
# measureof3dmedicalimagealignment,Patt.Rec.32(1999)71–86.
# Declarationofcompetinginterests
# [21] R.Shams,N.Barnes,Speedingupmutualinformationcomputationusing
# nvidiacudahardware,in:DICTA2007,IEEE,2007,pp.555–560.
# Theauthorsdeclarenocompetinginterests. [22] M.J.Atallah,Fasterimagetemplatematchinginthesumoftheabsolute
# valueofdiﬀerencesmeasure,IEEETrans.Im.Proc.10(2001)659–663.
# [23] D.-M.Tsai,C.-T.Lin,Fastnormalizedcrosscorrelationfordefectdetec-
# Acknowledgments tion,Patt.Rec.Lett.24(2003)2625–2631.
# [24] S.Paul,U.C.Pati, Acomprehensivereviewonremotesensingimage
# registration,Int.Jour.ofRemoteSensing42(2021)5400–5436.
# ThisworkwassupportedbytheWallenbergAI,Autonomous
# [25] S.B.Park,F.C.Rhee,J.I.Monroe,J.W.Sohn,Spatiallyweightedmutual
# Systems and Software Program (WASP) AI-Math initiative; informationimageregistrationforimageguidedradiationtherapy, Med.
# VINNOVA (MedTech4Health project 2017-02447); and the Phys.37(2010)4590–4601.
# [26] J.W.Cooley,J.W.Tukey, Analgorithmforthemachinecalculationof
# SwedishResearchCouncil(project2017-04385).
# complexfourierseries,Math.Comput.19(1965)297–301.
# [27] D.Sculley, Web-scalek-meansclustering, in: Proc.Int.Conf.World
# wideWeb,2010,pp.1177–1178.
# References
# [28] F.Pedregosa,Varoquaux,etal.,Scikit-learn:MachinelearninginPython,
# Jour.ofMach.Learn.Res.12(2011)2825–2830.
# [1] B.Zitova,J.Flusser,Imageregistrationmethods:asurvey,ImageVision [29] [dataset]J.Lu,J.O¨fverstedt,J.Lindblad,N.Sladoje,2021,Datasetsfor
# Comput.21(2003)977–1000. EvaluationofMultimodalImageRegistration, doi:10.5281/zenodo.
# [2] P.Paul-Gilloteaux,X.Heiligenstein,et.al,ec-clem:ﬂexiblemultidimen- 4587903.
# sionalregistrationsoftwareforcorrelativemicroscopies, Nat.Meth.14 [30] M.Volpi,V.Ferrari, Semanticsegmentationofurbanscenesbylearning
# (2017)102–103. localclassinteractions, in: 2015IEEEConf.Comp.Vis.andPatt.Rec.
# [3] D.Lowe,Objectrecognitionfromlocalscale-invariantfeatures,in:Proc. Works.,2015,pp.1–9.
# IEEEInt.Conf.Comp.Vis.,volume2,1999,pp.1150–1157vol.2. [31] T.Vicar,M.Raudenska,J.Gumulec,J.Balvan, TheQuantitative-Phase
# [4] J.O¨fverstedt,J.Lindblad,N.Sladoje,FastandRobustSymmetricImage DynamicsofApoptosisandLyticCellDeath,Sci.Rep.10(2020)1–12.
# RegistrationBasedonDistancesCombiningIntensityandSpatialInfor- [32] A.Keikhosravi,B.Li,Y.Liu,K.W.Eliceiri, Intensity-basedregistration
# mation,IEEETrans.ImageProcess.28(2019)3584–3597. ofbright-ﬁeldandsecond-harmonicgenerationimagesofhistopathology
# [5] P.Viola,W.M.WellsIII, Alignmentbymaximizationofmutualinfor- tissuesections,Biomed.Opt.Express11(2020)160.
# mation,Int.J.Comp.Vis.24(1997)137–154.

# %% [markdown]
# # Extract all URLs in a website

# %%
import requests
from bs4 import BeautifulSoup
from time import time
from tqdm import tqdm

# %%
class URLExplorer:

    def __init__(self, base_url, is_interesting_url):
        self.reference_dag = {}
        self.base_url = base_url
        self.unexplored_urls = [base_url]
        self.is_interesting_url = is_interesting_url
        self.timings = {}
        self.failed_urls = []

    def get_referenced_urls(self, url):
        request = requests.get(url)
        soup = BeautifulSoup(request.text, "html.parser")
        return [
            link.get("href")
            for link in soup.find_all("a")
            if link.get("href") and self.is_interesting_url(link.get("href"))
        ]

    def explore_url(self, url):
        if url in self.failed_urls:
            return []

        try:
            start = time()
            referenced_urls = self.get_referenced_urls(url)
            end = time()
            self.timings[url] = end - start

        except:
            self.failed_urls.append(url)
            return []

        self.reference_dag[url] = referenced_urls
        self.unexplored_urls += [
            url for url in referenced_urls if url not in self.reference_dag.keys()
        ]
        if url in self.unexplored_urls:
            self.unexplored_urls.remove(url)

    def explore_full_website(self, limit=None):
        with tqdm() as pbar:
            while self.unexplored_urls:
                n_failed = len(self.failed_urls)
                n_explored = len(self.reference_dag.keys()) + n_failed
                n_unexplored = len(self.unexplored_urls)
                n_total = n_explored + n_unexplored
                text = f"We have currently explored {n_explored}/{n_total} URLs ({n_failed} failures"
                if n_failed > 0:
                    text += f",namely {self.failed_urls[-1]})"
                else:
                    text += ")"
                pbar.set_description(text)
                pbar.update(1)
                self.explore_url(self.unexplored_urls.pop())
                if len(self.reference_dag.keys()) > limit:
                    return

    def number_of_connections(self):
        return sum([len(v) for v in self.reference_dag.values()])

    def __repr__(self):
        return f"{self.base_url} Explorer. {len(self.reference_dag.keys())} nodes explored with {self.number_of_connections()} connections"

# %%
def is_interesting_url(url):
    return all(
        [
            url.startswith("https://arxiv.org"),
            "ct?url=" not in url,
            not url.startswith("https://arxiv.org/search"),
            not url.startswith("https://arxiv.org/format"),
        ]
    )


explorer = URLExplorer(
    base_url="https://arxiv.org/", is_interesting_url=is_interesting_url
)
explorer
# Out:
# https://arxiv.org/ Explorer. 0 nodes explored with 0 connections

# %%
explorer.explore_full_website(limit=30)
explorer
# Out:
# We have currently explored 30/445 URLs (0 failures): : 49it [00:59,  1.21s/it]
# https://arxiv.org/ Explorer. 31 nodes explored with 731 connections

# %%
sorted(explorer.timings.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('https://arxiv.org/pdf/2203.03556', 30.036967039108276),
#  ('https://arxiv.org/covid19search', 1.6784424781799316),
#  ('https://arxiv.org/', 0.9685404300689697),
#  ('https://arxiv.org/support/moderation_help', 0.9072434902191162),
#  ('https://arxiv.org/corr/subjectclasses', 0.7228176593780518),
#  ('https://arxiv.org/about', 0.7123024463653564),
#  ('https://arxiv.org/corr', 0.5931897163391113),
#  ('https://arxiv.org/help/submit', 0.5829927921295166),
#  ('https://arxiv.org/help/endorsement#request', 0.5820391178131104),
#  ('https://arxiv.org/help', 0.580359697341919),
#  ('https://arxiv.org/login', 0.5691497325897217),
#  ('https://arxiv.org/help/contact', 0.568894624710083),
#  ('https://arxiv.org/about/people/developers', 0.5512149333953857),
#  ('https://arxiv.org/help/policies/privacy_policy', 0.5424740314483643),
#  ('https://arxiv.org/help/web_accessibility', 0.5417683124542236),
#  ('https://arxiv.org/help/license', 0.5416324138641357),
#  ('https://arxiv.org/help/view', 0.5414862632751465),
#  ('https://arxiv.org/help/email-protection', 0.5378584861755371),
#  ('https://arxiv.org/licenses/nonexclusive-distrib/1.0/', 0.5334033966064453),
#  ('https://arxiv.org/help/subscribe', 0.531207799911499),
#  ('https://arxiv.org/help/registerhelp', 0.5296356678009033),
#  ('https://arxiv.org/help/mathjax', 0.5281879901885986),
#  ('https://arxiv.org/help/moderation', 0.52620530128479),
#  ('https://arxiv.org/help/policies/instructions_for_submission',
#   0.5159857273101807),
#  ('https://arxiv.org/help/policies/submission_agreement', 0.5152199268341064),
#  ('https://arxiv.org/abs/2203.03556', 0.49268031120300293),
#  ('https://arxiv.org/cookies', 0.4484565258026123),
#  ('https://arxiv.org/user/register?submit=Register+for+the+first+time',
#   0.4467332363128662),
#  ('https://arxiv.org/archive/cs', 0.4406931400299072),
#  ('https://arxiv.org/licenses/nonexclusive-distrib/1.0/license.html',
#   0.41458749771118164),
#  ('https://arxiv.org/user/lost_password', 0.41370558738708496)]

# %%
[print(x) for x in explorer.reference_dag.keys()]
# Out:
# https://arxiv.org/
# https://arxiv.org/help/web_accessibility
# https://arxiv.org/help/policies/privacy_policy
# https://arxiv.org/help/license
# https://arxiv.org/help/subscribe
# https://arxiv.org/help/contact
# https://arxiv.org/help
# https://arxiv.org/about
# https://arxiv.org/login
# https://arxiv.org/user/register?submit=Register+for+the+first+time
# https://arxiv.org/user/lost_password
# https://arxiv.org/support/moderation_help
# https://arxiv.org/licenses/nonexclusive-distrib/1.0/
# https://arxiv.org/cookies
# https://arxiv.org/help/view
# https://arxiv.org/help/email-protection
# https://arxiv.org/help/endorsement#request
# https://arxiv.org/help/moderation
# https://arxiv.org/help/policies/instructions_for_submission
# https://arxiv.org/help/policies/submission_agreement
# https://arxiv.org/licenses/nonexclusive-distrib/1.0/license.html
# https://arxiv.org/help/registerhelp
# https://arxiv.org/help/submit
# https://arxiv.org/corr/subjectclasses
# https://arxiv.org/corr
# https://arxiv.org/archive/cs
# https://arxiv.org/covid19search
# https://arxiv.org/abs/2203.03556
# https://arxiv.org/help/mathjax
# https://arxiv.org/about/people/developers
# https://arxiv.org/abs/2203.03556v1
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
