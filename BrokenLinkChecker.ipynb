# %% [markdown]
# # Setup

# %%
from urllib.parse import urljoin, urlparse
import pandas as pd
import requests
from bs4 import BeautifulSoup
from tqdm.auto import tqdm

# %% [markdown]
# # Helper functions

# %%
def get_links_to_internal_urls(path, netloc):
    url = urljoin(f"https://{netloc}",path)
    response = requests.get(url)
    if response.status_code != 200:
        message = f'HTTP {response.status_code}: {url} '
        print(message)
        raise ValueError(message)
    soup = BeautifulSoup(
        response.content,
        'html.parser'
    )
    links = [urlparse(l.get("href")) for l in soup.find_all('a') if l is not None and l.get("href") is not None]
    return [
        l.path for l in links
        if l.netloc=='' or l.netloc == netloc
    ]

def print_urls(url_list):
    return sorted([urljoin(f"https://{netloc}",l) for l in list(url_list)])

# %%
urlparse('void(0)')
# Out:
# ParseResult(scheme='', netloc='', path='void(0)', params='', query='', fragment='')

# %% [markdown]
# # Goal
#
# We want to quickly get all broken URLs from a website. The steps will be
# 1. Submit the base URL
# 2. Recursively follow the links to get an exhaustive list of all pages
# 3. If a webpage returns a non 200 result, add it to the list of broken URLs

# %%
starting_url = urlparse('https://collapsedwave.com/')
netloc = starting_url.netloc
results = pd.DataFrame(
    data=[[False, False]],
    columns=["crawled", "broken"], index=[starting_url.path]
)
results
# Out:
#    crawled  broken
# /    False   False

# %%
with tqdm() as pbar:
    while not results[results["crawled"]==False].empty:
        current_url = results[results["crawled"]==False].index[0]
        try:
            new_links = get_links_to_internal_urls(path=current_url, netloc=netloc)
            new_urls = set(new_links).difference(set(results.index))
            # print(urljoin(f"https://{netloc}", current_url))
            # print(new_urls)
            for new_url in new_urls:
                results.loc[new_url] = [False, False]
            results.loc[current_url] = [True, False]
        except:
            results.loc[current_url] = [True, True]
        pbar.update(1)
        seen = results[results['crawled']==True].shape[0]
        failed = results[results['broken']==True].shape[0]
        remaining = results[results['crawled']==False].shape[0]
        pbar.set_description(f"{seen} seen | {failed} failed | {remaining} remaining")
# Out:
# 0it [00:00, ?it/s]
# HTTP 404: https://collapsedwave.com/Riesz-Representation-Theorem
# HTTP 404: https://collapsedwave.com/Implicit-Function-Theorem
# HTTP 404: https://collapsedwave.com/Diffeomorphism
# /opt/conda/lib/python3.11/site-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# HTTP 404: https://collapsedwave.com/qubit
# HTTP 404: https://collapsedwave.com/anti-commutative
# HTTP 404: https://collapsedwave.com/Jacobi-identity
# HTTP 404: https://collapsedwave.com/quantum-state-vector
# HTTP 404: https://collapsedwave.com/real-line
# HTTP 404: https://collapsedwave.com/supremum-operator
# HTTP 404: https://collapsedwave.com/conjugate
# HTTP 404: https://collapsedwave.com/interval
# HTTP 404: https://collapsedwave.com/Plancks-reduced-constant
# HTTP 404: https://collapsedwave.com/wave-function
# HTTP 404: https://collapsedwave.com/unit-vector
# HTTP 404: https://collapsedwave.com/quantum-system-state
# HTTP 404: https://collapsedwave.com/scalar-field
# HTTP 404: https://collapsedwave.com/triangle-inequality
# HTTP 404: https://collapsedwave.com/scalar
# HTTP 404: https://collapsedwave.com/subfield
# HTTP 404: https://collapsedwave.com/point-separation
# HTTP 404: https://collapsedwave.com/absolute-homogeneity
# HTTP 404: https://collapsedwave.com/vector
# HTTP 404: https://collapsedwave.com/complex-numbers
# HTTP 404: https://collapsedwave.com/cauchy-sequence
# HTTP 404: https://collapsedwave.com/field
# HTTP 404: https://collapsedwave.com/binary-operation
# HTTP 404: https://collapsedwave.com/Leibniz-rule
# HTTP 404: https://collapsedwave.com/bilinear
# HTTP 404: https://collapsedwave.com/graph
# HTTP 404: https://collapsedwave.com/Python
# HTTP 404: https://collapsedwave.com/density-matrix
# HTTP 404: https://collapsedwave.com/force
# HTTP 404: https://collapsedwave.com/matrix
# HTTP 404: https://collapsedwave.com/determinant
# HTTP 404: https://collapsedwave.com/quantum-theory
# HTTP 404: https://collapsedwave.com/core-distance
# HTTP 404: https://collapsedwave.com/Prims-algorithm
# HTTP 404: https://collapsedwave.com/clustering-algorithm
# HTTP 404: https://collapsedwave.com/Dual-Tree-Boruvka
# HTTP 404: https://collapsedwave.com/DBSCAN
# HTTP 404: https://collapsedwave.com/mutual-reachability-distance
# HTTP 404: https://collapsedwave.com/quantum-system
# HTTP 404: https://collapsedwave.com/measurement
# HTTP 404: https://collapsedwave.com/Linear-Operator
# HTTP 404: https://collapsedwave.com/📘-Hermitian-Operator
# HTTP 404: https://collapsedwave.com/braket-notation
# HTTP 404: https://collapsedwave.com/Operator
# HTTP 404: https://collapsedwave.com/acceleration
# HTTP 404: https://collapsedwave.com/mass
# HTTP 404: https://collapsedwave.com/Equation-of-motion
# HTTP 404: https://collapsedwave.com/Hooke`s-law
# HTTP 404: https://collapsedwave.com/dampening-factor
# HTTP 404: https://collapsedwave.com/k-ary-search-tree
# HTTP 404: https://collapsedwave.com/velocity
# HTTP 404: https://collapsedwave.com/supervised-learning
# HTTP 404: https://collapsedwave.com/subspace
# HTTP 404: https://collapsedwave.com/linearly-independent-basis
# HTTP 404: https://collapsedwave.com/orthonormal-basis
# HTTP 404: https://collapsedwave.com/Phase-gate
# HTTP 404: https://collapsedwave.com/cryptographic-hash
# HTTP 404: https://collapsedwave.com/Energy-function
# HTTP 404: https://collapsedwave.com/Smooth-Curve
# HTTP 404: https://collapsedwave.com/Critical-Points
# HTTP 404: https://collapsedwave.com/Artificial-Neural-Network
# HTTP 404: https://collapsedwave.com/EPR
# HTTP 404: https://collapsedwave.com/CNOT
# HTTP 404: https://collapsedwave.com/Partial-Derivative
# HTTP 404: https://collapsedwave.com/path
# HTTP 404: https://collapsedwave.com/undirected-graph
# HTTP 404: https://collapsedwave.com/Jordan-Networks
# HTTP 404: https://collapsedwave.com/Elman-Networks
# HTTP 404: https://collapsedwave.com/Fully-recurrent-neural-networks
# HTTP 404: https://collapsedwave.com/binary-classification
# HTTP 404: https://collapsedwave.com/F1-score
# HTTP 404: https://collapsedwave.com/quantum-error-correction
# HTTP 404: https://collapsedwave.com/integrable-function
# HTTP 404: https://collapsedwave.com/Lebesgue-measure
# HTTP 404: https://collapsedwave.com/Hamilton's-Equations
# HTTP 404: https://collapsedwave.com/complex-conjugate

# %%
# Broken
print_urls(results[results["broken"]==True].index)
# Out:
# ['https://collapsedwave.com/Artificial-Neural-Network',
#  'https://collapsedwave.com/CNOT',
#  'https://collapsedwave.com/Critical-Points',
#  'https://collapsedwave.com/DBSCAN',
#  'https://collapsedwave.com/Diffeomorphism',
#  'https://collapsedwave.com/Dual-Tree-Boruvka',
#  'https://collapsedwave.com/EPR',
#  'https://collapsedwave.com/Elman-Networks',
#  'https://collapsedwave.com/Energy-function',
#  'https://collapsedwave.com/Equation-of-motion',
#  'https://collapsedwave.com/F1-score',
#  'https://collapsedwave.com/Fully-recurrent-neural-networks',
#  "https://collapsedwave.com/Hamilton's-Equations",
#  'https://collapsedwave.com/Hooke`s-law',
#  'https://collapsedwave.com/Implicit-Function-Theorem',
#  'https://collapsedwave.com/Jacobi-identity',
#  'https://collapsedwave.com/Jordan-Networks',
#  'https://collapsedwave.com/Lebesgue-measure',
#  'https://collapsedwave.com/Leibniz-rule',
#  'https://collapsedwave.com/Linear-Operator',
#  'https://collapsedwave.com/Operator',
#  'https://collapsedwave.com/Partial-Derivative',
#  'https://collapsedwave.com/Phase-gate',
#  'https://collapsedwave.com/Plancks-reduced-constant',
#  'https://collapsedwave.com/Prims-algorithm',
#  'https://collapsedwave.com/Python',
#  'https://collapsedwave.com/Riesz-Representation-Theorem',
#  'https://collapsedwave.com/Smooth-Curve',
#  'https://collapsedwave.com/absolute-homogeneity',
#  'https://collapsedwave.com/acceleration',
#  'https://collapsedwave.com/anti-commutative',
#  'https://collapsedwave.com/bilinear',
#  'https://collapsedwave.com/binary-classification',
#  'https://collapsedwave.com/binary-operation',
#  'https://collapsedwave.com/braket-notation',
#  'https://collapsedwave.com/cauchy-sequence',
#  'https://collapsedwave.com/clustering-algorithm',
#  'https://collapsedwave.com/complex-conjugate',
#  'https://collapsedwave.com/complex-numbers',
#  'https://collapsedwave.com/conjugate',
#  'https://collapsedwave.com/core-distance',
#  'https://collapsedwave.com/cryptographic-hash',
#  'https://collapsedwave.com/dampening-factor',
#  'https://collapsedwave.com/density-matrix',
#  'https://collapsedwave.com/determinant',
#  'https://collapsedwave.com/field',
#  'https://collapsedwave.com/force',
#  'https://collapsedwave.com/graph',
#  'https://collapsedwave.com/integrable-function',
#  'https://collapsedwave.com/interval',
#  'https://collapsedwave.com/k-ary-search-tree',
#  'https://collapsedwave.com/linearly-independent-basis',
#  'https://collapsedwave.com/mass',
#  'https://collapsedwave.com/matrix',
#  'https://collapsedwave.com/measurement',
#  'https://collapsedwave.com/mutual-reachability-distance',
#  'https://collapsedwave.com/orthonormal-basis',
#  'https://collapsedwave.com/path',
#  'https://collapsedwave.com/point-separation',
#  'https://collapsedwave.com/quantum-error-correction',
#  'https://collapsedwave.com/quantum-state-vector',
#  'https://collapsedwave.com/quantum-system',
#  'https://collapsedwave.com/quantum-system-state',
#  'https://collapsedwave.com/quantum-theory',
#  'https://collapsedwave.com/qubit',
#  'https://collapsedwave.com/real-line',
#  'https://collapsedwave.com/scalar',
#  'https://collapsedwave.com/scalar-field',
#  'https://collapsedwave.com/subfield',
#  'https://collapsedwave.com/subspace',
#  'https://collapsedwave.com/supervised-learning',
#  'https://collapsedwave.com/supremum-operator',
#  'https://collapsedwave.com/triangle-inequality',
#  'https://collapsedwave.com/undirected-graph',
#  'https://collapsedwave.com/unit-vector',
#  'https://collapsedwave.com/vector',
#  'https://collapsedwave.com/velocity',
#  'https://collapsedwave.com/wave-function',
#  'https://collapsedwave.com/📘-Hermitian-Operator']

# %%
# External URLs
[u for u in results.index if not urlparse(u).path.startswith('/')]
# Out:
# ['',
#  './📘-Block-Sphere',
#  './📘-Ubiquitous-Language',
#  './📘-Commutator',
#  './📘-Jacobian',
#  './📙-Differential-Equations',
#  './📘-Quantum-observable',
#  './📙-Legendre-Transform',
#  './📘-Quantum-Hilbert-Space',
#  './📘-Gradient',
#  './📘-Vector-Space',
#  './📘-Poisson-bracket',
#  './📘-Spanning-tree',
#  './📘-Vector-field',
#  './📘-Frequency-of-Oscillation',
#  './📘-Gauge-Theory',
#  './📙-Trotterization',
#  './📘-Entropy',
#  './📘-Potential-energy',
#  './📘-Pauli-Matrix',
#  './📘-Quantum-Field-Theory',
#  './📘-Curl',
#  './📙-HDBSCAN',
#  './📕-Postulates-of-Quantum-Mechanics',
#  './Riesz-Representation-Theorem',
#  './📘-Linear-Operator',
#  './📗-Newtons-law',
#  './📗-No-cloning-theorem',
#  './📘-Harmonic-Oscillator',
#  './📘-Damped-Harmonic-Oscillator',
#  './📘-Trie',
#  './📘-Convex-function',
#  './📘-Minimum-spanning-tree',
#  './📘-Trajectory',
#  './Implicit-Function-Theorem',
#  './📘-Kinetic-energy',
#  './📘-Metric-space',
#  './📘-Del-or-Nabla',
#  './📘-Hamiltonian-Operator',
#  './📙-k-Nearest-Neighbours',
#  './📘-Conservative-force',
#  './📘-Laplacian',
#  './📘-Measurement-uncertainty',
#  './📘-Qudit',
#  './📘-Direct-Sum',
#  './📗-Heisenberg-Uncertainty-Principle',
#  './📘-Distance',
#  './📙-Gram–Schmidt',
#  './📗-Stokes-theorem',
#  './📘-Quantum-Gate',
#  './📘-Expectation-value',
#  './Diffeomorphism',
#  './📘-Merkle-Tree',
#  './📘-Total-Energy',
#  './📘-Constant-of-Motion',
#  './Help-me❓',
#  './📘-Level-Curve',
#  './📘-Classical-observable',
#  './📘-Conjugate-variable',
#  '.',
#  './📘-Convolutional-Neural-Network',
#  './📙-Quantum-Teleportation',
#  './📘-Total-derivative',
#  './📘-Bose-Einstein-condensate',
#  './📕-Maxwell-Equations',
#  './📘-Tree',
#  './📘-Divergence',
#  './📘-Recurrent-Neural-Network',
#  './📙-Decomposing-Operators',
#  './📘-F-score',
#  './📘-Coherent-state',
#  './📘-Fourier-Transform',
#  './📘-Flow',
#  './📘-Inner-Product',
#  './qubit',
#  './tags/quantum-theory',
#  './anti-commutative',
#  './Jacobi-identity',
#  './tags/math',
#  './quantum-state-vector',
#  './real-line',
#  './supremum-operator',
#  './conjugate',
#  './interval',
#  './Plancks-reduced-constant',
#  './wave-function',
#  './unit-vector',
#  './quantum-system-state',
#  './scalar-field',
#  './triangle-inequality',
#  './scalar',
#  './subfield',
#  './point-separation',
#  './absolute-homogeneity',
#  './vector',
#  './complex-numbers',
#  './cauchy-sequence',
#  './field',
#  './binary-operation',
#  './Leibniz-rule',
#  './bilinear',
#  './tags/graph-theory',
#  './graph',
#  './tags/classical-mechanics',
#  './tags/physics',
#  './Python',
#  './density-matrix',
#  './force',
#  './matrix',
#  './determinant',
#  './quantum-theory',
#  './core-distance',
#  './Prims-algorithm',
#  './tags/machine-learning',
#  './clustering-algorithm',
#  './Dual-Tree-Boruvka',
#  './DBSCAN',
#  './mutual-reachability-distance',
#  './quantum-system',
#  './measurement',
#  './Linear-Operator',
#  './📘-Hermitian-Operator',
#  './braket-notation',
#  './Operator',
#  './acceleration',
#  './mass',
#  './Equation-of-motion',
#  './Hooke`s-law',
#  './dampening-factor',
#  './k-ary-search-tree',
#  './tags/definition',
#  './velocity',
#  './supervised-learning',
#  './subspace',
#  './linearly-independent-basis',
#  './orthonormal-basis',
#  './Phase-gate',
#  './cryptographic-hash',
#  './Energy-function',
#  './Smooth-Curve',
#  './Critical-Points',
#  './Artificial-Neural-Network',
#  './EPR',
#  './CNOT',
#  './Partial-Derivative',
#  './path',
#  './undirected-graph',
#  './Jordan-Networks',
#  './Elman-Networks',
#  './Fully-recurrent-neural-networks',
#  './binary-classification',
#  './F1-score',
#  './quantum-error-correction',
#  './integrable-function',
#  './Lebesgue-measure',
#  "./Hamilton's-Equations",
#  './complex-conjugate',
#  '../📘-Coherent-state',
#  '../📗-Heisenberg-Uncertainty-Principle',
#  '../📘-Commutator',
#  '../📘-Quantum-Gate',
#  '../📙-Quantum-Teleportation',
#  '../📘-Conjugate-variable',
#  '../📘-Quantum-observable',
#  '..',
#  '../📕-Postulates-of-Quantum-Mechanics',
#  '../tags/physics',
#  '../📘-Flow',
#  '../📙-Trotterization',
#  '../📘-Poisson-bracket',
#  '../📘-Quantum-Field-Theory',
#  '../📗-No-cloning-theorem',
#  '../📘-Bose-Einstein-condensate',
#  '../tags/quantum-theory',
#  '../📘-Block-Sphere',
#  '../📘-Qudit',
#  '../📘-Pauli-Matrix',
#  '../tags/math',
#  '../📙-Differential-Equations',
#  '../📘-Minimum-spanning-tree',
#  '../📘-Spanning-tree',
#  '../📘-Tree',
#  '../📘-Merkle-Tree',
#  '../tags/graph-theory',
#  '../📘-Trie',
#  '../📘-Frequency-of-Oscillation',
#  '../tags/classical-mechanics',
#  '../📘-Constant-of-Motion',
#  '../📘-Trajectory',
#  '../📘-Kinetic-energy',
#  '../📘-Damped-Harmonic-Oscillator',
#  '../📘-Hamiltonian-Operator',
#  '../📘-Harmonic-Oscillator',
#  '../📕-Maxwell-Equations',
#  '../📘-Potential-energy',
#  '../📘-Gauge-Theory',
#  '../📘-Entropy',
#  '../📙-HDBSCAN',
#  '../📘-Convolutional-Neural-Network',
#  '../tags/machine-learning',
#  '../📘-Recurrent-Neural-Network',
#  '../📙-k-Nearest-Neighbours',
#  '../📘-F-score',
#  '../tags/definition',
#  '../📘-Convex-function']

# %%
# Success
print_urls(results[results["broken"]==False].index)
# Out:
# ['https://collapsedwave.com',
#  'https://collapsedwave.com/',
#  'https://collapsedwave.com/',
#  'https://collapsedwave.com/',
#  'https://collapsedwave.com/Help-me❓',
#  'https://collapsedwave.com/index.xml',
#  'https://collapsedwave.com/tags/classical-mechanics',
#  'https://collapsedwave.com/tags/classical-mechanics',
#  'https://collapsedwave.com/tags/definition',
#  'https://collapsedwave.com/tags/definition',
#  'https://collapsedwave.com/tags/graph-theory',
#  'https://collapsedwave.com/tags/graph-theory',
#  'https://collapsedwave.com/tags/machine-learning',
#  'https://collapsedwave.com/tags/machine-learning',
#  'https://collapsedwave.com/tags/math',
#  'https://collapsedwave.com/tags/math',
#  'https://collapsedwave.com/tags/physics',
#  'https://collapsedwave.com/tags/physics',
#  'https://collapsedwave.com/tags/quantum-theory',
#  'https://collapsedwave.com/tags/quantum-theory',
#  'https://collapsedwave.com/📕-Maxwell-Equations',
#  'https://collapsedwave.com/📕-Maxwell-Equations',
#  'https://collapsedwave.com/📕-Postulates-of-Quantum-Mechanics',
#  'https://collapsedwave.com/📕-Postulates-of-Quantum-Mechanics',
#  'https://collapsedwave.com/📗-Heisenberg-Uncertainty-Principle',
#  'https://collapsedwave.com/📗-Heisenberg-Uncertainty-Principle',
#  'https://collapsedwave.com/📗-Newtons-law',
#  'https://collapsedwave.com/📗-No-cloning-theorem',
#  'https://collapsedwave.com/📗-No-cloning-theorem',
#  'https://collapsedwave.com/📗-Stokes-theorem',
#  'https://collapsedwave.com/📘-Block-Sphere',
#  'https://collapsedwave.com/📘-Block-Sphere',
#  'https://collapsedwave.com/📘-Bose-Einstein-condensate',
#  'https://collapsedwave.com/📘-Bose-Einstein-condensate',
#  'https://collapsedwave.com/📘-Classical-observable',
#  'https://collapsedwave.com/📘-Coherent-state',
#  'https://collapsedwave.com/📘-Coherent-state',
#  'https://collapsedwave.com/📘-Commutator',
#  'https://collapsedwave.com/📘-Commutator',
#  'https://collapsedwave.com/📘-Conjugate-variable',
#  'https://collapsedwave.com/📘-Conjugate-variable',
#  'https://collapsedwave.com/📘-Conservative-force',
#  'https://collapsedwave.com/📘-Constant-of-Motion',
#  'https://collapsedwave.com/📘-Constant-of-Motion',
#  'https://collapsedwave.com/📘-Convex-function',
#  'https://collapsedwave.com/📘-Convex-function',
#  'https://collapsedwave.com/📘-Convolutional-Neural-Network',
#  'https://collapsedwave.com/📘-Convolutional-Neural-Network',
#  'https://collapsedwave.com/📘-Curl',
#  'https://collapsedwave.com/📘-Damped-Harmonic-Oscillator',
#  'https://collapsedwave.com/📘-Damped-Harmonic-Oscillator',
#  'https://collapsedwave.com/📘-Del-or-Nabla',
#  'https://collapsedwave.com/📘-Direct-Sum',
#  'https://collapsedwave.com/📘-Distance',
#  'https://collapsedwave.com/📘-Divergence',
#  'https://collapsedwave.com/📘-Entropy',
#  'https://collapsedwave.com/📘-Entropy',
#  'https://collapsedwave.com/📘-Expectation-value',
#  'https://collapsedwave.com/📘-F-score',
#  'https://collapsedwave.com/📘-F-score',
#  'https://collapsedwave.com/📘-Flow',
#  'https://collapsedwave.com/📘-Flow',
#  'https://collapsedwave.com/📘-Fourier-Transform',
#  'https://collapsedwave.com/📘-Frequency-of-Oscillation',
#  'https://collapsedwave.com/📘-Frequency-of-Oscillation',
#  'https://collapsedwave.com/📘-Gauge-Theory',
#  'https://collapsedwave.com/📘-Gauge-Theory',
#  'https://collapsedwave.com/📘-Gradient',
#  'https://collapsedwave.com/📘-Hamiltonian-Operator',
#  'https://collapsedwave.com/📘-Hamiltonian-Operator',
#  'https://collapsedwave.com/📘-Harmonic-Oscillator',
#  'https://collapsedwave.com/📘-Harmonic-Oscillator',
#  'https://collapsedwave.com/📘-Inner-Product',
#  'https://collapsedwave.com/📘-Jacobian',
#  'https://collapsedwave.com/📘-Kinetic-energy',
#  'https://collapsedwave.com/📘-Kinetic-energy',
#  'https://collapsedwave.com/📘-Laplacian',
#  'https://collapsedwave.com/📘-Level-Curve',
#  'https://collapsedwave.com/📘-Linear-Operator',
#  'https://collapsedwave.com/📘-Measurement-uncertainty',
#  'https://collapsedwave.com/📘-Merkle-Tree',
#  'https://collapsedwave.com/📘-Merkle-Tree',
#  'https://collapsedwave.com/📘-Metric-space',
#  'https://collapsedwave.com/📘-Minimum-spanning-tree',
#  'https://collapsedwave.com/📘-Minimum-spanning-tree',
#  'https://collapsedwave.com/📘-Pauli-Matrix',
#  'https://collapsedwave.com/📘-Pauli-Matrix',
#  'https://collapsedwave.com/📘-Poisson-bracket',
#  'https://collapsedwave.com/📘-Poisson-bracket',
#  'https://collapsedwave.com/📘-Potential-energy',
#  'https://collapsedwave.com/📘-Potential-energy',
#  'https://collapsedwave.com/📘-Quantum-Field-Theory',
#  'https://collapsedwave.com/📘-Quantum-Field-Theory',
#  'https://collapsedwave.com/📘-Quantum-Gate',
#  'https://collapsedwave.com/📘-Quantum-Gate',
#  'https://collapsedwave.com/📘-Quantum-Hilbert-Space',
#  'https://collapsedwave.com/📘-Quantum-observable',
#  'https://collapsedwave.com/📘-Quantum-observable',
#  'https://collapsedwave.com/📘-Qudit',
#  'https://collapsedwave.com/📘-Qudit',
#  'https://collapsedwave.com/📘-Recurrent-Neural-Network',
#  'https://collapsedwave.com/📘-Recurrent-Neural-Network',
#  'https://collapsedwave.com/📘-Spanning-tree',
#  'https://collapsedwave.com/📘-Spanning-tree',
#  'https://collapsedwave.com/📘-Total-Energy',
#  'https://collapsedwave.com/📘-Total-derivative',
#  'https://collapsedwave.com/📘-Trajectory',
#  'https://collapsedwave.com/📘-Trajectory',
#  'https://collapsedwave.com/📘-Tree',
#  'https://collapsedwave.com/📘-Tree',
#  'https://collapsedwave.com/📘-Trie',
#  'https://collapsedwave.com/📘-Trie',
#  'https://collapsedwave.com/📘-Ubiquitous-Language',
#  'https://collapsedwave.com/📘-Vector-Space',
#  'https://collapsedwave.com/📘-Vector-field',
#  'https://collapsedwave.com/📙-Decomposing-Operators',
#  'https://collapsedwave.com/📙-Differential-Equations',
#  'https://collapsedwave.com/📙-Differential-Equations',
#  'https://collapsedwave.com/📙-Gram–Schmidt',
#  'https://collapsedwave.com/📙-HDBSCAN',
#  'https://collapsedwave.com/📙-HDBSCAN',
#  'https://collapsedwave.com/📙-Legendre-Transform',
#  'https://collapsedwave.com/📙-Quantum-Teleportation',
#  'https://collapsedwave.com/📙-Quantum-Teleportation',
#  'https://collapsedwave.com/📙-Trotterization',
#  'https://collapsedwave.com/📙-Trotterization',
#  'https://collapsedwave.com/📙-k-Nearest-Neighbours',
#  'https://collapsedwave.com/📙-k-Nearest-Neighbours']

# %%
get_links_to_internal_urls('void(0)', netloc)
# Out:
# HTTP 404: https://collapsedwave.com/void(0)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 get_links_to_internal_urls('void(0)', netloc)
#
# Cell In[2], line 7, in get_links_to_internal_urls(path, netloc)
#       5     message = f'HTTP {response.status_code}: {url} '
#       6     print(message)
# ----> 7     raise ValueError(message)
#       8 soup = BeautifulSoup(
#       9     response.content,
#      10     'html.parser'
#      11 )
#      12 links = [urlparse(l.get("href")) for l in soup.find_all('a') if l is not None and l.get("href") is not None]
#
# ValueError: HTTP 404: https://collapsedwave.com/void(0)
