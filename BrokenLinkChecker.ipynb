# %% [markdown]
# # Setup

# %%
from urllib.parse import urljoin, urlparse
from IPython.display import HTML
import pandas as pd
import requests
from bs4 import BeautifulSoup
from tqdm.auto import tqdm

# %% [markdown]
# # Helper functions

# %%
def get_links_to_internal_urls(path, netloc):
    url = urljoin(f"https://{netloc}",path)
    response = requests.get(url)
    if response.status_code != 200:
        message = f'HTTP {response.status_code}: {url} '
        print(message)
        raise ValueError(message)
    soup = BeautifulSoup(
        response.content,
        'html.parser'
    )
    links = [urlparse(l.get("href")) for l in soup.find_all('a') if l is not None and l.get("href") is not None]
    return [
        l.path for l in links
        if l.netloc=='' or l.netloc == netloc
    ]

def show_urls(url_list):
    return HTML(url_list.sort_index().to_html(render_links=True, escape=False))

# %% [markdown]
# # Goal
#
# We want to quickly get all broken URLs from a website. The steps will be
# 1. Submit the base URL
# 2. Recursively follow the links to get an exhaustive list of all pages
# 3. If a webpage returns a non 200 result, add it to the list of broken URLs

# %%
starting_url = urlparse('https://collapsedwave.com/')
netloc = starting_url.netloc
results = pd.DataFrame(
    data=[[False, False]],
    columns=["crawled", "broken"], index=[starting_url.path]
)
results
# Out:
#    crawled  broken
# /    False   False

# %%
with tqdm() as pbar:
    while not results[results["crawled"]==False].empty:
        current_url = results[results["crawled"]==False].index[0]
        try:
            new_links = get_links_to_internal_urls(path=current_url, netloc=netloc)
            new_urls = set(new_links).difference(set(results.index))
            # print(urljoin(f"https://{netloc}", current_url))
            # print(new_urls)
            for new_url in new_urls:
                results.loc[new_url] = [False, False]
            results.loc[current_url] = [True, False]
        except:
            results.loc[current_url] = [True, True]
        pbar.update(1)
        seen = results[results['crawled']==True].shape[0]
        failed = results[results['broken']==True].shape[0]
        remaining = results[results['crawled']==False].shape[0]
        pbar.total = seen + failed + remaining
        pbar.set_description(f"{seen} seen | {failed} failed | {remaining} remaining")

# Adds the complete url after building the fully explored graph
results["url"] = [urljoin(f"https://{netloc}",l) for l in list(results.index)]
# Out:
# 0it [00:00, ?it/s]
# HTTP 404: https://collapsedwave.com/Diffeomorphism
# /opt/conda/lib/python3.11/site-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# HTTP 404: https://collapsedwave.com/Riesz-Representation-Theorem
# HTTP 404: https://collapsedwave.com/Implicit-Function-Theorem
# HTTP 404: https://collapsedwave.com/acceleration
# HTTP 404: https://collapsedwave.com/mass
# HTTP 404: https://collapsedwave.com/force
# HTTP 404: https://collapsedwave.com/wave-function
# HTTP 404: https://collapsedwave.com/quantum-state-vector
# HTTP 404: https://collapsedwave.com/unit-vector
# HTTP 404: https://collapsedwave.com/quantum-system-state
# HTTP 404: https://collapsedwave.com/Plancks-reduced-constant
# HTTP 404: https://collapsedwave.com/cauchy-sequence
# HTTP 404: https://collapsedwave.com/point-separation
# HTTP 404: https://collapsedwave.com/triangle-inequality
# HTTP 404: https://collapsedwave.com/vector
# HTTP 404: https://collapsedwave.com/field
# HTTP 404: https://collapsedwave.com/scalar
# HTTP 404: https://collapsedwave.com/absolute-homogeneity
# HTTP 404: https://collapsedwave.com/binary-operation
# HTTP 404: https://collapsedwave.com/subfield
# HTTP 404: https://collapsedwave.com/complex-numbers
# HTTP 404: https://collapsedwave.com/scalar-field
# HTTP 404: https://collapsedwave.com/qubit
# HTTP 404: https://collapsedwave.com/Partial-Derivative
# HTTP 404: https://collapsedwave.com/quantum-error-correction
# HTTP 404: https://collapsedwave.com/complex-conjugate
# HTTP 404: https://collapsedwave.com/supervised-learning
# HTTP 404: https://collapsedwave.com/measurement
# HTTP 404: https://collapsedwave.com/Operator
# HTTP 404: https://collapsedwave.com/Jordan-Networks
# HTTP 404: https://collapsedwave.com/Fully-recurrent-neural-networks
# HTTP 404: https://collapsedwave.com/Artificial-Neural-Network
# HTTP 404: https://collapsedwave.com/Elman-Networks
# HTTP 404: https://collapsedwave.com/Phase-gate
# HTTP 404: https://collapsedwave.com/Jacobi-identity
# HTTP 404: https://collapsedwave.com/Leibniz-rule
# HTTP 404: https://collapsedwave.com/anti-commutative
# HTTP 404: https://collapsedwave.com/bilinear
# HTTP 404: https://collapsedwave.com/core-distance
# HTTP 404: https://collapsedwave.com/Dual-Tree-Boruvka
# HTTP 404: https://collapsedwave.com/clustering-algorithm
# HTTP 404: https://collapsedwave.com/DBSCAN
# HTTP 404: https://collapsedwave.com/Prims-algorithm
# HTTP 404: https://collapsedwave.com/mutual-reachability-distance
# HTTP 404: https://collapsedwave.com/Linear-Operator
# HTTP 404: https://collapsedwave.com/📘-Hermitian-Operator
# HTTP 404: https://collapsedwave.com/braket-notation
# HTTP 404: https://collapsedwave.com/undirected-graph
# HTTP 404: https://collapsedwave.com/path
# HTTP 404: https://collapsedwave.com/k-ary-search-tree
# HTTP 404: https://collapsedwave.com/F1-score
# HTTP 404: https://collapsedwave.com/binary-classification
# HTTP 404: https://collapsedwave.com/linearly-independent-basis
# HTTP 404: https://collapsedwave.com/orthonormal-basis
# HTTP 404: https://collapsedwave.com/dampening-factor
# HTTP 404: https://collapsedwave.com/Equation-of-motion
# HTTP 404: https://collapsedwave.com/Hamilton's-Equations
# HTTP 404: https://collapsedwave.com/density-matrix
# HTTP 404: https://collapsedwave.com/matrix
# HTTP 404: https://collapsedwave.com/determinant
# HTTP 404: https://collapsedwave.com/cryptographic-hash
# HTTP 404: https://collapsedwave.com/quantum-theory
# HTTP 404: https://collapsedwave.com/Python
# HTTP 404: https://collapsedwave.com/Smooth-Curve
# HTTP 404: https://collapsedwave.com/Critical-Points
# HTTP 404: https://collapsedwave.com/real-line
# HTTP 404: https://collapsedwave.com/conjugate
# HTTP 404: https://collapsedwave.com/interval
# HTTP 404: https://collapsedwave.com/supremum-operator
# HTTP 404: https://collapsedwave.com/velocity
# HTTP 404: https://collapsedwave.com/subspace
# HTTP 404: https://collapsedwave.com/graph
# HTTP 404: https://collapsedwave.com/Hooke`s-law
# HTTP 404: https://collapsedwave.com/quantum-system
# HTTP 404: https://collapsedwave.com/Energy-function
# HTTP 404: https://collapsedwave.com/Lebesgue-measure
# HTTP 404: https://collapsedwave.com/integrable-function
# HTTP 404: https://collapsedwave.com/EPR
# HTTP 404: https://collapsedwave.com/CNOT

# %%
# Broken
show_urls(results[results["broken"]==True])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>crawled</th>
#       <th>broken</th>
#       <th>url</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>./Artificial-Neural-Network</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/Artificial-Neural-Network" target="_blank">https://collapsedwave.com/Artificial-Neural-Network</a></td>
#     </tr>
#     <tr>
#       <th>./CNOT</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/CNOT" target="_blank">https://collapsedwave.com/CNOT</a></td>
#     </tr>
#     <tr>
#       <th>./Critical-Points</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/Critical-Points" target="_blank">https://collapsedwave.com/Critical-Points</a></td>
#     </tr>
#     <tr>
#       <th>./DBSCAN</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/DBSCAN" target="_blank">https://collapsedwave.com/DBSCAN</a></td>
#     </tr>
#     <tr>
#       <th>./Diffeomorphism</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/Diffeomorphism" target="_blank">https://collapsedwave.com/Diffeomorphism</a></td>
#     </tr>
#     <tr>
#       <th>./Dual-Tree-Boruvka</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/Dual-Tree-Boruvka" target="_blank">https://collapsedwave.com/Dual-Tree-Boruvka</a></td>
#     </tr>
#     <tr>
#       <th>./EPR</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/EPR" target="_blank">https://collapsedwave.com/EPR</a></td>
#     </tr>
#     <tr>
#       <th>./Elman-Networks</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/Elman-Networks" target="_blank">https://collapsedwave.com/Elman-Networks</a></td>
#     </tr>
#     <tr>
#       <th>./Energy-function</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/Energy-function" target="_blank">https://collapsedwave.com/Energy-function</a></td>
#     </tr>
#     <tr>
#       <th>./Equation-of-motion</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/Equation-of-motion" target="_blank">https://collapsedwave.com/Equation-of-motion</a></td>
#     </tr>
#     <tr>
#       <th>./F1-score</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/F1-score" target="_blank">https://collapsedwave.com/F1-score</a></td>
#     </tr>
#     <tr>
#       <th>./Fully-recurrent-neural-networks</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/Fully-recurrent-neural-networks" target="_blank">https://collapsedwave.com/Fully-recurrent-neural-networks</a></td>
#     </tr>
#     <tr>
#       <th>./Hamilton's-Equations</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/Hamilton's-Equations" target="_blank">https://collapsedwave.com/Hamilton's-Equations</a></td>
#     </tr>
#     <tr>
#       <th>./Hooke`s-law</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/Hooke`s-law" target="_blank">https://collapsedwave.com/Hooke`s-law</a></td>
#     </tr>
#     <tr>
#       <th>./Implicit-Function-Theorem</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/Implicit-Function-Theorem" target="_blank">https://collapsedwave.com/Implicit-Function-Theorem</a></td>
#     </tr>
#     <tr>
#       <th>./Jacobi-identity</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/Jacobi-identity" target="_blank">https://collapsedwave.com/Jacobi-identity</a></td>
#     </tr>
#     <tr>
#       <th>./Jordan-Networks</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/Jordan-Networks" target="_blank">https://collapsedwave.com/Jordan-Networks</a></td>
#     </tr>
#     <tr>
#       <th>./Lebesgue-measure</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/Lebesgue-measure" target="_blank">https://collapsedwave.com/Lebesgue-measure</a></td>
#     </tr>
#     <tr>
#       <th>./Leibniz-rule</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/Leibniz-rule" target="_blank">https://collapsedwave.com/Leibniz-rule</a></td>
#     </tr>
#     <tr>
#       <th>./Linear-Operator</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/Linear-Operator" target="_blank">https://collapsedwave.com/Linear-Operator</a></td>
#     </tr>
#     <tr>
#       <th>./Operator</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/Operator" target="_blank">https://collapsedwave.com/Operator</a></td>
#     </tr>
#     <tr>
#       <th>./Partial-Derivative</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/Partial-Derivative" target="_blank">https://collapsedwave.com/Partial-Derivative</a></td>
#     </tr>
#     <tr>
#       <th>./Phase-gate</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/Phase-gate" target="_blank">https://collapsedwave.com/Phase-gate</a></td>
#     </tr>
#     <tr>
#       <th>./Plancks-reduced-constant</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/Plancks-reduced-constant" target="_blank">https://collapsedwave.com/Plancks-reduced-constant</a></td>
#     </tr>
#     <tr>
#       <th>./Prims-algorithm</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/Prims-algorithm" target="_blank">https://collapsedwave.com/Prims-algorithm</a></td>
#     </tr>
#     <tr>
#       <th>./Python</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/Python" target="_blank">https://collapsedwave.com/Python</a></td>
#     </tr>
#     <tr>
#       <th>./Riesz-Representation-Theorem</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/Riesz-Representation-Theorem" target="_blank">https://collapsedwave.com/Riesz-Representation-Theorem</a></td>
#     </tr>
#     <tr>
#       <th>./Smooth-Curve</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/Smooth-Curve" target="_blank">https://collapsedwave.com/Smooth-Curve</a></td>
#     </tr>
#     <tr>
#       <th>./absolute-homogeneity</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/absolute-homogeneity" target="_blank">https://collapsedwave.com/absolute-homogeneity</a></td>
#     </tr>
#     <tr>
#       <th>./acceleration</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/acceleration" target="_blank">https://collapsedwave.com/acceleration</a></td>
#     </tr>
#     <tr>
#       <th>./anti-commutative</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/anti-commutative" target="_blank">https://collapsedwave.com/anti-commutative</a></td>
#     </tr>
#     <tr>
#       <th>./bilinear</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/bilinear" target="_blank">https://collapsedwave.com/bilinear</a></td>
#     </tr>
#     <tr>
#       <th>./binary-classification</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/binary-classification" target="_blank">https://collapsedwave.com/binary-classification</a></td>
#     </tr>
#     <tr>
#       <th>./binary-operation</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/binary-operation" target="_blank">https://collapsedwave.com/binary-operation</a></td>
#     </tr>
#     <tr>
#       <th>./braket-notation</th>
#       <td>True</td>
#       <td>True</td>
#       <td><a href="https://collapsedwave.com/braket-notation" target="_blank">https://collapsedwave.com/braket-notation</a></td>
#     </tr>
#     <tr>
#       <th>./cauchy-sequence</th>
#       <td>True</td>

# %%
# External URLs
show_urls(results[list(map(lambda x: urlparse(x).path.startswith('/'), results.index))])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>crawled</th>
#       <th>broken</th>
#       <th>url</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>/</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/" target="_blank">https://collapsedwave.com/</a></td>
#     </tr>
#     <tr>
#       <th>/index.xml</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/index.xml" target="_blank">https://collapsedwave.com/index.xml</a></td>
#     </tr>
#   </tbody>
# </table>

# %%
# Success
show_urls(results[results["broken"]==False])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>crawled</th>
#       <th>broken</th>
#       <th>url</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th></th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com" target="_blank">https://collapsedwave.com</a></td>
#     </tr>
#     <tr>
#       <th>.</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/" target="_blank">https://collapsedwave.com/</a></td>
#     </tr>
#     <tr>
#       <th>..</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/" target="_blank">https://collapsedwave.com/</a></td>
#     </tr>
#     <tr>
#       <th>../tags/classical-mechanics</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/tags/classical-mechanics" target="_blank">https://collapsedwave.com/tags/classical-mechanics</a></td>
#     </tr>
#     <tr>
#       <th>../tags/definition</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/tags/definition" target="_blank">https://collapsedwave.com/tags/definition</a></td>
#     </tr>
#     <tr>
#       <th>../tags/graph-theory</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/tags/graph-theory" target="_blank">https://collapsedwave.com/tags/graph-theory</a></td>
#     </tr>
#     <tr>
#       <th>../tags/machine-learning</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/tags/machine-learning" target="_blank">https://collapsedwave.com/tags/machine-learning</a></td>
#     </tr>
#     <tr>
#       <th>../tags/math</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/tags/math" target="_blank">https://collapsedwave.com/tags/math</a></td>
#     </tr>
#     <tr>
#       <th>../tags/physics</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/tags/physics" target="_blank">https://collapsedwave.com/tags/physics</a></td>
#     </tr>
#     <tr>
#       <th>../tags/quantum-theory</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/tags/quantum-theory" target="_blank">https://collapsedwave.com/tags/quantum-theory</a></td>
#     </tr>
#     <tr>
#       <th>../📕-Maxwell-Equations</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/📕-Maxwell-Equations" target="_blank">https://collapsedwave.com/📕-Maxwell-Equations</a></td>
#     </tr>
#     <tr>
#       <th>../📕-Postulates-of-Quantum-Mechanics</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/📕-Postulates-of-Quantum-Mechanics" target="_blank">https://collapsedwave.com/📕-Postulates-of-Quantum-Mechanics</a></td>
#     </tr>
#     <tr>
#       <th>../📗-Heisenberg-Uncertainty-Principle</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/📗-Heisenberg-Uncertainty-Principle" target="_blank">https://collapsedwave.com/📗-Heisenberg-Uncertainty-Principle</a></td>
#     </tr>
#     <tr>
#       <th>../📗-No-cloning-theorem</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/📗-No-cloning-theorem" target="_blank">https://collapsedwave.com/📗-No-cloning-theorem</a></td>
#     </tr>
#     <tr>
#       <th>../📘-Block-Sphere</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/📘-Block-Sphere" target="_blank">https://collapsedwave.com/📘-Block-Sphere</a></td>
#     </tr>
#     <tr>
#       <th>../📘-Bose-Einstein-condensate</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/📘-Bose-Einstein-condensate" target="_blank">https://collapsedwave.com/📘-Bose-Einstein-condensate</a></td>
#     </tr>
#     <tr>
#       <th>../📘-Coherent-state</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/📘-Coherent-state" target="_blank">https://collapsedwave.com/📘-Coherent-state</a></td>
#     </tr>
#     <tr>
#       <th>../📘-Commutator</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/📘-Commutator" target="_blank">https://collapsedwave.com/📘-Commutator</a></td>
#     </tr>
#     <tr>
#       <th>../📘-Conjugate-variable</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/📘-Conjugate-variable" target="_blank">https://collapsedwave.com/📘-Conjugate-variable</a></td>
#     </tr>
#     <tr>
#       <th>../📘-Constant-of-Motion</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/📘-Constant-of-Motion" target="_blank">https://collapsedwave.com/📘-Constant-of-Motion</a></td>
#     </tr>
#     <tr>
#       <th>../📘-Convex-function</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/📘-Convex-function" target="_blank">https://collapsedwave.com/📘-Convex-function</a></td>
#     </tr>
#     <tr>
#       <th>../📘-Convolutional-Neural-Network</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/📘-Convolutional-Neural-Network" target="_blank">https://collapsedwave.com/📘-Convolutional-Neural-Network</a></td>
#     </tr>
#     <tr>
#       <th>../📘-Damped-Harmonic-Oscillator</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/📘-Damped-Harmonic-Oscillator" target="_blank">https://collapsedwave.com/📘-Damped-Harmonic-Oscillator</a></td>
#     </tr>
#     <tr>
#       <th>../📘-Entropy</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/📘-Entropy" target="_blank">https://collapsedwave.com/📘-Entropy</a></td>
#     </tr>
#     <tr>
#       <th>../📘-F-score</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/📘-F-score" target="_blank">https://collapsedwave.com/📘-F-score</a></td>
#     </tr>
#     <tr>
#       <th>../📘-Flow</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/📘-Flow" target="_blank">https://collapsedwave.com/📘-Flow</a></td>
#     </tr>
#     <tr>
#       <th>../📘-Frequency-of-Oscillation</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/📘-Frequency-of-Oscillation" target="_blank">https://collapsedwave.com/📘-Frequency-of-Oscillation</a></td>
#     </tr>
#     <tr>
#       <th>../📘-Gauge-Theory</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/📘-Gauge-Theory" target="_blank">https://collapsedwave.com/📘-Gauge-Theory</a></td>
#     </tr>
#     <tr>
#       <th>../📘-Hamiltonian-Operator</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/📘-Hamiltonian-Operator" target="_blank">https://collapsedwave.com/📘-Hamiltonian-Operator</a></td>
#     </tr>
#     <tr>
#       <th>../📘-Harmonic-Oscillator</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/📘-Harmonic-Oscillator" target="_blank">https://collapsedwave.com/📘-Harmonic-Oscillator</a></td>
#     </tr>
#     <tr>
#       <th>../📘-Kinetic-energy</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/📘-Kinetic-energy" target="_blank">https://collapsedwave.com/📘-Kinetic-energy</a></td>
#     </tr>
#     <tr>
#       <th>../📘-Merkle-Tree</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/📘-Merkle-Tree" target="_blank">https://collapsedwave.com/📘-Merkle-Tree</a></td>
#     </tr>
#     <tr>
#       <th>../📘-Minimum-spanning-tree</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/📘-Minimum-spanning-tree" target="_blank">https://collapsedwave.com/📘-Minimum-spanning-tree</a></td>
#     </tr>
#     <tr>
#       <th>../📘-Pauli-Matrix</th>
#       <td>True</td>
#       <td>False</td>
#       <td><a href="https://collapsedwave.com/📘-Pauli-Matrix" target="_blank">https://collapsedwave.com/📘-Pauli-Matrix</a></td>
#     </tr>
#     <tr>
#       <th>../📘-P
